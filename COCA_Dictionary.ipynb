# %% [markdown]
# # Testing With 1 File

# %%
"""
import numpy as np
dict = {}

text = open('/Users/TaraD/Ling_Research/COCA/COCA/Word_lemma_PoS/wlp_spok_2005.txt', 'r', encoding='utf-8', errors='ignore')
lines = (text.readlines())

count = -1
for line in lines:
    count += 1
    #if count <50:
        #if count >= 0:
    line_list = line.split()
    if len(line_list)==3 and line_list[2] != 'y':
        word = line_list[1]
        if word in dict:
            dict[word] = dict[word] + 1
        else:
            dict[word] = 1
        #print(word)
        
    #else:
        #break
print(count)
print(len(dict))
#print(dict)
#print(dict.values())
#print(max(dict, key=dict.get))

text.close()
"""
# Out:
# 5241539
# 49313

# %%
"""
import os
directory = '/Users/TaraD/Ling_Research/COCA/COCA/Word_lemma_PoS/'

count = 0
for file in os.listdir(directory):
    count+=1
print(count)
"""
# Out:
# 115

# %%
"""
sorted_dict = sorted(dict, key=dict.get, reverse=True)
print(sorted_dict)
"""
# Out:
# ['be', 'the', 'to', 'and', 'a', 'of', 'that', 'in', 'you', 'i', 'have', 'it', 'do', 'we', 'this', 'for', 'on', 'he', 'they', 'with', 'go', 'but', 'say', 'there', 'what', 'know', 'as', 'not', "n't", 'so', 'at', 'get', 'about', 'from', 'think', 'all', 'will', 'people', 'just', 'now', "'s", 'his', 'one', 'who', 'out', 'can', 'well', 'or', 'if', 'like', 'up', 'right', 'she', 'us', 'come', 'when', 'some', 'by', 'very', 'see', 'time', 'here', 'would', 'more', 'make', 'their', '...', 'your', 'my', 'no', 'me', 'her', 'want', 'new', 'year', 'take', 'how', 'because', 'them', 'our', 'look', 'thing', 'back', 'really', 'these', 'day', 'talk', 'him', 'could', 'way', 'good', 'tell', 'other', 'much', 'president', 'its', 'first', "'", 'then', 'where', 'lot', 'mean', 'over', 'which', 'into', 'those', 'than', 'work', 'also', 'yes', 'two', 'call', 'after', 'today', 'state', 'let', 'try', 'many', 'story', 'even', 'give', 'man', 'show', 'any', 'down', 'find', 'happen', 'last', 'kind', 'end', 'need', 'news', 'still', 'why', 'life', 'something', 'little', 'most', 'week', 'only', 'thank', 'case', 'big', 'home', 'house', 'country', 'use', 'question', 'yeah', 'before', 'world', 'american', 'should', 'begin', 'put', 'next', 'nt', 'start', 'unidentified', 'hear', 'actually', 'cnn', 'ask', 'live', 'woman', 'iraq', 'help', 'through', 'great', 'feel', 'family', 'child', 'may', 'part', 'point', 'around', 'break', 'fact', 'believe', 'off', 'again', 'never', 'city', 'long', 'report', 'bush', 'another', 'government', 'problem', 'too', 'court', 'three', 'every', 'number', 'guy', 'place', 'leave', 'video', 'course', 'keep', 'own', 'john', 'ok', 'issue', 'oh', 'bring', 'police', 'war', 'morning', 'security', 'hour', 'money', 'join', 'change', 'same', 'tonight', 'play', 'love', 'sure', 'ago', 'mr', 'write', 'white', 'always', 'name', 'york', 'united', 'different', 'might', 'month', 'turn', 'away', 'become', 'kill', 'seem', 'kid', 'bad', 'job', 'sort', 'million', 'move', 'run', 'thanks', 'area', 'percent', 'high', 'both', 'against', 'few', 'clip', 'videotape', 'far', 'speak', 'watch', 'night', 'old', 'washington', 'ever', 'early', 'im', 'whether', 'school', 'hope', 'law', 'book', 'public', 'meet', 'since', 'anything', 'hurricane', 'official', 'national', 'orleans', 'bill', 'better', 'able', 'water', 'deal', 'word', 'hard', 'person', 'real', 'plan', 'iraqi', 'important', 'maybe', 'pay', 'four', 'stay', 'commercial', 'lose', 'attack', 'force', 'probably', 'later', 'young', 'bit', 'under', 'friend', 'continue', 'npr', 'judge', 'business', 'best', 'face', 'michael', 'while', 'group', 'vote', 'understand', 'between', 'death', 'ph', 'everything', 'program', 'though', 'die', 'mother', 'least', 'idea', 'certainly', 'correspondent', 'line', 'hit', 'everybody', 'head', 'america', 'political', 'pretty', 'hold', 'moment', 'minute', 'whole', '-', 'company', 'second', 'republican', 'enough', 'set', 'information', 'side', 'open', 'stop', 'male', 'once', 'former', 'late', 'stand', 'car', 'movie', 'center', 'five', 'remember', 'military', 'without', 'already', 'send', 'god', 'together', 'such', 'almost', 'close', 'democrat', 'media', 'storm', 'situation', 'couple', 'lead', 'system', 'support', 'charge', 'nation', 'hand', 'expect', 'reason', 'top', 'spend', 'nothing', 'welcome', 'read', 'fight', 'father', 'member', 'during', 'yet', 'absolutely', 'federal', 'cause', 'ahead', 'exactly', 'sit', 'tavis', 'someone', 'somebody', 'until', 'election', 'picture', 'sense', 'dr', 'street', 'parent', 'answer', 'care', 'power', 'thats', 'party', 'learn', 'david', 'pm', 'record', 'past', 'camera', 'small', '10', 'senator', 'wait', 'each', 'win', 'dolan', 'else', 'cover', 'leader', 'listen', 'along', 'music', 'walk', 'across', 'administration', 'decide', 'behind', 'quite', 'justice', 'rather', 'price', 'body', 'decision', 'agree', 'jackson', 'true', 'matter', 'youre', 'murder', 'process', 'wrong', 'air', 'voice-over', 'buy', 'department', 'mind', 'room', 'social', 'phone', 'large', 'allow', 'wife',  ...

# %% [markdown]
# # Running all Files --> Full Dictionary

# %%
PoS_remove = ['y','x', '"@_ge','...','ge_"@', 'zz_nn', 'fo']
Join = ["'s", "'ll","'m", "'ve","'re","n't", "'d", "'"]

def phone_number(word):
    if len(word) >= 8 and word[3] == '-' and word[0].isdigit()==True and word[4].isdigit()==True and word[5].isdigit()==True and word[1].isdigit()==True and word[6].isdigit()==True:
        return True
    else:
        return False
    
def line_inclusion(x):
    if len(x)==3 and x[2] not in PoS_remove and x[0].lower() not in Join and 'www' not in x[0].lower() and '*' not in x[0].lower() and phone_number(x[0].lower())==False:
        return True

# %%
import numpy as np
import os
import time

t1 = time.time()


dict = {}
directory = '/home/tdacunha/pnc_project/COCA/Word_lemma_PoS/' #Changed for server

count = 0
for file in os.listdir(directory):
    #if count > 0:
        #break
    #count+=1
    #print(file)
    
    #Full directory:
    text = open(directory + file, 'r', encoding='utf-8', errors='ignore')
    
    #Test file:
    #text = open('/home/tdacunha/pnc_project/COCA/Word_lemma_PoS/wlp_news_2007.txt', 'r', encoding='utf-8', errors='ignore')
    
    lines = (text.readlines())

    length = len(lines)
    
    for index in range(length):
        line = lines[index]
        #line_after = lines[index+1]
        
        line_list = line.split()
        #line_list_after = line_after.split()
        
        #MAKING SURE LINE/WORD SHOULD BE INCLUDED
        if line_inclusion(line_list)==True:
            word = (line_list[0]).lower()
            
            #MAKING SURE NOT END WORD AND CONCATENATING CONTRACTIONS
            if (index+1) < length:
                word_after = ((lines[index+1]).split())[0].lower()   #(line_list_after[0]).lower()

                if word_after in Join:
                    word = word + word_after
            
            #ADDING WORD TO DICTIONARY
            if word in dict:
                dict[word] = dict[word] + 1
                
            else:
                dict[word] = 1
            #print(word)
            
    text.close()        
    
print(time.time()-t1)
print(len(dict))
#print(dict)
# Out:
# wlp_fic_1993.txt
# wlp_acad_2001.txt
# wlp_spok_1993.txt
# wlp_spok_1992.txt
# wlp_acad_2000.txt
# wlp_fic_1992.txt
# wlp_fic_1990.txt
# wlp_acad_2002.txt
# wlp_news_2009.txt
# wlp_spok_1990.txt
# wlp_spok_1991.txt
# wlp_news_2008.txt
# wlp_acad_2003.txt
# wlp_fic_1991.txt
# wlp_fic_1995.txt
# wlp_acad_2007.txt
# wlp_spok_1995.txt
# wlp_spok_1994.txt
# wlp_acad_2012.txt
# wlp_acad_2006.txt
# wlp_fic_1994.txt
# wlp_fic_1996.txt
# wlp_acad_2010.txt
# wlp_acad_2004.txt
# wlp_mag_1998.txt
# wlp_spok_1996.txt
# wlp_spok_1997.txt
# wlp_mag_1999.txt
# wlp_acad_2005.txt
# wlp_acad_2011.txt
# wlp_fic_1997.txt
# wlp_acad_1999.txt
# wlp_mag_2005.txt
# wlp_mag_2011.txt
# wlp_news_1992.txt
# wlp_news_1993.txt
# wlp_mag_2010.txt
# wlp_mag_2004.txt
# wlp_acad_1998.txt
# wlp_fic_2008.txt
# wlp_mag_2012.txt
# wlp_mag_2006.txt
# wlp_news_1991.txt
# wlp_spok_2008.txt
# wlp_spok_2009.txt
# wlp_news_1990.txt
# wlp_mag_2007.txt
# wlp_fic_2009.txt
# wlp_news_1994.txt
# wlp_mag_2003.txt
# wlp_mag_2002.txt
# wlp_news_1995.txt
# wlp_news_1997.txt
# wlp_mag_2000.txt
# wlp_mag_2001.txt
# wlp_news_1996.txt
# wlp_acad_1990.txt
# wlp_fic_2002.txt
# wlp_spok_2002.txt
# wlp_spok_2003.txt
# wlp_fic_2003.txt
# wlp_acad_1991.txt
# wlp_acad_1993.txt
# wlp_fic_2001.txt
# wlp_news_1998.txt
# wlp_spok_2001.txt
# wlp_spok_2000.txt
# wlp_news_1999.txt
# wlp_fic_2000.txt
# wlp_acad_1992.txt
# wlp_acad_1996.txt
# wlp_fic_2004.txt
# wlp_fic_2010.txt
# wlp_spok_2010.txt
# wlp_spok_2004.txt
# wlp_spok_2005.txt
# wlp_spok_2011.txt
# wlp_fic_2011.txt
# wlp_fic_2005.txt
# wlp_acad_1997.txt
# wlp_acad_1995.txt
# wlp_fic_2007.txt
# wlp_mag_2009.txt
# wlp_spok_2007.txt
# wlp_spok_2012.txt
# wlp_spok_2006.txt
# wlp_mag_2008.txt
# wlp_fic_2006.txt
# wlp_fic_2012.txt
# wlp_acad_1994.txt
# wlp_acad_2008.txt
# wlp_mag_1994.txt
# wlp_news_2003.txt
# wlp_news_2002.txt
# wlp_mag_1995.txt
# wlp_acad_2009.txt
# wlp_fic_1999.txt
# wlp_mag_1997.txt
# wlp_news_2000.txt
# wlp_spok_1999.txt
# wlp_spok_1998.txt
# wlp_news_2001.txt
# wlp_mag_1996.txt
# wlp_fic_1998.txt
# wlp_news_2005.txt
# wlp_news_2011.txt
# wlp_mag_1992.txt
# wlp_mag_1993.txt
# wlp_news_2010.txt
# wlp_news_2004.txt
# wlp_news_2012.txt
# wlp_news_2006.txt
# wlp_mag_1991.txt
# wlp_mag_1990.txt
# wlp_news_2007.txt
# 1774.8999421596527
# 1998160

# %%
"""
print(dict)
"""
# Out:
# {'when': 8920, 'martin': 314, 'luther': 66, 'king': 626, 'was': 20993, 'buried': 83, 'in': 71691, 'atlanta': 857, 'the': 197106, 'live': 979, 'tv': 766, 'coverage': 254, 'lasted': 45, 'hours': 958, 'president': 2196, 'lyndon': 12, 'johnson': 656, 'announced': 415, 'a': 93182, 'national': 1817, 'day': 2864, 'of': 86134, 'mourning': 22, 'richard': 387, 'nixon': 58, 'called': 1391, 'great': 1558, 'leader': 462, 'even': 3552, 'one': 9413, "king's": 55, 'most': 4305, 'beastly': 4, 'political': 1146, 'enemies': 56, 'mississippi': 122, 'rep.': 297, 'william': 263, 'colmer': 1, 'honored': 54, "president's": 115, 'call': 1231, 'to': 93362, 'unity': 45, 'by': 14236, 'terming': 2, 'murder': 228, 'dastardly': 3, 'act': 496, 'others': 1173, 'demurred': 2, 'south': 1181, 'carolina': 374, 'sen.': 432, 'strom': 2, 'thurmond': 3, 'wrote': 621, 'we': 9965, 'are': 17027, 'now': 4296, 'witnessing': 12, 'whirlwind': 8, 'sowed': 3, 'years': 5487, 'ago': 1574, 'some': 6078, 'preachers': 10, 'and': 92005, 'teachers': 386, 'began': 926, 'telling': 240, 'people': 6165, 'that': 37244, 'each': 1912, 'man': 1285, 'could': 4220, 'be': 16084, 'his': 17055, 'own': 1935, 'judge': 448, 'case': 1405, 'another': 2368, 'prominent': 117, 'conservative': 254, 'said': 18576, 'it': 23819, 'sort': 296, 'tragedy': 85, 'compromising': 12, 'with': 25817, 'law': 1286, 'order': 557, 'started': 954, 'choosing': 85, 'which': 6246, 'laws': 399, "they'd": 157, 'break': 458, 'ronald': 93, 'reagan': 75, 'governor': 222, 'california': 714, 'arguing': 74, 'had': 8457, 'coming': 811, 'who': 12278, 'taught': 203, 'they': 13528, 'choose': 216, 'soaring': 37, 'letter': 340, 'from': 15998, 'uplifts': 1, 'human': 523, 'personality': 117, 'is': 32205, 'just': 5259, 'any': 2709, 'degrades': 3, 'unjust': 12, 'thus': 145, 'i': 17599, 'can': 7394, 'urge': 50, 'men': 848, 'obey': 20, '1954': 34, 'decision': 542, 'supreme': 225, 'court': 1162, 'for': 36458, 'morally': 20, 'right': 2202, 'them': 4947, 'disobey': 2, 'segregation': 12, 'ordinances': 15, 'wrong': 504, "that's": 2524, 'not': 12927, 'what': 6614, 'you': 11874, 'hear': 445, 'conservatives': 86, 'today': 1430, 'course': 837, 'get': 4812, 'fantastical': 4, 'tributes': 16, 'properly': 92, 'understood': 68, 'actually': 566, 'or': 11896, 'would': 7013, 'have': 16062, 'been': 6600, 'he': 24724, 'lived': 364, 'but': 16764, 'if': 7656, 'going': 3247, 'holiday': 149, 'honor': 222, 'history': 1112, 'might': 1960, 'as': 20487, 'well': 2312, 'recover': 57, 'true': 497, 'story': 1029, 'both': 1770, 'democrats': 390, 'republicans': 263, 'hated': 34, 'doctrines': 10, 'legacy': 115, 'lawlessness': 7, 'idea': 703, 'expounded': 1, 'systematically': 15, 'book': 1016, 'came': 1414, 'out': 7602, 'shortly': 112, 'after': 5699, 'assassination': 56, 'house': 2307, 'divided': 111, 'life': 2224, "right's": 2, 'better': 1733, 'writers': 197, 'lionel': 18, 'lokos': 2, 'civil': 327, 'disobedience': 8, 'glorified': 6, 'meant': 237, 'put': 1546, 'kind': 1016, 'good': 3116, 'housekeeping': 11, 'seal': 42, 'approval': 186, 'on': 26826, 'met': 427, 'favor': 201, 'particular': 233, 'enemy': 120, "chicago's": 83, 'white': 1505, 'ethnics': 1, 'marches': 17, 'open': 1187, 'housing': 502, 'organized': 139, '1966': 43, 'next': 2144, 'year': 4913, 'chicago': 1030, 'archdiocese': 8, 'released': 362, 'new': 7201, 'catechism': 2, 'leaders': 585, 'negro': 21, 'brave': 25, 'named': 455, 'stated': 55, 'preaches': 9, 'message': 391, 'jesus': 123, 'love': 1249, 'catholic': 247, 'laymen': 1, 'outraged': 20, 'demanded': 53, 'an': 13185, 'fbi': 117, 'investigation': 350, 'local': 1171, 'clergy': 27, 'know': 2677, 'about': 10071, 'chicagoans': 20, 'threw': 194, 'bricks': 23, 'at': 22302, 'forgotten': 68, 'while': 2728, 'such': 2837, 'hooliganism': 2, 'universally': 14, 'reviled': 7, 'reviling': 2, 'establishment': 45, 'also': 5027, 'embraced': 69, 'reaganlike': 1, 'arguments': 59, 'why': 1661, 'only': 4179, 'expected': 620, 'upon': 258, 'tribune': 79, 'editorialized': 2, 'because': 439 ...

# %%
#import pickle
dict_COCA_txt = open("TESTdict_COCA_txt.txt", "w")
for k, v in dict.items():
    dict_COCA_txt.write(str(k) + ' : '+str(v)+'\n\n')
#dict_COCA_txt.write((dict))

#with open("dict_COCA_txt3.txt", "w") as file:
    #file.write(pickle.dumps(dict))
dict_COCA_txt.close()

#import pickle
#dict_COCA_pkl = open("dict_COCA_pkl3.pkl", "wb")
#pickle.dump(dict,dict_COCA_pkl)
#dict_COCA_pkl.close()

# %%
#import numpy as np
#sorted_dict_full = sorted(dict, key=dict.get, reverse=True)
#print(type(sorted_dict_full))
#print(np.shape(sorted_dict_full))
#print(type(dict))
#dict_COCA_txt_sorted = open("dict_COCA_txt3_sorted.txt", "w")
#for k, v in sorted_dict_full:
#    dict_COCA_txt_sorted.write(str(k) + ' : '+str(v)+'\n\n')
#dict_COCA_txt_sorted.close()
#print(sorted_dict_full)

# %%
import io
file2 = io.open

# %%
#TESTING ETC
#word = '215-382-5349'
#word[8].isdigit()
# Out:
# True
