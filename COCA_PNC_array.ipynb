# %%
import time
import csv
import numpy as np
import ast

t0 = time.time()
#LOADING PNC DATA
pnc_file = open('/home/tdacunha/pnc_project/refaved_PNCvowels_master_corrected_shorta.csv', newline='')
#pnc_file = open('/Users/TaraD/Downloads/refaved_PNCvowels_master_corrected_shorta.csv', newline='')
print('opened pnc file')
data = np.array(list(csv.reader(pnc_file)))
print('made data array')
pnc_words = (data[1:,11])
#pnc_vowel_freqs = (data[1:,13]) #CAN CHANGE TO DIFFERENT FREQUENCY COLUMN
pnc_trans = data[1:,34]
pnc_v_index = data[1:,32]
pnc_v_class = data[1:,51]
pnc_stress = data[1:,9]

print('reached first for loop', time.time() - t0)
for i in range(len(pnc_words)):
    pnc_words[i] = pnc_words[i].lower()
print("PNC length:", len(pnc_words))
#print("time for loading and making PNC lists:", time.time()-t0)


#LOADING COCA DICTIONARY
COCA_words = open('/home/tdacunha/pnc_project/dict_COCA_txt3.txt', 'r')
#COCA_words = open('/Users/TaraD/LING_Research/dict_COCA_txt3.txt', 'r')
COCA_list = COCA_words.readlines()

omitfile = open('/home/tdacunha/pnc_project/omitwords.csv')
#omitfile = open('/Users/TaraD/Downloads/omitwords.csv')
omitdata = list(csv.reader(omitfile))
omitwords = []
for i in range(1,len(omitdata)):
    line = (((omitdata)[i]))
    if line != []:
        omitwords.append(line[0].lower())
#print(omitwords)
#print(COCA_list[0:50])
                      
omitfile.close()
COCA_words.close()


t1 = time.time()
COCA_list = [value for value in COCA_list if value != '\n']
#print("time for list removal = ", time.time() - t1)
#print(COCA_list[0:50])

#Removing omitted words from COCA_list:
#for j in range(len(COCA_list)):
for line in COCA_list:
    #line = COCA_list[j]
    array = line.split(':')
    word = array[0][:-1]
    if (word in omitwords) == True:
        COCA_list.remove(line)
#print(COCA_list[0:50])
            

print('time for opening etc:',time.time()-t0)
# Out:
# opened pnc file
# made data array
# reached first for loop 224.47308683395386
# PNC length: 935728
# time for opening etc: 314.241712808609

# %%
t1 = time.time()
pnc_words_list = list(pnc_words)
print("COCA_list length", len(COCA_list))

header = ['COCA word', 'COCA dict #', 'PNC word', 'Trans', 'v_index', 'v_class', 'Stress', 'PNC count']
PNCinCOCA = [header]

count = 0
for line in COCA_list:
    #if count < 21:
    if count%1000 == 0 or count==1 or count==2:
        print(count, time.time()-t1)
            
    #Getting COCA info
    #print("before splitting etc", time.time()-t1)
    array = line.split(':')
    word = array[0][:-1]
    number = (array[1].replace('\n',''))[1:]
    #line_list = [word, number]
        
    #IF COCA WORD IN PNC, GATHER INFO AND APPEND
    #print("before indices:", time.time()-t1)
    #indices = (np.where(pnc_words==word))[0]
    indices = [i for i in range(len(pnc_words_list)) if pnc_words_list[i]==word]
    
    #print("after indices:", time.time()-t1)
    if len(indices) != 0:
        list_array = []
        list_array_count = []
        for index in indices:
            line_list=[word, number, pnc_words[index], pnc_trans[index], pnc_v_index[index], pnc_v_class[index], pnc_stress[index], ]
                
            if (line_list not in list_array) == True:
                list_array.append(line_list)
                list_array_count.append(1)
                    
            else:
                ind = list_array.index(line_list)
                list_array_count[ind] +=1
        for i in range(len(list_array)):
            (list_array[i]).append(list_array_count[i])
                
                    
            
        PNCinCOCA.extend(list_array)
        
    #IF COCA WORD NOT IN PNC, PUT DASHES        
    else:
        line_list=[word,number,'-','-','-','-','-','-']
        PNCinCOCA.append(line_list)
    #print("after if/for loop:", time.time()-t1)
    
    count += 1
        
print('finished looping')        
PNCinCOCA = np.array(PNCinCOCA)
#print(PNCinCOCA)

print('finished PNCinCOCA array, now saving files')
np.savetxt('PNCinCOCA_full.txt',PNCinCOCA,'%-15s')
np.savetxt('PNCinCOCA_full.csv',PNCinCOCA, '%s',delimiter=",")

print(time.time()-t1)
# Out:
# COCA_list length 1998062
# 0 21.180233001708984
# 1 22.537208080291748
# 2 23.1565260887146
# finished looping
# [['COCA word' 'COCA dict #' 'PNC word' 'Trans' 'v_index' 'v_class'
#   'Stress' 'PNC count']
#  ['afternoon' '33129' 'afternoon' 'AE2 F T ER0 N UW1 N' '1' 'NA' '2' '57']
#  ['afternoon' '33129' 'afternoon' 'AE2 F T ER0 N UW1 N' '6' 'Tuw' '1'
#   '61']
#  ['afternoon' '33129' 'afternoon' 'AE2 F T ER0 N UW1 N' '4' '*hr' '0'
#   '14']
#  ['late' '83875' 'late' 'L EY1 T' '2' 'ey' '1' '143']
#  ['late' '83875' 'late' 'AE1 AH0 Z L EY1 N D T HH' '1' 'NA' '1' '1']
#  ['late' '83875' 'late' 'AE1 AH0 Z L EY1 N D T HH' '5' 'ey' '1' '1']
#  ['late' '83875' 'late' 'OW1 L EY1 N T' '1' 'ow' '1' '1']
#  ['late' '83875' 'late' 'L DH IY0 EY1 T' '3' 'iy' '0' '1']
#  ['late' '83875' 'late' 'L DH IY0 EY1 T' '4' 'ey' '1' '1']
#  ['late' '83875' 'late' 'M L AY1 EY1 T' '3' 'ay' '1' '1']
#  ['late' '83875' 'late' 'M L AY1 EY1 T' '4' 'ey' '1' '1']
#  ['july' '38955' 'july' 'JH AH0 L AY1' '4' 'ay' '1' '37']
#  ['july' '38955' 'july' 'JH AH0 L AY1' '2' '@' '0' '13']
#  ['july' '38955' 'july' 'JH UW2 L AY1' '2' 'uw' '2' '1']
#  ['july' '38955' 'july' 'JH UW2 L AY1' '4' 'ay' '1' '1']
#  ['children' '216374' 'children' 'CH IH1 L D R AH0 N' '6' '@' '0' '153']
#  ['children' '216374' 'children' 'CH IH1 L D R AH0 N' '2' 'i' '1' '62']
#  ['children' '216374' 'children' 'DH CH IH1 EH1 L D R R AH0 N' '4' 'e'
#   '1' '1']
#  ['children' '216374' 'children' 'CH T AH0 IH1 L T EY1 D K R AH0 SP N'
#   '3' '@' '0' '1']
#  ['angry' '22693' 'angry' 'AE1 NG G R IY0' '1' 'ae' '1' '67']
#  ['angry' '22693' 'angry' 'AE1 NG G R IY0' '5' 'iyF' '0' '58']]
# finished PNCinCOCA array, now saving files
# 24.4877450466156

# %%
"""
list1 = [1,'2',5,'2']
list2 = [7,8,9]

list3 = [[1,2,3],[4,5,6]]
list1 in list3
list3.append(list2)
#print(list3)
indices = (np.where(np.array(list1)=='7'))[0]
print(len(indices))
"""
# Out:
# 0

# %% [markdown]
# ## Making reduced file with words in both pnc and coca, excluding those with less than 5% count

# %%
import time
import csv
import numpy as np
import ast

t0 = time.time()
PC_file = open('/Users/TaraD/LING_Research/PNCinCOCA_full.csv', newline='')
#pnc_file = open('/Users/TaraD/Downloads/refaved_PNCvowels_master_corrected_shorta.csv', newline='')

print('opened pncincoca file')
#data = np.array(list(csv.reader(pnc_file)))
#print(np.shape(data))
data_array = np.array(list(csv.reader(PC_file)))
data_list_fixed = []
#print(data_array)
for row in data_array:
    if len(row) == 8:
        data_list_fixed.append(row)
    else:
        new_row = []
        number = len(row)-8
        string = ''
        for j in range(0,number+1):
            string += row[j]
        new_row.append(string)
        new_row.extend(row[number+1:])
        data_list_fixed.append(new_row)
data_array_fixed = np.array(data_list_fixed)
print(data_array_fixed[:10])

            

#data = np.array([np.array(xi) for xi in data_array])
print(np.shape(data_array_fixed))
#print(data_array_fixed[:10])
for i in data_array_fixed:
    if (len(i)) != 8:
        print(i, len(i))
# Out:
# opened pncincoca file
# [['COCA word' 'COCA dict #' 'PNC word' 'Trans' 'v_index' 'v_class'
#   'Stress' 'PNC count']
#  ['afternoon' '33129' 'afternoon' 'AE2 F T ER0 N UW1 N' '1' 'NA' '2' '57']
#  ['afternoon' '33129' 'afternoon' 'AE2 F T ER0 N UW1 N' '6' 'Tuw' '1'
#   '61']
#  ['afternoon' '33129' 'afternoon' 'AE2 F T ER0 N UW1 N' '4' '*hr' '0'
#   '14']
#  ['late' '83875' 'late' 'L EY1 T' '2' 'ey' '1' '143']
#  ['late' '83875' 'late' 'AE1 AH0 Z L EY1 N D T HH' '1' 'NA' '1' '1']
#  ['late' '83875' 'late' 'AE1 AH0 Z L EY1 N D T HH' '5' 'ey' '1' '1']
#  ['late' '83875' 'late' 'OW1 L EY1 N T' '1' 'ow' '1' '1']
#  ['late' '83875' 'late' 'L DH IY0 EY1 T' '3' 'iy' '0' '1']
#  ['late' '83875' 'late' 'L DH IY0 EY1 T' '4' 'ey' '1' '1']]
# (2014338, 8)

# %%
print("length of array:", np.shape(data_array_fixed))
header = ['COCA word', 'COCA dict #', 'PNC word', 'Trans', 'v_index', 'v_class', 'Stress', 'PNC count']

reduced_PNCinCOCA = [header]
t0 = time.time()
for i in range(1,len(data_array_fixed)):
    line = data_array_fixed[i]
    word = line[0]
    if word != data_array_fixed[i-1,0] and line[7] != '-':
        word_list = []
    #if line[7] =='1':
        #np.delete(data_array, (i), axis=0)
        #continue
    if line[7] != '-':
        word_list.append(line)
    else:
        continue
    # At last instance of word
    if i == (len(data_array_fixed)-1) or data_array_fixed[i+1,0] != word:
        word_array = np.array(word_list)
        #print(word_array)
        Sum = np.sum((word_array[:,7].astype(int)), axis=0)
        mask = (word_array[:,7].astype(int) >= (.05*Sum))
        reduced_word_array = word_array[mask]
        #print(reduced_word_array)
        #print(len(word_array), len(reduced_word_array))
        reduced_PNCinCOCA.extend((reduced_word_array).tolist())
    else: 
        #print('continue')
        continue

print(np.shape(reduced_PNCinCOCA))
#print(*reduced_PNCinCOCA, sep='\n')
print(time.time()-t0)

np.savetxt('PNCinCOCA_5pcdeleted.csv',reduced_PNCinCOCA, '%s',delimiter=",")
np.savetxt('PNCinCOCA_5pcdeleted.txt',reduced_PNCinCOCA,'%-15s')
# Out:
# length of array: (2014338, 8)
# (31705, 8)
# 15.612656116485596

# %%
print(*reduced_PNCinCOCA, sep='\n')
# Out:
# ['afternoon', '33129', 'afternoon', 'AE2 F T ER0 N UW1 N', '1', 'NA', '2', '57']
# ['afternoon', '33129', 'afternoon', 'AE2 F T ER0 N UW1 N', '6', 'Tuw', '1', '61']
# ['afternoon', '33129', 'afternoon', 'AE2 F T ER0 N UW1 N', '4', '*hr', '0', '14']
# ['late', '83875', 'late', 'L EY1 T', '2', 'ey', '1', '143']
# ['july', '38955', 'july', 'JH AH0 L AY1', '4', 'ay', '1', '37']
# ['july', '38955', 'july', 'JH AH0 L AY1', '2', '@', '0', '13']
# ['children', '216374', 'children', 'CH IH1 L D R AH0 N', '6', '@', '0', '153']
# ['children', '216374', 'children', 'CH IH1 L D R AH0 N', '2', 'i', '1', '62']
# ['angry', '22693', 'angry', 'AE1 NG G R IY0', '1', 'ae', '1', '67']
# ['angry', '22693', 'angry', 'AE1 NG G R IY0', '5', 'iyF', '0', '58']
# ['while', '287334', 'while', 'W AY1 L', '2', 'ay', '1', '303']
# ['while', '287334', 'while', 'HH W AY1 L', '3', 'ay', '1', '30']
# ['worked', '70978', 'worked', 'W ER1 K T', '2', '*hr', '1', '630']
# ['sat', '52508', 'sat', 'S AE1 T', '2', 'ae', '1', '125']
# ['reading', '57699', 'reading', 'R IY1 D AH0 N', '2', 'iy', '1', '56']
# ['reading', '57699', 'reading', 'R IY1 D IH0 NG', '2', 'iy', '1', '13']
# ['reading', '57699', 'reading', 'R IY1 D AH0 N', '4', '@', '0', '12']
# ['nikki', '1590', 'nikki', 'N IH1 K IY0', '2', 'i', '1', '2']
# ['nikki', '1590', 'nikki', 'N IH1 K IY0', '4', 'iyF', '0', '3']
# ['about', '1182613', 'about', 'AH0 B AW1 T', '3', 'aw', '1', '3455']
# ['about', '1182613', 'about', 'AH0 B AW1 T', '1', '@', '0', '992']
# ['how', '585549', 'how', 'HH AW1', '2', 'aw', '1', '1557']
# ['cotton', '11343', 'cotton', 'K AA1 T AH0 N', '2', 'o', '1', '21']
# ['cotton', '11343', 'cotton', 'K AA1 T AH0 N', '4', '@', '0', '7']
# ['candy', '8630', 'candy', 'K AE1 N D IY0', '2', 'aeh', '1', '49']
# ['candy', '8630', 'candy', 'K AE1 N D IY0', '5', 'iyF', '0', '45']
# ['was', '3083112', 'was', 'W AH0 Z', '2', '@', '0', '2172']
# ['was', '3083112', 'was', 'W AH1 Z', '2', 'uh', '1', '1727']
# ['was', '3083112', 'was', 'W AA1 Z', '2', 'o', '1', '481']
# ['a', '9899789', 'a', 'AH0', '1', '@', '0', '7850']
# ['a', '9899789', 'a', 'EY1', '1', 'eyF', '1', '2122']
# ['rainy', '2477', 'rainy', 'R EY1 N IY0', '2', 'ey', '1', '6']
# ['rainy', '2477', 'rainy', 'R EY1 N IY0', '4', 'iyF', '0', '6']
# ['day', '322080', 'day', 'D EY1', '2', 'eyF', '1', '1114']
# ['fact', '155865', 'fact', 'F AE1 K T', '2', 'ae', '1', '386']
# ['sunny', '5567', 'sunny', 'S AH1 N IY0', '2', 'uh', '1', '5']
# ['sunny', '5567', 'sunny', 'S AH1 N IY0', '4', 'iyF', '0', '5']
# ['wanted', '136546', 'wanted', 'W AO1 N AH0 D', '2', 'oh', '1', '381']
# ['wanted', '136546', 'wanted', 'W AO1 N AH0 D', '4', '@', '0', '216']
# ['wanted', '136546', 'wanted', 'W AO1 N T AH0 D', '2', 'oh', '1', '58']
# ['go', '407416', 'go', 'G OW1', '2', 'owF', '1', '4693']
# ['out', '1002667', 'out', 'AW1 T', '1', 'aw', '1', '4649']
# ['play', '117716', 'play', 'P L EY1', '3', 'eyF', '1', '940']
# ['said', '1039828', 'said', 'S EH1 D', '2', 'e', '1', '2407']
# ['meant', '38693', 'meant', 'M EH1 N T', '2', 'e', '1', '44']
# ['talk', '141398', 'talk', 'T AO1 K', '2', 'oh', '1', '757']
# ['boys', '44362', 'boys', 'B OY1 Z', '2', 'oy', '1', '381']
# ['needed', '74089', 'needed', 'N IY1 D AH0 D', '2', 'iy', '1', '111']
# ['needed', '74089', 'needed', 'N IY1 D AH0 D', '4', '@', '0', '56']
# ['girls', '48964', 'girls', 'G ER1 L Z', '2', '*hr', '1', '528']
# ['did', '453509', 'did', 'D IH1 D', '2', 'i', '1', '1445']
# ['did', '453509', 'did', 'D AH0 D', '2', '@', '0', '415']
# ['know', '688963', 'know', 'N OW1', '2', 'owF', '1', '11828']
# ['much', '401761', 'much', 'M AH1 CH', '2', 'uh', '1', '1117']
# ['anything', '134065', 'anything', 'EH1 N IY0 TH IH2 NG', '1', 'e', '1', '552']
# ['anything', '134065', 'anything', 'EH1 N IY0 TH IH2 NG', '3', 'iy', '0', '768']
# ['anything', '134065', 'anything', 'EH1 N IY0 TH IH2 NG', '5', 'i', '2', '314']
# ['as', '2599971', 'as', 'AE1 Z', '1', 'NA', '1', '683']
# ['as', '2599971', 'as', 'AH0 Z', '1', '@', '0', '495']
# ['one', '1209216', 'one', 'W AH1 N', '2', 'uh', '1', '2510']
# ['cleaned', '4860', 'cleaned', 'K L IY1 N D', '3', 'iy', '1', '21']
# ['bathroom', '14521', 'bathroom', 'B AE1 TH R UW2 M', '2', 'aeh', '1', '103']
# ['bathroom', '14521', 'bathroom', 'B AE1 TH R UW2 M', '5', 'Tuw', '2', '28']
# ['other', '665978', 'other', 'AH1 DH ER0', '1', 'uh', '1', '1752']
# ['other', '665978', 'other', 'AH1 DH ER0', '3', '*hr', '0', '936']
# ['oven', '12733', 'oven', 'AH1 V AH0 N', '1', 'uh', '1', '16']
# ['oven', '12733', 'oven', 'AH1 V AH0 N', '3', '@', '0', '3']
# ['rolled', '13741', 'rolled', 'R OW1 L D', '2', 'ow', '1', '8']
# ['their', '1170430', 'their', 'DH EH1 R', '2', 'e', '1', '995']
# ['eyes', '137912', 'eyes', 'AY1 Z', '1', 'ay', '1', '104']
# ['time', '693937', 'time', 'T AY1 M', '2', 'ay', '1', '2668']
# ['direction', '32780', 'direction', 'D ER0 EH1 K SH AH0 N', '2', '*hr', '0', '10']
# ['direction', '32780', 'direction', 'D ER0 EH1 K SH AH0 N', '3', 'e', '1', '10']
# ['even', '480810', 'even', 'IY1 V AH0 N', '3', '@', '0', '219']
# ['even', '480810', 'even', 'IY1 V AH0 N', '1', 'iy', '1', '1107']
# ['ventured', '1662', 'ventured', 'V EH1 N CH ER0 D', '2', 'e', '1', '1']
# ['ventured', '1662', 'ventured', 'V EH1 N CH ER0 D', '5', '*hr', '0', '1']
# ['say', '402529', 'say', 'S EY1', '2', 'eyF', '1', '2833']
# ['book', '112279', 'book', 'B UH1 K', '2', 'u', '1', '160']
# ['stupid', '13561', 'stupid', 'S T UW1 P AH0 D', '3', 'Tuw', '1', '67']
# ['stupid', '13561', 'stupid', 'S T UW1 P AH0 D', '5', '@', '0', '41']
# ['defended', '4107', 'defended', 'D AH0 F EH1 N D AH0 D', '4', 'e', '1', '1']
# ['defended', '4107', 'defended', 'D AH0 F EH1 N D AH0 D', '7', '@', '0', '1']
# ["it's", '772979', "it's", 'IH1 T S', '1', 'i', '1', '2055']
# ["it's", '772979', "it's", 'AH0 T S', '1', '@', '0', '1776']
# ['helping', '25329', 'helping', 'HH EH1 L P IH0 NG', '5', 'i', '0', '16']
# ['helping', '25329', 'helping', 'HH EH1 L P IH0 NG', '2', 'e', '1', '7']
# ['wish', '30893', 'wish', 'W IH1 SH', '2', 'i', '1', '12']
# ['help', '191892', 'help', 'HH EH1 L P', '2', 'e', '1', '57']
# ['us', '422915', 'us', 'AH1 S', '1', 'uh', '1', '775']
# ['ignored', '11403', 'ignored', 'IH0 G N AO1 R D', '4', 'owr', '1', '6']
# ['ignored', '11403', 'ignored', 'IH0 G N AO1 R D', '1', 'i', '0', '2']
# ['remark', '3545', 'remark', 'R IY0 M AA1 R K', '2', 'iy', '0', '1']
# ['remark', '3545', 'remark', 'R IY0 M AA1 R K', '4', 'ahr', '1', '1']
# ['turned', '108585', 'turned', 'T ER1 N D', '2', '*hr', '1', '158']
# ['page', '42589', 'page', 'P EY1 JH', '2', 'ey', '1', '18']
# ['began', '109730', 'began', 'B IY0 G AE1 N', '2', 'iy', '0', '32']
# ['began', '109730', 'began', 'B IY0 G AE1 N', '4', 'NA', '1', '33']
# ['began', '109730', 'began', 'B IH0 G AE1 N', '2', 'i', '0', '28']
# ['began', '109730', 'began', 'B IH0 G AE1 N', '4', 'NA', '1', '37']
# ['read', '88536', 'read', 'R IY1 D', '2', 'iy', '1', '174']
# ['read', '88536', 'read', 'R EH1 D', '2', 'e', '1', '50']
# ['saving', '10196', 'saving', 'S EY1 V IH0 NG', '2', 'ey', '1', '6']
# ['saving', '10196', 'saving', 'S EY1 V IH0 NG', '4', 'i', '0', '3']
# ['saving', '10196', 'saving', 'S EY1 V AH0 N', '2', 'ey', '1', '1']
# ['winter', '33087', 'winter', 'W IH1 N T ER0', '5', '*hr', '0', '59']
# ['winter', '33087', 'winter', 'W IH1 N T ER0', '2', 'i', '1', '13']
# ['her', '1495860', 'her', 'HH ER1', '2', '*hr', '1', '774']
# ['her', '1495860', 'her', 'HH ER0', '2', '*hr', '0', '2135']
# ['dreams', '16230', 'dreams', 'D R IY1 M Z', '3', 'iy', '1', '33']
# ['continued', '43323', 'continued', 'K AH0 N T IH1 N Y UW0 D', '8', 'uw', '0', '8']
# ['continued', '43323', 'continued', 'K AH0 N T IH1 N Y UW0 D', '5', 'i', '1', '13']
# ['do', '898900', 'do', 'D UW1', '2', 'Tuw', '1', '3784']
# ['choice', '47512', 'choice', 'CH OY1 S', '2', 'oy', '1', '59']
# ['daily', '40288', 'daily', 'D EY1 L IY0', '2', 'ey', '1', '10']
# ['daily', '40288', 'daily', 'D EY1 L IY0', '4', 'iyF', '0', '9']
# ['mirror', '18030', 'mirror', 'M IY1 R ER0', '2', 'iyr', '1', '20']
# ['mirror', '18030', 'mirror', 'M IY1 R ER0', '4', '*hr', '0', '18']
# ['mirror', '18030', 'mirror', 'M IH1 R ER0', '2', 'iyr', '1', '5']
# ['mirror', '18030', 'mirror', 'M IH1 R ER0', '4', '*hr', '0', '6']
# ['beauty', '22289', 'beauty', 'B Y UW1 T IY0', '3', 'uw', '1', '4']
# ['beauty', '22289', 'beauty', 'B Y UW1 T IY0', '5', 'iyF', '0', '3']
# ['hair', '74251', 'hair', 'HH EH1 R', '2', 'e', '1', '139']
# ['deep', '55489', 'deep', 'D IY1 P', '2', 'iy', '1', '29']
# ['black', '167565', 'black', 'B L AE1 K', '3', 'ae', '1', '481']
# ['channels', '7067', 'channels', 'CH AE1 N AH0 L Z', '2', 'NA', '1', '5']
# ['breast', '16628', 'breast', 'B R EH1 S T', '3', 'e', '1', '6']
# ['like', '860341', 'like', 'L AY1 K', '2', 'ay0', '1', '13096']
# ['rare', '20220', 'rare', 'R EH1 R', '2', 'e', '1', '18']
# ['skin', '42942', 'skin', 'S K IH1 N', '3', 'i', '1', '20']
# ['by', '1644480', 'by', 'B AY1', '2', 'ay', '1', '1086']
# ['men', '156241', 'men', 'M EH1 N', '2', 'e', '1', '177']
# ['rank', '8025', 'rank', 'R AE1 NG K', '2', 'ae', '1', '1']
# ['seed', '9910', 'seed', 'S IY1 D', '2', 'iy', '1', '13']
# ['salt', '32427', 'salt', 'S AO1 L T', '2', 'oh', '1', '40']
# ['flood', '8277', 'flood', 'F L AH1 D', '3', 'uh', '1', '4']
# ['pride', '12940', 'pride', 'P R AY1 D', '3', 'ay', '1', '19']
# ['swelled', '1470', 'swelled', 'S W EH1 L D', '3', 'e', '1', '1']
# ['rubber', '7610', 'rubber', 'R AH1 B ER0', '4', '*hr', '0', '33']
# ['rubber', '7610', 'rubber', 'R AH1 B ER0', '2', 'uh', '1', '25']
# ['sea', '40305', 'sea', 'S IY1', '2', 'iyF', '1', '19']
# ['took', '163599', 'took', 'T UH1 K', '2', 'u', '1', '536']
# ['claim', '28233', 'claim', 'K L EY1 M', '3', 'ey', '1', '8']
# ['kin', '2806', 'kin', 'K IH1 N', '2', 'i', '1', '2']
# ["father's", '18694', "father's", 'F AA1 DH ER0 Z', '2', 'ah', '1', '142']
# ["father's", '18694', "father's", 'F AA1 DH ER0 Z', '4', '*hr', '0', '69']
# ['arms', '51586', 'arms', 'AA1 R M Z', '1', 'ahr', '1', '27']
# ['sisters', '12904', 'sisters', 'S IH1 S T ER0 Z', '5', '*hr', '0', '108']
# ['sisters', '12904', 'sisters', 'S IH1 S T ER0 Z', '2', 'i', '1', '73']
# ['drew', '21023', 'drew', 'D R UW1', '3', 'Tuw', '1', '13']
# ['mouths', '3529', 'mouths', 'M AW1 DH Z', '2', 'aw', '1', '3']
# ['core', '19971', 'core', 'K AO1 R', '2', 'owr', '1', '11']
# ['things', '240621', 'things', 'TH IH1 NG Z', '2', 'i', '1', '379']
# ['now', '678761', 'now', 'N AW1', '2', 'aw', '1', '3119']
# ['rage', '7414', 'rage', 'R EY1 JH', '2', 'ey', '1', '1']
# ['fathers', '9386', 'fathers', 'F AA1 DH ER0 Z', '2', 'o', '1', '23']
# ['fathers', '9386', 'fathers', 'F AA1 DH ER0 Z', '4', '*hr', '0', '13']
# ['suffers', '2734', 'suffers', 'S AH1 F ER0 Z', '2', 'uh', '1', '3']
# ['suffers', '2734', 'suffers', 'S AH1 F ER0 Z', '4', '*hr', '0', '2']
# ['sentence', '13228', 'sentence', 'S EH1 N T AH0 N S', '2', 'e', '1', '8']
# ['sentence', '13228', 'sentence', 'S EH1 N T AH0 N S', '5', '@', '0', '2']
# ['across', '127881', 'across', 'AH0 K R AO1 S', '4', 'oh', '1', '211']
# ['across', '127881', 'across', 'AH0 K R AO1 S', '1', '@', '0', '92']
# ['hard', '128906', 'hard', 'HH AA1 R D', '2', 'ahr', '1', '398']
# ['belly', '7813', 'belly', 'B EH1 L IY0', '2', 'e', '1', '8']
# ['belly', '7813', 'belly', 'B EH1 L IY0', '4', 'iyF', '0', '9']
# ['stone', '29484', 'stone', 'S T OW1 N', '3', 'ow', '1', '52']
# ['more', '1023460', 'more', 'M AO1 R', '2', 'owr', '1', '1485']
# ['surely', '14889', 'surely', 'SH UH1 R L IY0', '2', 'uwr', '1', '3']
# ['surely', '14889', 'surely', 'SH UH1 R L IY0', '5', 'iyF', '0', '4']
# ['any', '378425', 'any', 'EH1 N IY0', '3', 'iyF', '0', '836']
# ['any', '378425', 'any', 'EH1 N IY0', '1', 'e', '1', '580']
# ['lover', '6341', 'lover', 'L AH1 V ER0', '2', 'uh', '1', '11']
# ['lover', '6341', 'lover', 'L AH1 V ER0', '4', '*hr', '0', '9']
# ['held', '77946', 'held', 'HH EH1 L D', '2', 'e', '1', '12']
# ['blind', '14398', 'blind', 'B L AY1 N D', '3', 'ay', '1', '17']
# ['fins', '1023', 'fins', 'F IH1 N Z', '2', 'i', '1', '2']
# ['through', '408551', 'through', 'TH R UW1', '3', 'Tuw', '1', '500']
# ['water', '171970', 'water', 'W AO1 T ER0', '2', 'oh', '1', '248']
# ['water', '171970', 'water', 'W AO1 T ER0', '4', '*hr', '0', '265']
# ['cost', '66786', 'cost', 'K AO1 S T', '2', 'oh', '1', '77']
# ['legal', '48069', 'legal', 'L IY1 G AH0 L', '2', 'iy', '1', '8']
# ['legal', '48069', 'legal', 'L IY1 G AH0 L', '4', '@', '0', '1']
# ['element', '12672', 'element', 'EH1 L AH0 M AH0 N T', '1', 'e', '1', '3']
# ['element', '12672', 'element', 'EH1 L AH0 M AH0 N T', '5', '@', '0', '2']
# ['forbidden', '3631', 'forbidden', 'F ER0 R B IH1 D AH0 N', '2', '*hr', '0', '2']
# ['forbidden', '3631', 'forbidden', 'F ER0 R B IH1 D AH0 N', '5', 'i', '1', '1']
# ['liquids', '1026', 'liquids', 'L IH1 K W AH0 D Z', '5', '@', '0', '1']
# ['comes', '90219', 'comes', 'K AH1 M Z', '2', 'uh', '1', '218']
# ['bloody', '8263', 'bloody', 'B L AH1 D IY0', '3', 'uh', '1', '3']
# ['bloody', '8263', 'bloody', 'B L AH1 D IY0', '5', 'iyF', '0', '3']
# ['also', '508752', 'also', 'AO1 L S OW0', '1', 'oh', '1', '237']
# ['also', '508752', 'also', 'AO1 L S OW0', '4', 'owF', '0', '213']
# ['head', '166407', 'head', 'HH EH1 D', '2', 'e', '1', '250']
# ['trophy', '3704', 'trophy', 'T R OW1 F IY0', '3', 'ow', '1', '5']
# ['trophy', '3704', 'trophy', 'T R OW1 F IY0', '5', 'iyF', '0', '4']
# ['fingers', '27115', 'fingers', 'F IH1 NG G ER0 Z', '2', 'i', '1', '9']
# ['fingers', '27115', 'fingers', 'F IH1 NG G ER0 Z', '5', '*hr', '0', '27']
# ['reach', '41396', 'reach', 'R IY1 CH', '2', 'iy', '1', '27']
# ['rescue', '12048', 'rescue', 'R EH1 S K Y UW0', '6', 'uw', '0', '5']
# ['rescue', '12048', 'rescue', 'R EH1 S K Y UW0', '2', 'e', '1', '3']
# ['final', '53879', 'final', 'F AY1 N AH0 L', '2', 'ay', '1', '10']
# ['power', '139064', 'power', 'P AW1 ER0', '2', 'aw', '1', '38']
# ['power', '139064', 'power', 'P AW1 ER0', '3', '*hr', '0', '22']
# ['helpless', '3307', 'helpless', 'HH EH1 L P L AH0 S', '6', '@', '0', '1']
# ['snap', '5594', 'snap', 'S N AE1 P', '3', 'ae', '1', '6']
# ['iron', '15847', 'iron', 'AY1 ER0 N', '1', 'ay', '1', '19']
# ['iron', '15847', 'iron', 'AY1 ER0 N', '2', '*hr', '0', '9']
# ['glad', '16893', 'glad', 'G L AE1 D', '3', 'aeh', '1', '145']
# ['breath', '25803', 'breath', 'B R EH1 TH', '3', 'e', '1', '14']
# ['down', '406684', 'down', 'D AW1 N', '2', 'aw', '1', '2905']
# ['into', '723936', 'into', 'IH2 N T UW1', '1', 'i', '2', '121']
# ['into', '723936', 'into', 'IH2 N T UW1', '4', 'Tuw', '1', '245']
# ['into', '723936', 'into', 'IH2 N T AH0', '4', '@', '0', '223']
# ['into', '723936', 'into', 'IH1 N T UW0', '1', 'i', '1', '65']
# ['into', '723936', 'into', 'IH1 N T UW0', '4', 'Tuw', '0', '55']
# ['into', '723936', 'into', 'IH2 N T AH0', '1', 'i', '2', '289']
# ['silver', '21460', 'silver', 'S IH1 L V ER0', '5', '*hr', '0', '16']
# ['silver', '21460', 'silver', 'S IH1 L V ER0', '2', 'i', '1', '4']
# ['jaw', '5281', 'jaw', 'JH AO1', '2', 'oh', '1', '12']
# ['can', '949767', 'can', 'K AE1 N', '2', 'NA', '1', '360']
# ['can', '949767', 'can', 'K AH0 N', '2', '@', '0', '224']
# ['be', '2004995', 'be', 'B IY0', '2', 'iyF', '0', '2818']
# ['be', '2004995', 'be', 'B IY1', '2', 'iyF', '1', '1142']
# ['no', '799654', 'no', 'N OW1', '2', 'owF', '1', '5016']
# ['safe', '36892', 'safe', 'S EY1 F', '2', 'ey', '1', '103']
# ['harbor', '9785', 'harbor', 'HH AA1 R B ER0', '2', 'ahr', '1', '2']
# ['harbor', '9785', 'harbor', 'HH AA1 R B ER0', '5', '*hr', '0', '2']
# ['sunshine', '3783', 'sunshine', 'S AH1 N SH AY2 N', '2', 'uh', '1', '1']
# ['sunshine', '3783', 'sunshine', 'S AH1 N SH AY2 N', '5', 'ay', '2', '1']
# ['promises', '9615', 'promises', 'P R AA1 M AH0 S AH0 Z', '3', 'o', '1', '4']
# ['promises', '9615', 'promises', 'P R AA1 M AH0 S AH0 Z', '5', '@', '0', '1']
# ["don't", '536831', "don't", 'D OW1 N', '2', 'ow', '1', '4519']
# ["don't", '536831', "don't", 'D OW1 N T', '2', 'ow', '1', '782']
# ['always', '195689', 'always', 'AO1 L W EY2 Z', '1', 'oh', '1', '139']
# ['always', '195689', 'always', 'AO1 L W EY2 Z', '4', 'ey', '2', '160']
# ['always', '195689', 'always', 'AO1 L W IY0 Z', '4', 'iy', '0', '670']
# ['always', '195689', 'always', 'AO1 L W IY0 Z', '1', 'oh', '1', '711']
# ['last', '338606', 'last', 'L AE1 S T', '2', 'aeh', '1', '104']
# ['last', '338606', 'last', 'L AE1 S', '2', 'aeh', '1', '523']
# ['look', '273376', 'look', 'L UH1 K', '2', 'u', '1', '424']
# ['window', '49429', 'window', 'W IH1 N D OW0', '5', 'owF', '0', '99']
# ['window', '49429', 'window', 'W IH1 N D OW0', '2', 'i', '1', '34']
# ['lie', '23362', 'lie', 'L AY1', '2', 'ay', '1', '22']
# ['seeing', '41919', 'seeing', 'S IY1 IH0 NG', '2', 'iy', '1', '57']
# ['seeing', '41919', 'seeing', 'S IY1 IH0 NG', '3', 'i', '0', '9']
# ['miles', '61813', 'miles', 'M AY1 L Z', '2', 'ay', '1', '54']
# ['miles', '61813', 'miles', 'M AY1 AH0 L Z', '2', 'ay', '1', '3']
# ['cities', '29119', 'cities', 'S IH1 T IY0 Z', '2', 'i', '1', '20']
# ['cities', '29119', 'cities', 'S IH1 T IY0 Z', '4', 'iy', '0', '22']
# ['electric', '17374', 'electric', 'AH0 L EH1 K T R IH0 K', '3', 'e', '1', '19']
# ['electric', '17374', 'electric', 'AH0 L EH1 K T R IH0 K', '7', 'i', '0', '9']
# ['electric', '17374', 'electric', 'AH0 L EH1 K T R IH0 K', '1', '@', '0', '7']
# ['stare', '7421', 'stare', 'S T EH1 R', '3', 'e', '1', '2']
# ['sky', '33309', 'sky', 'S K AY1', '3', 'ay', '1', '15']
# ['hold', '67164', 'hold', 'HH OW1 L D', '2', 'ow', '1', '119']
# ['myself', '65033', 'myself', 'M AY2 S EH1 L F', '2', 'ay0', '2', '312']
# ['myself', '65033', 'myself', 'M AY2 S EH1 L F', '4', 'e', '1', '189']
# ['cloud', '10222', 'cloud', 'K L AW1 D', '3', 'aw', '1', '3']
# ['who', '1058483', 'who', 'HH UW1', '2', 'uw', '1', '1024']
# ['sings', '3537', 'sings', 'S IH1 NG Z', '2', 'i', '1', '1']
# ['rain', '25783', 'rain', 'R EY1 N', '2', 'ey', '1', '27']
# ['pulse', '5520', 'pulse', 'P AH1 L S', '2', 'uh', '1', '1']
# ['playing', '55429', 'playing', 'P L EY1 IH0 NG', '3', 'ey', '1', '195']
# ['playing', '55429', 'playing', 'P L EY1 IH0 NG', '4', 'i', '0', '16']
# ['drops', '10357', 'drops', 'D R AA1 P S', '3', 'o', '1', '3']
# ['roof', '15350', 'roof', 'R UW1 F', '2', 'Tuw', '1', '47']
# ['top', '121765', 'top', 'T AA1 P', '2', 'o', '1', '224']
# ['porch', '10818', 'porch', 'P AO1 R CH', '2', 'owr', '1', '69']
# ['stretch', '13129', 'stretch', 'S T R EH1 CH', '4', 'e', '1', '11']
# ['far', '147926', 'far', 'F AA1 R', '2', 'ahr', '1', '447']
# ['trace', '8301', 'trace', 'T R EY1 S', '3', 'ey', '1', '4']
# ['yellow', '25596', 'yellow', 'Y EH1 L OW0', '4', 'owF', '0', '33']
# ['yellow', '25596', 'yellow', 'Y EH1 L OW0', '2', 'e', '1', '25']
# ['lines', '43582', 'lines', 'L AY1 N Z', '2', 'ay', '1', '23']
# ['mind', '92520', 'mind', 'M AY1 N D', '2', 'ay', '1', '217']
# ['tears', '18529', 'tears', 'T IH1 R Z', '2', 'iyr', '1', '2']
# ['tears', '18529', 'tears', 'T IY1 R Z', '2', 'iyr', '1', '1']
# ['tears', '18529', 'tears', 'T EH1 R Z', '2', 'e', '1', '8']
# ['swim', '7029', 'swim', 'S W IH1 M', '3', 'i', '1', '12']
# ['between', '290141', 'between', 'B IY0 T W IY1 N', '5', 'iy', '1', '103']
# ['between', '290141', 'between', 'B IY0 T W IY1 N', '2', 'iy', '0', '118']
# ['between', '290141', 'between', 'B AH0 T W IY1 N', '2', '@', '0', '23']
# ['between', '290141', 'between', 'B AH0 T W IY1 N', '5', 'iy', '1', '70']
# ['words', '93184', 'words', 'W ER1 D Z', '2', '*hr', '1', '172']
# ['glass', '43247', 'glass', 'G L AE1 S', '3', 'aeh', '1', '58']
# ['shade', '7977', 'shade', 'SH EY1 D', '2', 'ey', '1', '5']
# ['pick', '40356', 'pick', 'P IH1 K', '2', 'i', '1', '136']
# ['flowers', '19435', 'flowers', 'F L AW1 ER0 Z', '3', 'aw', '1', '33']
# ['flowers', '19435', 'flowers', 'F L AW1 ER0 Z', '4', '*hr', '0', '30']
# ['too', '304103', 'too', 'T UW1', '2', 'Tuw', '1', '1515']
# ['long', '261909', 'long', 'L AO1 NG', '2', 'oh', '1', '483']
# ['wound', '10354', 'wound', 'W AW1 N D', '2', 'aw', '1', '27']
# ['around', '289378', 'around', 'ER0 AW1 N', '1', '*hr', '0', '1621']
# ['around', '289378', 'around', 'ER0 AW1 N', '2', 'aw', '1', '1713']
# ['around', '289378', 'around', 'ER0 AW1 N D', '1', '*hr', '0', '333']
# ['around', '289378', 'around', 'ER0 AW1 N D', '2', 'aw', '1', '339']
# ['neck', '26584', 'neck', 'N EH1 K', '2', 'e', '1', '48']
# ['weighs', '2802', 'weighs', 'W EY1 Z', '2', 'ey', '1', '1']
# ['less', '157768', 'less', 'L EH1 S', '2', 'e', '1', '119']
# ['ounce', '2382', 'ounce', 'AW1 N S', '1', 'aw', '1', '4']
# ['all', '1160223', 'all', 'AO1 L', '1', 'oh', '1', '5164']
# ['earth', '47435', 'earth', 'ER1 TH', '1', '*hr', '1', '39']
# ['daughter', '49451', 'daughter', 'D AO1 T ER0', '2', 'oh', '1', '322']
# ['daughter', '49451', 'daughter', 'D AO1 T ER0', '4', '*hr', '0', '266']
# ['grown', '22850', 'grown', 'G R OW1 N', '3', 'ow', '1', '28']
# ['lifetime', '11429', 'lifetime', 'L AY1 F T AY2 M', '2', 'ay0', '1', '9']
# ['lifetime', '11429', 'lifetime', 'L AY1 F T AY2 M', '5', 'ay', '2', '9']
# ['brush', '11704', 'brush', 'B R AH1 SH', '3', 'uh', '1', '10']
# ['sand', '15965', 'sand', 'S AE1 N D', '2', 'aeh', '1', '16']
# ['ash', '4595', 'ash', 'AE1 SH', '1', 'ae', '1', '11']
# ['blonde', '3800', 'blonde', 'B L AA1 N D', '3', 'o', '1', '7']
# ['thumb', '6617', 'thumb', 'TH AH1 M', '2', 'uh', '1', '11']
# ['first', '522098', 'first', 'F ER1 S T', '2', '*hr', '1', '1191']
# ['finger', '17244', 'finger', 'F IH1 NG G ER0', '2', 'i', '1', '8']
# ['finger', '17244', 'finger', 'F IH1 NG G ER0', '5', '*hr', '0', '13']
# ['crosses', '4298', 'crosses', 'K R AO1 S AH0 Z', '3', 'oh', '1', '2']
# ['hand', '151687', 'hand', 'HH AE1 N D', '2', 'aeh', '1', '214']
# ['thin', '24007', 'thin', 'TH IH1 N', '2', 'i', '1', '20']
# ['trail', '22034', 'trail', 'T R EY1 L', '3', 'ey', '1', '6']
# ['six', '98487', 'six', 'S IH1 K S', '2', 'i', '1', '352']
# ['summers', '3897', 'summers', 'S AH1 M ER0 Z', '2', 'uh', '1', '12']
# ['summers', '3897', 'summers', 'S AH1 M ER0 Z', '4', '*hr', '0', '10']
# ['girl', '65867', 'girl', 'G ER1 L', '2', '*hr', '1', '601']
# ['hope', '76503', 'hope', 'HH OW1 P', '2', 'ow', '1', '76']
# ['pull', '29457', 'pull', 'P UH1 L', '2', 'u', '1', '20']
# ['slowly', '35328', 'slowly', 'S L OW1 L IY0', '3', 'ow', '1', '24']
# ['slowly', '35328', 'slowly', 'S L OW1 L IY0', '5', 'iyF', '0', '23']
# ['harsh', '7531', 'harsh', 'HH AA1 R SH', '2', 'ahr', '1', '4']
# ['braid', '1080', 'braid', 'B R EY1 D', '3', 'ey', '1', '1']
# ['morning', '121557', 'morning', 'M AO1 R N IH0 NG', '2', 'owr', '1', '264']
# ['morning', '121557', 'morning', 'M AO1 R N IH0 NG', '5', 'i', '0', '69']
# ['bottom', '39328', 'bottom', 'B AA1 T AH0 M', '2', 'o', '1', '66']
# ['bottom', '39328', 'bottom', 'B AA1 T AH0 M', '4', '@', '0', '12']
# ['dark', '64242', 'dark', 'D AA1 R K', '2', 'ahr', '1', '94']
# ['back', '537367', 'back', 'B AE1 K', '2', 'ae', '1', '2149']
# ['rosewood', '380', 'rosewood', 'R OW1 Z W UH2 D', '2', 'ow', '1', '5']
# ['rosewood', '380', 'rosewood', 'R OW1 Z W UH2 D', '5', 'u', '2', '2']
# ['will', '864121', 'will', 'W IH1 L', '2', 'i', '1', '14']
# ['will', '864121', 'will', 'W AH0 L', '2', '@', '0', '59']
# ['mature', '6725', 'mature', 'M AH0 CH UH1 R', '4', 'uwr', '1', '3']
# ['mature', '6725', 'mature', 'M AH0 CH UH1 R', '2', '@', '0', '2']
# ['catch', '28532', 'catch', 'K AE1 CH', '2', 'NA', '1', '146']
# ['crescent', '1962', 'crescent', 'K R EH1 S AH0 N T', '3', 'e', '1', '2']
# ['twist', '6526', 'twist', 'T W IH1 S T', '3', 'i', '1', '7']
# ['tightly', '7230', 'tightly', 'T AY1 T L IY0', '2', 'ay0', '1', '2']
# ['behind', '122782', 'behind', 'B AH0 HH AY1 N D', '4', 'ay', '1', '131']
# ['behind', '122782', 'behind', 'B AH0 HH AY1 N D', '2', '@', '0', '38']
# ['ear', '16819', 'ear', 'IY1 R', '1', 'iyr', '1', '29']
# ['ear', '16819', 'ear', 'IH1 R', '1', 'iyr', '1', '6']
# ['see', '456625', 'see', 'S IY1', '2', 'iyF', '1', '2466']
# ['woman', '142845', 'woman', 'W UH1 M AH0 N', '2', 'u', '1', '26']
# ['woman', '142845', 'woman', 'W UH1 M AH0 N', '4', '@', '0', '30']
# ['appear', '34901', 'appear', 'AH0 P IY1 R', '3', 'iyr', '1', '7']
# ['appear', '34901', 'appear', 'AH0 P IY1 R', '1', '@', '0', '2']
# ['appear', '34901', 'appear', 'AH0 P IH1 R', '3', 'iyr', '1', '1']
# ['let', '165765', 'let', 'L EH1 T', '2', 'e', '1', '374']
# ['side', '135733', 'side', 'S AY1 D', '2', 'ay', '1', '526']
# ["mermaid's", '35', "mermaid's", 'M ER1 M EY2 D Z', '2', '*hr', '1', '1']
# ["mermaid's", '35', "mermaid's", 'M ER1 M EY2 D Z', '4', 'ey', '2', '1']
# ['fall', '63522', 'fall', 'F AO1 L', '2', 'oh', '1', '59']
# ['fall', '63522', 'fall', 'F AA1 L', '2', 'o', '1', '10']
# ['show', '163252', 'show', 'SH OW1', '2', 'owF', '1', '172']
# ['bending', '2761', 'bending', 'B EH1 N D IH0 NG', '2', 'e', '1', '3']
# ['forward', '57189', 'forward', 'F AO1 R W ER0 D', '2', 'owr', '1', '41']
# ['forward', '57189', 'forward', 'F AO1 R W ER0 D', '5', '*hr', '0', '32']
# ['adding', '17966', 'adding', 'AE1 D IH0 NG', '1', 'ae', '1', '2']
# ['adding', '17966', 'adding', 'AE1 D AH0 N', '1', 'ae', '1', '1']
# ['make', '389672', 'make', 'M EY1 K', '2', 'ey', '1', '1028']
# ['moves', '22610', 'moves', 'M UW1 V Z', '2', 'uw', '1', '13']
# ['pressure', '47423', 'pressure', 'P R EH1 SH ER0', '3', 'e', '1', '18']
# ['pressure', '47423', 'pressure', 'P R EH1 SH ER0', '5', '*hr', '0', '25']
# ['love', '143532', 'love', 'L AH1 V', '2', 'uh', '1', '363']
# ['before', '366010', 'before', 'B IY2 F AO1 R', '2', 'iy', '2', '424']
# ['before', '366010', 'before', 'B IY2 F AO1 R', '4', 'owr', '1', '431']
# ['before', '366010', 'before', 'B AH0 F AO1 R', '2', '@', '0', '123']
# ['before', '366010', 'before', 'B AH0 F AO1 R', '4', 'owr', '1', '344']
# ['bed', '57148', 'bed', 'B EH1 D', '2', 'e', '1', '212']
# ['hundred', '37031', 'hundred', 'HH AH1 N ER0 D', '4', '*hr', '0', '139']
# ['hundred', '37031', 'hundred', 'HH AH1 N D R AH0 D', '2', 'uh', '1', '32']
# ['hundred', '37031', 'hundred', 'HH AH1 N D ER0 D', '2', 'uh', '1', '133']
# ['hundred', '37031', 'hundred', 'HH AH1 N D ER0 D', '5', '*hr', '0', '137']
# ['hundred', '37031', 'hundred', 'HH AH1 N ER0 D', '2', 'uh', '1', '125']
# ['strokes', '4150', 'strokes', 'S T R OW1 K S', '4', 'ow', '1', '3']
# ['two', '553044', 'two', 'T UW1', '2', 'Tuw', '1', '2328']
# ['hands', '94666', 'hands', 'HH AE1 N Z', '2', 'aeh', '1', '85']
# ['hands', '94666', 'hands', 'HH AE1 N D Z', '2', 'aeh', '1', '23']
# ['dry', '30054', 'dry', 'D R AY1', '3', 'ay', '1', '26']
# ['heat', '49490', 'heat', 'HH IY1 T', '2', 'iy', '1', '39']
# ['summer', '63962', 'summer', 'S AH1 M ER0', '2', 'uh', '1', '265']
# ['summer', '63962', 'summer', 'S AH1 M ER0', '4', '*hr', '0', '203']
# ['been', '852399', 'been', 'B IH1 N', '2', 'i', '1', '473']
# ['been', '852399', 'been', 'B AH0 N', '2', '@', '0', '403']
# ['cool', '34622', 'cool', 'K UW1 L', '2', 'uw', '1', '67']
# ['breaking', '16291', 'breaking', 'B R EY1 K IH0 NG', '3', 'ey', '1', '22']
# ['breaking', '16291', 'breaking', 'B R EY1 K AH0 N', '3', 'ey', '1', '3']
# ['breaking', '16291', 'breaking', 'B R EY1 K IH0 NG', '5', 'i', '0', '4']
# ['thick', '22572', 'thick', 'TH IH1 K', '2', 'i', '1', '12']
# ['tender', '8424', 'tender', 'T EH1 N D ER0', '2', 'e', '1', '6']
# ['tender', '8424', 'tender', 'T EH1 N D ER0', '5', '*hr', '0', '5']
# ['mount', '12913', 'mount', 'M AW1 N T', '2', 'aw', '1', '55']
# ['mud', '8527', 'mud', 'M AH1 D', '2', 'uh', '1', '12']
# ['pink', '16293', 'pink', 'P IH1 NG K', '2', 'i', '1', '9']
# ['magenta', '518', 'magenta', 'M AH0 JH EH1 N T AH0', '4', 'e', '1', '3']
# ['magenta', '518', 'magenta', 'M AH0 JH EH1 N T AH0', '7', '@', '0', '2']
# ['travels', '4852', 'travels', 'T R AE1 V AH0 L Z', '3', 'ae', '1', '3']
# ['geographic', '4971', 'geographic', 'JH IY2 AH0 G R AE1 F IH0 K', '2', 'iy', '2', '1']
# ['geographic', '4971', 'geographic', 'JH IY2 AH0 G R AE1 F IH0 K', '6', 'NA', '1', '1']
# ['geographic', '4971', 'geographic', 'JH IY2 AH0 G R AE1 F IH0 K', '8', 'i', '0', '1']
# ['broad', '20270', 'broad', 'B R AO1 D', '3', 'oh', '1', '129']
# ['leaves', '34974', 'leaves', 'L IY1 V Z', '2', 'iy', '1', '34']
# ['garden', '32740', 'garden', 'G AA1 R D AH0 N', '2', 'ahr', '1', '31']
# ['garden', '32740', 'garden', 'G AA1 R D AH0 N', '5', '@', '0', '2']
# ['breeds', '1460', 'breeds', 'B R IY1 D Z', '3', 'iy', '1', '1']
# ['squash', '3617', 'squash', 'S K W AA1 SH', '4', 'o', '1', '4']
# ['bright', '27631', 'bright', 'B R AY1 T', '3', 'ay0', '1', '17']
# ['tomatoes', '10046', 'tomatoes', 'T AH0 M EY1 T OW0 Z', '4', 'ey', '1', '37']
# ['tomatoes', '10046', 'tomatoes', 'T AH0 M EY1 T OW0 Z', '6', 'ow', '0', '16']
# ['swollen', '2995', 'swollen', 'S W OW1 L AH0 N', '5', '@', '0', '3']
# ['swollen', '2995', 'swollen', 'S W OW1 L AH0 N', '3', 'ow', '1', '3']
# ['till', '11450', 'till', 'T IH1 L', '2', 'i', '1', '22']
# ['white', '196720', 'white', 'W AY1 T', '2', 'ay0', '1', '418']
# ['white', '196720', 'white', 'HH W AY1 T', '3', 'ay0', '1', '51']
# ['burst', '9280', 'burst', 'B ER1 S T', '2', '*hr', '1', '3']
# ['touch', '32659', 'touch', 'T AH1 CH', '2', 'uh', '1', '115']
# ['clouds', '11284', 'clouds', 'K L AW1 D Z', '3', 'aw', '1', '3']
# ['spin', '7832', 'spin', 'S P IH1 N', '3', 'i', '1', '15']
# ['above', '77032', 'above', 'AH0 B AH1 V', '3', 'uh', '1', '47']
# ['above', '77032', 'above', 'AH0 B AH1 V', '1', '@', '0', '15']
# ['grass', '17410', 'grass', 'G R AE1 S', '3', 'aeh', '1', '30']
# ['swarming', '795', 'swarming', 'S W AO1 R M IH0 NG', '3', 'owr', '1', '1']
# ['climate', '20087', 'climate', 'K L AY1 M AH0 T', '3', 'ay', '1', '2']
# ['climate', '20087', 'climate', 'K L AY1 M AH0 T', '5', '@', '0', '1']
# ['prevent', '26391', 'prevent', 'P R IY0 V EH1 N T', '3', 'iy', '0', '1']
# ['prevent', '26391', 'prevent', 'P R IY0 V EH1 N T', '5', 'e', '1', '2']
# ['prevent', '26391', 'prevent', 'P R IH0 V EH1 N T', '5', 'e', '1', '5']
# ['pinch', '3238', 'pinch', 'P IH1 N CH', '2', 'i', '1', '2']
# ['infection', '9626', 'infection', 'IH2 N F EH1 K SH AH0 N', '4', 'e', '1', '5']
# ['infection', '9626', 'infection', 'IH2 N F EH1 K SH AH0 N', '1', 'i', '2', '1']
# ['greasy', '1773', 'greasy', 'G R IY1 S IY0', '3', 'iy', '1', '2']
# ['greasy', '1773', 'greasy', 'G R IY1 S IY0', '5', 'iyF', '0', '1']
# ['bare', '10018', 'bare', 'B EH1 R', '2', 'e', '1', '8']
# ['feet', '86947', 'feet', 'F IY1 T', '2', 'iy', '1', '101']
# ['brilliant', '10430', 'brilliant', 'B R IH1 L Y AH0 N T', '3', 'i', '1', '1']
# ['chronic', '9192', 'chronic', 'K R AA1 N IH0 K', '3', 'o', '1', '6']
# ['chronic', '9192', 'chronic', 'K R AA1 N IH0 K', '5', 'i', '0', '6']
# ['growth', '54671', 'growth', 'G R OW1 TH', '3', 'ow', '1', '1']
# ['burnt', '2064', 'burnt', 'B ER1 N T', '2', '*hr', '1', '16']
# ['ground', '74909', 'ground', 'G R AW1 N D', '3', 'aw', '1', '106']
# ['never', '284072', 'never', 'N EH1 V ER0', '4', '*hr', '0', '1403']
# ['never', '284072', 'never', 'N EH1 V ER0', '2', 'e', '1', '1549']
# ['under', '200019', 'under', 'AH1 N D ER0', '1', 'uh', '1', '180']
# ['under', '200019', 'under', 'AH1 N D ER0', '4', '*hr', '0', '122']
# ['dense', '5513', 'dense', 'D EH1 N S', '2', 'e', '1', '4']
# ['contracted', '2489', 'contracted', 'K AA1 N T R AE0 K T AH0 D', '6', 'NA', '0', '1']
# ['contracted', '2489', 'contracted', 'K AA1 N T R AE0 K T AH0 D', '9', '@', '0', '1']
# ['oak', '9677', 'oak', 'OW1 K', '1', 'ow', '1', '1']
# ['scraping', '1875', 'scraping', 'S K R EY1 P IH0 NG', '4', 'ey', '1', '1']
# ['scraping', '1875', 'scraping', 'S K R EY1 P IH0 NG', '6', 'i', '0', '1']
# ['hollow', '4742', 'hollow', 'HH AA1 L OW0', '2', 'o', '1', '6']
# ['hollow', '4742', 'hollow', 'HH AA1 L OW0', '4', 'owF', '0', '6']
# ['brief', '18534', 'brief', 'B R IY1 F', '3', 'iy', '1', '4']
# ['roots', '13687', 'roots', 'R UW1 T S', '2', 'Tuw', '1', '17']
# ['green', '67759', 'green', 'G R IY1 N', '3', 'iy', '1', '50']
# ['left', '193076', 'left', 'L EH1 F T', '2', 'e', '1', '386']
# ['dusty', '5089', 'dusty', 'D AH1 S T IY0', '2', 'uh', '1', '5']
# ['dusty', '5089', 'dusty', 'D AH1 S T IY0', '5', 'iyF', '0', '5']
# ['soil', '20409', 'soil', 'S OY1 L', '2', 'oy', '1', '3']
# ['set', '150620', 'set', 'S EH1 T', '2', 'e', '1', '133']
# ['cracks', '4179', 'cracks', 'K R AE1 K S', '3', 'ae', '1', '6']
# ['dim', '4801', 'dim', 'D IH1 M', '2', 'i', '1', '2']
# ['plants', '34846', 'plants', 'P L AE1 N T S', '3', 'aeh', '1', '20']
# ['nothing', '135310', 'nothing', 'N AH1 TH IH0 NG', '2', 'uh', '1', '640']
# ['nothing', '135310', 'nothing', 'N AH1 TH IH0 NG', '4', 'i', '0', '143']
# ['or', '1490463', 'or', 'ER0', '1', '*hr', '0', '2802']
# ['or', '1490463', 'or', 'AO1 R', '1', 'owr', '1', '1043']
# ['insect', '3323', 'insect', 'IH1 N S EH2 K T', '1', 'i', '1', '1']
# ['insect', '3323', 'insect', 'IH1 N S EH2 K T', '4', 'e', '2', '1']
# ['bloom', '4942', 'bloom', 'B L UW1 M', '3', 'Tuw', '1', '4']
# ['opening', '31297', 'opening', 'OW1 P AH0 N IH0 NG', '1', 'ow', '1', '16']
# ['opening', '31297', 'opening', 'OW1 P AH0 N AH0 N', '1', 'ow', '1', '2']
# ['opening', '31297', 'opening', 'OW1 P AH0 N IH0 NG', '3', '@', '0', '3']
# ['afternoons', '2155', 'afternoons', 'AE2 F T ER0 N UW1 N Z', '1', 'NA', '2', '1']
# ['afternoons', '2155', 'afternoons', 'AE2 F T ER0 N UW1 N Z', '6', 'Tuw', '1', '2']
# ['flat', '21376', 'flat', 'F L AE1 T', '3', 'ae', '1', '24']
# ['hanging', '16655', 'hanging', 'HH AE1 NG IH0 NG', '2', 'ae', '1', '20']
# ['hanging', '16655', 'hanging', 'HH AE1 NG G IH0 NG', '2', 'ae', '1', '24']
# ['hanging', '16655', 'hanging', 'HH AE1 NG IH0 NG', '4', 'i', '0', '9']
# ['hanging', '16655', 'hanging', 'HH AE1 NG G IH0 NG', '5', 'i', '0', '4']
# ['air', '113528', 'air', 'EH1 R', '1', 'e', '1', '129']
# ['tense', '4936', 'tense', 'T EH1 N S', '2', 'e', '1', '5']
# ['heated', '5292', 'heated', 'HH IY1 T AH0 D', '2', 'iy', '1', '5']
# ['heated', '5292', 'heated', 'HH IY1 T AH0 D', '4', '@', '0', '4']
# ['thirst', '1537', 'thirst', 'TH ER1 S T', '2', '*hr', '1', '1']
# ['plain', '13275', 'plain', 'P L EY1 N', '3', 'ey', '1', '26']
# ['steadily', '5451', 'steadily', 'S T EH1 D AH0 L IY0', '3', 'e', '1', '2']
# ['steadily', '5451', 'steadily', 'S T EH1 D AH0 L IY0', '7', 'iyF', '0', '2']
# ['drain', '7545', 'drain', 'D R EY1 N', '3', 'ey', '1', '8']
# ['stored', '6096', 'stored', 'S T AO1 R D', '3', 'owr', '1', '5']
# ['still', '338468', 'still', 'S T IH1 L', '3', 'i', '1', '239']
# ['simple', '50185', 'simple', 'S IH1 M P AH0 L', '2', 'i', '1', '11']
# ['heart', '82004', 'heart', 'HH AA1 R T', '2', 'ahr', '1', '163']
# ['plant', '37238', 'plant', 'P L AE1 N T', '3', 'aeh', '1', '32']
# ['deaf', '3113', 'deaf', 'D EH1 F', '2', 'e', '1', '7']
# ['immediate', '16848', 'immediate', 'IH2 M IY1 D IY0 AH0 T', '3', 'iy', '1', '18']
# ['immediate', '16848', 'immediate', 'IH2 M IY1 D IY0 AH0 T', '5', 'iy', '0', '20']
# ['immediate', '16848', 'immediate', 'IH2 M IY1 D IY0 AH0 T', '1', 'i', '2', '6']
# ['worlds', '8198', 'worlds', 'W ER1 L D Z', '2', '*hr', '1', '3']
# ['divide', '7726', 'divide', 'D IH0 V AY1 D', '2', 'i', '0', '1']
# ['divide', '7726', 'divide', 'D IH0 V AY1 D', '4', 'ay', '1', '2']
# ['separate', '27590', 'separate', 'S EH1 P ER0 AH0 T', '4', '*hr', '0', '7']
# ['separate', '27590', 'separate', 'S EH1 P ER0 EY2 T', '2', 'e', '1', '10']
# ['separate', '27590', 'separate', 'S EH1 P ER0 EY2 T', '4', '*hr', '0', '11']
# ['separate', '27590', 'separate', 'S EH1 P ER0 EY2 T', '5', 'ey', '2', '10']
# ['separate', '27590', 'separate', 'S EH1 P ER0 AH0 T', '2', 'e', '1', '10']
# ['separate', '27590', 'separate', 'S EH1 P R AH0 T', '2', 'e', '1', '16']
# ['separate', '27590', 'separate', 'S EH1 P R AH0 T', '5', '@', '0', '4']
# ['walking', '35406', 'walking', 'W AO1 K IH0 NG', '2', 'oh', '1', '175']
# ['walking', '35406', 'walking', 'W AO1 K IH0 NG', '4', 'i', '0', '47']
# ['hear', '89968', 'hear', 'HH IY1 R', '2', 'iyr', '1', '238']
# ['hear', '89968', 'hear', 'HH IH1 R', '2', 'iyr', '1', '57']
# ['parting', '1437', 'parting', 'P AA1 R T IH0 NG', '2', 'ahr', '1', '1']
# ['some', '728176', 'some', 'S AH1 M', '2', 'uh', '1', '1135']
# ['distant', '13352', 'distant', 'D IH1 S T AH0 N T', '2', 'i', '1', '5']
# ['lovely', '9904', 'lovely', 'L AH1 V L IY0', '2', 'uh', '1', '23']
# ['lovely', '9904', 'lovely', 'L AH1 V L IY0', '5', 'iyF', '0', '25']
# ['ocean', '18433', 'ocean', 'OW1 SH AH0 N', '1', 'ow', '1', '23']
# ['ocean', '18433', 'ocean', 'OW1 SH AH0 N', '3', '@', '0', '4']
# ['fine', '54120', 'fine', 'F AY1 N', '2', 'ay', '1', '205']
# ['shell', '10314', 'shell', 'SH EH1 L', '2', 'e', '1', '4']
# ['found', '201703', 'found', 'F AW1 N D', '2', 'aw', '1', '260']
# ['nearly', '71617', 'nearly', 'N IY1 R L IY0', '2', 'iyr', '1', '7']
# ['nearly', '71617', 'nearly', 'N IY1 R L IY0', '5', 'iyF', '0', '6']
# ['nearly', '71617', 'nearly', 'N IH1 R L IY0', '2', 'iyr', '1', '1']
# ['nearly', '71617', 'nearly', 'N IH1 R L IY0', '5', 'iyF', '0', '1']
# ['sinking', '3340', 'sinking', 'S IH1 NG K IH0 NG', '2', 'i', '1', '3']
# ['sinking', '3340', 'sinking', 'S IH1 NG K IH0 NG', '5', 'i', '0', '5']
# ['hearing', '32919', 'hearing', 'HH IH1 R IH0 NG', '2', 'iyr', '1', '20']
# ['hearing', '32919', 'hearing', 'HH IY1 R IH0 NG', '2', 'iyr', '1', '8']
# ['hearing', '32919', 'hearing', 'HH IH1 R IH0 NG', '4', 'i', '0', '8']
# ['hearing', '32919', 'hearing', 'HH IH1 R AH0 N', '2', 'iyr', '1', '2']
# ['brushes', '2437', 'brushes', 'B R AH1 SH AH0 Z', '3', 'uh', '1', '3']
# ['brushes', '2437', 'brushes', 'B R AH1 SH AH0 Z', '5', '@', '0', '3']
# ['face', '151053', 'face', 'F EY1 S', '2', 'ey', '1', '167']
# ['telling', '38282', 'telling', 'T EH1 L IH0 NG', '2', 'e', '1', '97']
# ['telling', '38282', 'telling', 'T EH1 L IH0 NG', '4', 'i', '0', '15']
# ['loves', '12688', 'loves', 'L AH1 V Z', '2', 'uh', '1', '49']
# ['mute', '1618', 'mute', 'M Y UW1 T', '3', 'uw', '1', '4']
# ['form', '75752', 'form', 'F AO1 R M', '2', 'owr', '1', '26']
# ['filled', '31496', 'filled', 'F IH1 L D', '2', 'i', '1', '1']
# ['bowl', '31761', 'bowl', 'B OW1 L', '2', 'ow', '1', '41']
# ['wet', '16886', 'wet', 'W EH1 T', '2', 'e', '1', '18']
# ['ran', '43327', 'ran', 'R AE1 N', '2', 'NA', '1', '239']
# ['over', '555491', 'over', 'OW1 V ER0', '1', 'ow', '1', '1740']
# ['over', '555491', 'over', 'OW1 V ER0', '3', '*hr', '0', '1215']
# ['surface', '36884', 'surface', 'S ER1 F AH0 S', '2', '*hr', '1', '4']
# ['surface', '36884', 'surface', 'S ER1 F AH0 S', '4', '@', '0', '4']
# ['cold', '55333', 'cold', 'K OW1 L D', '2', 'ow', '1', '92']
# ['clay', '10157', 'clay', 'K L EY1', '3', 'eyF', '1', '2']
# ['pushing', '15566', 'pushing', 'P UH1 SH IH0 NG', '2', 'u', '1', '18']
# ['wondering', '14039', 'wondering', 'W AH1 N D ER0 IH0 NG', '5', '*hr', '0', '10']
# ['wondering', '14039', 'wondering', 'W AH1 N D ER0 IH0 NG', '2', 'uh', '1', '4']
# ['wondering', '14039', 'wondering', 'W AH1 N D ER0 IH0 NG', '6', 'i', '0', '3']
# ['wondering', '14039', 'wondering', 'W AH1 N D ER0 AH0 N', '2', 'uh', '1', '3']
# ['shape', '29727', 'shape', 'SH EY1 P', '2', 'ey', '1', '28']
# ['take', '316501', 'take', 'T EY1 K', '2', 'ey', '1', '1264']
# ['thought', '196108', 'thought', 'TH AO1 T', '2', 'oh', '1', '517']
# ['rock', '40175', 'rock', 'R AA1 K', '2', 'o', '1', '97']
# ['tired', '20224', 'tired', 'T AY1 ER0 D', '2', 'ay', '1', '61']
# ['tired', '20224', 'tired', 'T AY1 ER0 D', '3', '*hr', '0', '28']
# ['marine', '14958', 'marine', 'M ER0 IY1 N', '2', '*hr', '0', '11']
# ['marine', '14958', 'marine', 'M ER0 IY1 N', '3', 'iy', '1', '13']
# ['life', '297654', 'life', 'L AY1 F', '2', 'ay0', '1', '569']
# ['already', '125232', 'already', 'AO0 R EH1 D IY0', '1', 'owr', '0', '59']
# ['already', '125232', 'already', 'AO0 L R EH1 D IY0', '6', 'iyF', '0', '61']
# ['already', '125232', 'already', 'AO0 R EH1 D IY0', '5', 'iyF', '0', '103']
# ['already', '125232', 'already', 'AO0 R EH1 D IY0', '3', 'e', '1', '40']
# ['already', '125232', 'already', 'AO0 L R EH1 D IY0', '1', 'oh', '0', '36']
# ['already', '125232', 'already', 'AO0 L R EH1 D IY0', '4', 'e', '1', '32']
# ['attempted', '10468', 'attempted', 'AH0 T EH1 M P T AH0 D', '3', 'e', '1', '1']
# ['attempted', '10468', 'attempted', 'AH0 T EH1 M P T AH0 D', '7', '@', '0', '1']
# ['yesterday', '25759', 'yesterday', 'Y EH1 S T ER0 D EY2', '2', 'e', '1', '61']
# ['yesterday', '25759', 'yesterday', 'Y EH1 S T ER0 D EY2', '7', 'eyF', '2', '53']
# ['yesterday', '25759', 'yesterday', 'Y EH1 S T ER0 D EY2', '5', '*hr', '0', '25']
# ['yesterday', '25759', 'yesterday', 'Y EH1 S T ER0 D IY0', '2', 'e', '1', '17']
# ['yesterday', '25759', 'yesterday', 'Y EH1 S T ER0 D IY0', '7', 'iyF', '0', '10']
# ['fish', '47253', 'fish', 'F IH1 SH', '2', 'i', '1', '70']
# ['week', '139555', 'week', 'W IY1 K', '2', 'iy', '1', '430']
# ['people', '725398', 'people', 'P IY1 P AH0 L', '2', 'iy', '1', '3513']
# ['people', '725398', 'people', 'P IY1 P AH0 L', '4', '@', '0', '357']
# ['person', '102488', 'person', 'P ER1 S AH0 N', '2', '*hr', '1', '589']
# ['person', '102488', 'person', 'P ER1 S AH0 N', '4', '@', '0', '134']
# ['making', '127351', 'making', 'M EY1 K IH0 NG', '2', 'ey', '1', '167']
# ['making', '127351', 'making', 'M EY1 K IH0 NG', '4', 'i', '0', '40']
# ['touching', '7160', 'touching', 'T AH1 CH IH0 NG', '4', 'i', '0', '1']
# ['touching', '7160', 'touching', 'T AH1 CH IH0 NG', '2', 'uh', '1', '5']
# ['touching', '7160', 'touching', 'T AH1 CH AH0 N', '2', 'uh', '1', '1']
# ['lately', '7326', 'lately', 'L EY1 T L IY0', '2', 'ey', '1', '18']
# ['lately', '7326', 'lately', 'L EY1 T L IY0', '5', 'iyF', '0', '16']
# ['stomach', '13951', 'stomach', 'S T AH1 M AH0 K', '3', 'uh', '1', '31']
# ['stomach', '13951', 'stomach', 'S T AH1 M AH0 K', '5', '@', '0', '8']
# ['dirty', '12286', 'dirty', 'D ER1 T IY0', '2', '*hr', '1', '48']
# ['dirty', '12286', 'dirty', 'D ER1 T IY0', '4', 'iyF', '0', '51']
# ['soak', '2453', 'soak', 'S OW1 K', '2', 'ow', '1', '7']
# ['shirt', '18617', 'shirt', 'SH ER1 T', '2', '*hr', '1', '26']
# ['fasten', '793', 'fasten', 'F AE1 S AH0 N', '2', 'aeh', '1', '6']
# ['fasten', '793', 'fasten', 'F AE1 S AH0 N', '4', '@', '0', '1']
# ['sometimes', '91514', 'sometimes', 'S AH1 M T AY2 M Z', '2', 'uh', '1', '246']
# ['sometimes', '91514', 'sometimes', 'S AH1 M T AY2 M Z', '5', 'ay', '2', '310']
# ['sometimes', '91514', 'sometimes', 'S AH0 M T AY1 M Z', '5', 'ay', '1', '240']
# ['sometimes', '91514', 'sometimes', 'S AH0 M T AY1 M Z', '2', '@', '0', '141']
# ['gave', '84409', 'gave', 'G EY1 V', '2', 'ey', '1', '324']
# ['teaching', '46583', 'teaching', 'T IY1 CH IH0 NG', '2', 'iy', '1', '83']
# ['teaching', '46583', 'teaching', 'T IY1 CH IH0 NG', '4', 'i', '0', '19']
# ['teaching', '46583', 'teaching', 'T IY1 CH AH0 N', '2', 'iy', '1', '8']
# ['kid', '33140', 'kid', 'K IH1 D', '2', 'i', '1', '543']
# ['art', '90724', 'art', 'AA1 R T', '1', 'ahr', '1', '45']
# ['came', '190857', 'came', 'K EY1 M', '2', 'ey', '1', '1378']
# ['light', '107085', 'light', 'L AY1 T', '2', 'ay0', '1', '130']
# ['room', '164260', 'room', 'R UW1 M', '2', 'Tuw', '1', '311']
# ['find', '184292', 'find', 'F AY1 N D', '2', 'ay', '1', '349']
# ['happily', '5773', 'happily', 'HH AE1 P AH0 L IY0', '2', 'ae', '1', '4']
# ['happily', '5773', 'happily', 'HH AE1 P AH0 L IY0', '6', 'iyF', '0', '4']
# ['happily', '5773', 'happily', 'HH AE1 P AH0 L IY0', '4', '@', '0', '1']
# ['naked', '10790', 'naked', 'N EY1 K AH0 D', '2', 'ey', '1', '8']
# ['naked', '10790', 'naked', 'N EY1 K AH0 D', '4', '@', '0', '2']
# ['waist', '6627', 'waist', 'W EY1 S T', '2', 'ey', '1', '1']
# ['chilly', '2190', 'chilly', 'CH IH1 L IY0', '4', 'iyF', '0', '1']
# ['kept', '59068', 'kept', 'K AE1 P T', '2', 'NA', '1', '140']
# ['kept', '59068', 'kept', 'K EH1 P T', '2', 'e', '1', '69']
# ['pads', '3118', 'pads', 'P AE1 D Z', '2', 'ae', '1', '7']
# ['strong', '71603', 'strong', 'S T R AO1 NG', '4', 'oh', '1', '78']
# ['today', '177191', 'today', 'T AH0 D EY1', '4', 'eyF', '1', '584']
# ['today', '177191', 'today', 'T AH0 D EY1', '2', '@', '0', '221']
# ['destroy', '10257', 'destroy', 'D AH0 S T R OY1', '6', 'oy', '1', '6']
# ['destroy', '10257', 'destroy', 'D AH0 S T R OY1', '2', '@', '0', '2']
# ['self', '15930', 'self', 'S EH1 L F', '2', 'e', '1', '15']
# ['wrong', '72111', 'wrong', 'R AO1 NG', '2', 'oh', '1', '260']
# ['happy', '52535', 'happy', 'HH AE1 P IY0', '2', 'ae', '1', '212']
# ['happy', '52535', 'happy', 'HH AE1 P IY0', '4', 'iyF', '0', '186']
# ['piece', '45163', 'piece', 'P IY1 S', '2', 'iy', '1', '135']
# ["didn't", '275385', "didn't", 'D IH1 N T', '2', 'i', '1', '1196']
# ["didn't", '275385', "didn't", 'D IH1 D AH0 N', '2', 'i', '1', '593']
# ["didn't", '275385', "didn't", 'D IH1 D AH0 N', '4', '@', '0', '117']
# ['think', '604459', 'think', 'TH IH1 NG K', '2', 'i', '1', '889']
# ['good', '394706', 'good', 'G UH1 D', '2', 'u', '1', '717']
# ['good', '394706', 'good', 'G AH0 D', '2', '@', '0', '973']
# ['artist', '27378', 'artist', 'AA1 R T AH0 S T', '1', 'ahr', '1', '12']
# ['artist', '27378', 'artist', 'AA1 R T AH0 S T', '4', '@', '0', '3']
# ['mother', '144251', 'mother', 'M AH1 DH ER0', '2', 'uh', '1', '1581']
# ['mother', '144251', 'mother', 'M AH1 DH ER0', '4', '*hr', '0', '1002']
# ['same', '241762', 'same', 'S EY1 M', '2', 'ey', '1', '1006']
# ['particularly', '54021', 'particularly', 'P ER0 T IH1 K Y AH0 L ER0 L IY0', '7', '@', '0', '5']
# ['particularly', '54021', 'particularly', 'P ER0 T IH1 K Y AH0 L ER0 L IY0', '11', 'iyF', '0', '14']
# ['particularly', '54021', 'particularly', 'P ER0 T IH1 K Y AH0 L ER0 L IY0', '9', '*hr', '0', '4']
# ['particularly', '54021', 'particularly', 'P ER0 T IH1 K Y AH0 L ER0 L IY0', '4', 'i', '1', '9']
# ['particularly', '54021', 'particularly', 'P ER0 T IH1 K Y AH0 L ER0 L IY0', '2', '*hr', '0', '7']
# ['leave', '80101', 'leave', 'L IY1 V', '2', 'iy', '1', '323']
# ['phone', '71549', 'phone', 'F OW1 N', '2', 'ow', '1', '128']
# ['hooked', '4978', 'hooked', 'HH UH1 K T', '2', 'u', '1', '19']
# ['working', '113221', 'working', 'W ER1 K IH0 NG', '2', '*hr', '1', '384']
# ['working', '113221', 'working', 'W ER1 K IH0 NG', '4', 'i', '0', '106']
# ['deal', '82576', 'deal', 'D IY1 L', '2', 'iy', '1', '112']
# ['baby', '55463', 'baby', 'B EY1 B IY0', '2', 'ey', '1', '280']
# ['baby', '55463', 'baby', 'B EY1 B IY0', '4', 'iyF', '0', '240']
# ['crying', '13815', 'crying', 'K R AY1 IH0 NG', '3', 'ay', '1', '45']
# ['crying', '13815', 'crying', 'K R AY1 IH0 NG', '4', 'i', '0', '8']
# ['small', '171175', 'small', 'S M AO1 L', '3', 'oh', '1', '184']
# ['child', '110140', 'child', 'CH AY1 L D', '2', 'ay', '1', '194']
# ['wanting', '11176', 'wanting', 'W AA1 N IH0 NG', '2', 'o', '1', '12']
# ['wanting', '11176', 'wanting', 'W AA1 N IH0 NG', '4', 'i', '0', '3']
# ['wanting', '11176', 'wanting', 'W AA1 N T IH0 NG', '2', 'o', '1', '1']
# ['wanting', '11176', 'wanting', 'W AA1 N T IH0 NG', '5', 'i', '0', '1']
# ['wanting', '11176', 'wanting', 'W AA1 N AH0 N', '2', 'o', '1', '1']
# ['attention', '70021', 'attention', 'AH0 T EH1 N SH AH0 N', '3', 'e', '1', '40']
# ['attention', '70021', 'attention', 'AH0 T EH1 N SH AH0 N', '1', '@', '0', '8']
# ['attention', '70021', 'attention', 'AH0 T EH1 N SH AH0 N', '6', '@', '0', '6']
# ['trying', '128382', 'trying', 'T R AY1 NG', '3', 'ay', '1', '166']
# ['trying', '128382', 'trying', 'T R AY1 IH0 NG', '3', 'ay', '1', '130']
# ['concentrate', '6810', 'concentrate', 'K AA1 N S AH0 N T R EY2 T', '2', 'o', '1', '8']
# ['concentrate', '6810', 'concentrate', 'K AA1 N S AH0 N T R EY2 T', '5', '@', '0', '2']
# ['concentrate', '6810', 'concentrate', 'K AA1 N S AH0 N T R EY2 T', '9', 'ey', '2', '8']
# ['offered', '37162', 'offered', 'AO1 F ER0 D', '1', 'oh', '1', '19']
# ['offered', '37162', 'offered', 'AO1 F ER0 D', '3', '*hr', '0', '13']
# ['happier', '3303', 'happier', 'HH AE1 P IY0 ER0', '2', 'ae', '1', '6']
# ['happier', '3303', 'happier', 'HH AE1 P IY0 ER0', '4', 'iy', '0', '7']
# ['happier', '3303', 'happier', 'HH AE1 P IY0 ER0', '5', '*hr', '0', '5']
# ['if', '1013741', 'if', 'IH1 F', '1', 'i', '1', '1436']
# ['if', '1013741', 'if', 'AH0 F', '1', '@', '0', '923']
# ['work', '340701', 'work', 'W ER1 K', '2', '*hr', '1', '1288']
# ['completely', '35755', 'completely', 'K AH0 M P L IY1 T L IY0', '9', 'iyF', '0', '58']
# ['completely', '35755', 'completely', 'K AH0 M P L IY1 T L IY0', '6', 'iy', '1', '46']
# ['decision', '59139', 'decision', 'D AH0 S IH1 ZH AH0 N', '2', '@', '0', '6']
# ['decision', '59139', 'decision', 'D AH0 S IH1 ZH AH0 N', '4', 'i', '1', '12']
# ['decision', '59139', 'decision', 'D AH0 S IH1 ZH AH0 N', '6', '@', '0', '4']
# ['course', '155262', 'course', 'K AO1 R S', '2', 'owr', '1', '280']
# ['easier', '24841', 'easier', 'IY1 Z IY0 ER0', '1', 'iy', '1', '47']
# ['easier', '24841', 'easier', 'IY1 Z IY0 ER0', '4', '*hr', '0', '37']
# ['easier', '24841', 'easier', 'IY1 Z IY0 ER0', '3', 'iy', '0', '31']
# ['months', '109859', 'months', 'M AH1 N TH S', '2', 'uh', '1', '278']
# ['ago', '135646', 'ago', 'AH0 G OW1', '3', 'owF', '1', '439']
# ['ago', '135646', 'ago', 'AH0 G OW1', '1', '@', '0', '170']
# ['finding', '33869', 'finding', 'F AY1 N D IH0 NG', '2', 'ay', '1', '13']
# ['finding', '33869', 'finding', 'F AY1 N D AH0 N', '2', 'ay', '1', '3']
# ['finding', '33869', 'finding', 'F AY1 N D IH0 NG', '5', 'i', '0', '1']
# ['pregnant', '13338', 'pregnant', 'P R EH1 G N AH0 N T', '3', 'e', '1', '57']
# ['pregnant', '13338', 'pregnant', 'P R EH1 G N AH0 N T', '6', '@', '0', '19']
# ['happened', '83805', 'happened', 'HH AE1 P AH0 N D', '2', 'ae', '1', '441']
# ['happened', '83805', 'happened', 'HH AE1 P AH0 N D', '4', '@', '0', '83']
# ...
# ['joshuas', '3', 'joshuas', 'JH AA1 SH UH0 AH0 Z', '2', 'o', '1', '1']
# ['flossy', '20', 'flossy', 'F L AO1 S IY0', '3', 'oh', '1', '1']
# ['flossy', '20', 'flossy', 'F L AO1 S IY0', '5', 'iyF', '0', '1']
# ['m', 'ck/fork ', 'm', 'EH1 M', '1', 'e', '1', '81']
# ['fumos', '2', 'fumos', 'F Y UW1 M OW0 Z', '5', 'ow', '0', '1']
# ['eeney', '1', 'eeney', 'IY1 N IY0', '3', 'iyF', '0', '2']
# ['eeney', '1', 'eeney', 'IY1 N IY0', '1', 'iy', '1', '1']
# ['s', '0/24/98 ', 's', 'EH1 S', '1', 'e', '1', '89']
# ['bartends', '2', 'bartends', 'B AA1 R T EH2 N D Z', '2', 'ahr', '1', '3']
# ['bartends', '2', 'bartends', 'B AA1 R T EH2 N D Z', '5', 'e', '2', '4']
# ['salvatores', '4', 'salvatores', 'S AE1 L V AH0 D AO2 R Z', '2', 'NA', '1', '1']
# ['oswell', '1', 'oswell', 'AA1 S W EH2 L', '1', 'o', '1', '1']
# ['modernish', '1', 'modernish', 'M AA1 D ER0 N IH0 SH', '2', 'o', '1', '1']
# ['modernish', '1', 'modernish', 'M AA1 D ER0 N IH0 SH', '4', '*hr', '0', '1']
# ['modernish', '1', 'modernish', 'M AA1 D ER0 N IH0 SH', '6', 'i', '0', '1']
# ['candi-', '1', 'candi-', 'K AE1 N D AH0', '2', 'aeh', '1', '1']
# ['calamar', '2', 'calamar', 'K AA0 L AA0 M AA1 R', '6', 'ahr', '1', '1']
# ['pennsyl-', '1', 'pennsyl-', 'P EH2 N S AH0 L', '2', 'e', '2', '2']
# ['aga-', '1', 'aga-', 'AH0 G EH1', '1', '@', '0', '1']
# ['dagus', '1', 'dagus', 'D EY1 G UW0 Z', '2', 'ey', '1', '1']
# ['dagus', '1', 'dagus', 'D EY1 G UW0 Z', '4', 'uw', '0', '1']
# ['mhm', '1', 'mhm', 'AH0 M HH AH0 M', '1', '@', '0', '531']
# ['mhm', '1', 'mhm', 'AH0 M HH AH0 M', '4', '@', '0', '378']
# ['margary', '1', 'margary', 'M AA1 R JH AH0 R IY0', '2', 'ahr', '1', '1']
# ['margary', '1', 'margary', 'M AA1 R JH AH0 R IY0', '7', 'iyF', '0', '1']
# ['liona', '7', 'liona', 'L IY0 OW1 N AH0', '2', 'iy', '0', '1']
# ['liona', '7', 'liona', 'L IY0 OW1 N AH0', '3', 'ow', '1', '1']
# ['liona', '7', 'liona', 'L IY0 OW1 N AH0', '5', '@', '0', '1']
# ['megacolon', '1', 'megacolon', 'M EH2 G AH0 K OW1 L AH0 N', '2', 'e', '2', '1']
# ['megacolon', '1', 'megacolon', 'M EH2 G AH0 K OW1 L AH0 N', '4', '@', '0', '1']
# ['megacolon', '1', 'megacolon', 'M EH2 G AH0 K OW1 L AH0 N', '6', 'ow', '1', '1']
# ['mondy', '6', 'mondy', 'M AA1 N D IY0', '2', 'o', '1', '5']
# ['mondy', '6', 'mondy', 'M AA1 N D IY0', '5', 'iyF', '0', '5']
# ['langhorn', '4', 'langhorn', 'L AE1 NG HH AO0 R N', '2', 'ae', '1', '1']
# ['aight', '2', 'aight', 'AA0 AY1 T', '2', 'ay0', '1', '1']
# ['flowerboxes', '2', 'flowerboxes', 'F L AW1 ER0 B AA2 K S AH0 S', '3', 'aw', '1', '1']
# ['flowerboxes', '2', 'flowerboxes', 'F L AW1 ER0 B AA2 K S AH0 S', '6', 'o', '2', '1']
# ['shaina', '6', 'shaina', 'SH EY1 N AH0', '2', 'ey', '1', '1']
# ["strokin'", '1', "strokin'", 'S T R OW1 K AH0 N', '4', 'ow', '1', '1']
# ['rufford', '4', 'rufford', 'R AH1 F ER0 D', '2', 'uh', '1', '1']
# ['arou-', '1', 'arou-', 'AH0 R AW1', '1', 'uh', '0', '1']
# ["prejudice'", '3', "prejudice'", 'P R EH1 JH AH0 D AH0 S', '7', '@', '0', '1']
# ['falutin', '1', 'falutin', 'F AH0 L UW1 T IH0 N', '4', 'Tuw', '1', '1']
# ['falutin', '1', 'falutin', 'F AH0 L UW1 T IH0 N', '6', 'i', '0', '1']
# ["rottin'", '2', "rottin'", 'R AA1 T AH0 N', '2', 'o', '1', '1']
# ["towin'", '8', "towin'", 'T OW1 AH0 N', '2', 'ow', '1', '1']
# ['schuykill', '2', 'schuykill', 'S K OW1 IY0 K AH0 L', '3', 'ow', '1', '7']
# ['schuykill', '2', 'schuykill', 'S K OW1 IY0 K AH0 L', '6', '@', '0', '2']
# ['schuykill', '2', 'schuykill', 'S K OW1 IY0 K AH0 L', '4', 'iy', '0', '2']
# ["ordinary's", '2', "ordinary's", 'AO1 R D IH0 N EH2 R IY0', '1', 'owr', '1', '2']
# ["ordinary's", '2', "ordinary's", 'AO1 R D IH0 N EH2 R IY0', '6', 'e', '2', '2']
# ["ordinary's", '2', "ordinary's", 'AO1 R D IH0 N EH2 R IY0', '8', 'iyF', '0', '2']
# ['smuck', '1', 'smuck', 'S M AH1 K', '3', 'uh', '1', '1']
# ['eventual-', '1', 'eventual-', 'AH0 V EH1 N CH UW0 AH0 L', '1', '@', '0', '1']
# ['eventual-', '1', 'eventual-', 'AH0 V EH1 N CH UW0 AH0 L', '3', 'e', '1', '1']
# ['wessie', '2', 'wessie', 'W EH1 S IY0', '2', 'e', '1', '8']
# ['wessie', '2', 'wessie', 'W EH1 S IY0', '4', 'iyF', '0', '7']
# ['headedness', '4', 'headedness', 'HH EH1 D AH0 D N AH0 S', '2', 'e', '1', '1']
# ['headedness', '4', 'headedness', 'HH EH1 D AH0 D N AH0 S', '4', '@', '0', '1']
# ['headedness', '4', 'headedness', 'HH EH1 D AH0 D N AH0 S', '7', '@', '0', '1']
# ['spicket', '1', 'spicket', 'S P IH1 K IH0 T', '3', 'i', '1', '1']
# ['spicket', '1', 'spicket', 'S P IH1 K IH0 T', '5', 'i', '0', '1']
# ["wrestlin'", '4', "wrestlin'", 'R EH1 S L AH0 N', '2', 'e', '1', '1']
# ["wrestlin'", '4', "wrestlin'", 'R EH1 S AH0 L AH0 N', '2', 'e', '1', '2']
# ['bigley', '27', 'bigley', 'B IH1 G L IY0', '2', 'i', '1', '1']
# ['bigley', '27', 'bigley', 'B IH1 G L IY0', '5', 'iyF', '0', '1']
# ['talmudical', '3', 'talmudical', 'T AE0 L M Y UW1 D AH0 K AH0 L', '6', 'uw', '1', '1']
# ['talmudical', '3', 'talmudical', 'T AE0 L M Y UW1 D AH0 K AH0 L', '10', '@', '0', '1']
# ["stetson's", '2', "stetson's", 'S T EH1 T S AH0 N Z', '3', 'e', '1', '1']
# ['shopright', '1', 'shopright', 'SH AA1 P R AY0 T', '2', 'o', '1', '1']
# ['shopright', '1', 'shopright', 'SH AA1 P R AY0 T', '5', 'ay0', '0', '1']
# ["chisel's", '3', "chisel's", 'CH IH1 Z AH0 L Z', '2', 'i', '1', '1']
# ["chisel's", '3', "chisel's", 'CH IH1 Z AH0 L Z', '4', '@', '0', '1']
# ["comparin'", '2', "comparin'", 'K AH0 M P EH1 R AH0 N', '5', 'e', '1', '1']
# ["scramblin'", '2', "scramblin'", 'S K R AE1 M B AH0 L AH0 N', '9', '@', '0', '1']
# ["kenny'll", '3', "kenny'll", 'K EH1 N IY0 AH0 L', '2', 'e', '1', '1']
# ["kenny'll", '3', "kenny'll", 'K EH1 N IY0 AH0 L', '4', 'iy', '0', '1']
# ['whops', '1', 'whops', 'W AA1 P S', '2', 'o', '1', '1']
# ["graduatin'", '2', "graduatin'", 'G R AE1 JH UW0 EY2 T AH0 N', '6', 'ey', '2', '1']
# ["graduatin'", '2', "graduatin'", 'G R AE1 JH UW0 EY2 T AH0 N', '3', 'ae', '1', '1']
# ["graduatin'", '2', "graduatin'", 'G R AE1 JH UW0 EY2 T AH0 N', '5', 'uw', '0', '1']
# ['formicola', '3', 'formicola', 'F OW1 R M AH0 K OW2 L AH0', '2', 'owr', '1', '2']
# ['formicola', '3', 'formicola', 'F OW1 R M AH0 K OW2 L AH0', '7', 'ow', '2', '2']
# ['formicola', '3', 'formicola', 'F OW1 R M AH0 K OW2 L AH0', '5', '@', '0', '1']
# ['dynamiter', '2', 'dynamiter', 'D AY1 N AH0 M AY0 T ER0', '2', 'ay', '1', '1']
# ['dynamiter', '2', 'dynamiter', 'D AY1 N AH0 M AY0 T ER0', '6', 'ay0', '0', '1']
# ['dynamiter', '2', 'dynamiter', 'D AY1 N AH0 M AY0 T ER0', '8', '*hr', '0', '1']
# ['belarussia', '2', 'belarussia', 'B EH1 L AH0 R AH2 SH AH0', '2', 'e', '1', '1']
# ['belarussia', '2', 'belarussia', 'B EH1 L AH0 R AH2 SH AH0', '4', 'uh', '0', '1']
# ['belarussia', '2', 'belarussia', 'B EH1 L AH0 R AH2 SH AH0', '6', 'uh', '2', '1']
# ['belarussia', '2', 'belarussia', 'B EH1 L AH0 R AH2 SH AH0', '8', '@', '0', '1']
# ['salvato', '7', 'salvato', 'S AA0 L V AA1 T OW0', '2', 'o', '0', '1']
# ['salvato', '7', 'salvato', 'S AA0 L V AA1 T OW0', '5', 'o', '1', '1']
# ['salvato', '7', 'salvato', 'S AA0 L V AA1 T OW0', '7', 'owF', '0', '1']
# ["satisfyin'", '1', "satisfyin'", 'S AE1 T AH0 S F AY2 AH0 N', '2', 'ae', '1', '1']
# ["satisfyin'", '1', "satisfyin'", 'S AE1 T AH0 S F AY2 AH0 N', '7', 'ay', '2', '1']
# ['prophesizes', '2', 'prophesizes', 'P R AA1 F AH0 S AY2 Z AH0 Z', '3', 'o', '1', '1']
# ['prophesizes', '2', 'prophesizes', 'P R AA1 F AH0 S AY2 Z AH0 Z', '7', 'ay', '2', '1']
# ["datin'", '2', "datin'", 'D EY1 T AH0 N', '2', 'ey', '1', '2']
# ['deporter', '3', 'deporter', 'D IH0 P AO1 R T ER0', '2', 'i', '0', '1']
# ['deporter', '3', 'deporter', 'D IH0 P AO1 R T ER0', '4', 'owr', '1', '1']
# ['deporter', '3', 'deporter', 'D IH0 P AO1 R T ER0', '7', '*hr', '0', '1']
# ['turnersville', '3', 'turnersville', 'T ER1 N ER0 Z V IH2 L', '2', '*hr', '1', '1']
# ['dotch', '1', 'dotch', 'D AA1 CH', '2', 'o', '1', '1']
# ['shlepper', '2', 'shlepper', 'SH L EH1 P ER0', '3', 'e', '1', '1']
# ['shlepper', '2', 'shlepper', 'SH L EH1 P ER0', '5', '*hr', '0', '1']
# ['deez', '2', 'deez', 'D IY1 Z', '2', 'iy', '1', '1']
# ['stinked', '2', 'stinked', 'S T IH1 NG K T', '3', 'i', '1', '1']
# ['epi-', '1', 'epi-', 'EH1 P IH0', '1', 'e', '1', '1']
# ['dragers', '1', 'dragers', 'D R EY1 G ER0 Z', '3', 'ey', '1', '2']
# ['dragers', '1', 'dragers', 'D R EY1 G ER0 Z', '5', '*hr', '0', '2']
# ["deliverin'", '1', "deliverin'", 'D AH0 L IH1 V ER0 AH0 N', '2', '@', '0', '2']
# ["deliverin'", '1', "deliverin'", 'D AH0 L IH1 V ER0 AH0 N', '6', '*hr', '0', '2']
# ["deliverin'", '1', "deliverin'", 'D AH0 L IH1 V ER0 AH0 N', '4', 'i', '1', '1']
# ["le'", '5', "le'", 'L EH1', '2', 'e', '1', '2']
# ['tullytown', '1', 'tullytown', 'T AH1 L IY0 T AW2 N', '2', 'uh', '1', '2']
# ['tullytown', '1', 'tullytown', 'T AH1 L IY0 T AW2 N', '4', 'iy', '0', '2']
# ['tullytown', '1', 'tullytown', 'T AH1 L IY0 T AW2 N', '6', 'aw', '2', '2']
# ['j', ' ', 'j', 'JH EY1', '2', 'eyF', '1', '29']
# ['j', ' ', 'j', 'JH EY1', '2', 'eyF', '1', '29']
# ['calif-', '1', 'calif-', 'K AE2 L AH0 F', '2', 'NA', '2', '1']
# ['did', 'nvwi', 'did', 'D IH1 D', '2', 'i', '1', '1445']
# ['did', 'nvwi', 'did', 'D AH0 D', '2', '@', '0', '415']
# ['backsies', '1', 'backsies', 'B AE1 K S IY0 Z', '2', 'ae', '1', '1']
# ['backsies', '1', 'backsies', 'B AE1 K S IY0 Z', '5', 'iy', '0', '1']
# ['gimme', '1', 'gimme', 'G IH1 M IY0', '2', 'i', '1', '5']
# ['gimme', '1', 'gimme', 'G IH1 M IY0', '4', 'iyF', '0', '8']
# ['bamby', '2', 'bamby', 'B AE1 M B IY0', '2', 'aeh', '1', '2']
# ['bamby', '2', 'bamby', 'B AE1 M B IY0', '5', 'iyF', '0', '2']
# ['halfsies', '2', 'halfsies', 'HH AE1 F S IY0 Z', '2', 'aeh', '1', '1']
# ['halfsies', '2', 'halfsies', 'HH AE1 F S IY0 Z', '5', 'iy', '0', '1']
# ["brahm's", '3', "brahm's", 'B R AA1 M Z', '3', 'o', '1', '1']
# ['phanatics', '1', 'phanatics', 'F AH0 N AE1 T IH0 K S', '2', '@', '0', '1']
# ['phanatics', '1', 'phanatics', 'F AH0 N AE1 T IH0 K S', '4', 'ae', '1', '1']
# ['expen-', '1', 'expen-', 'IH0 K S P EH1 N', '1', 'i', '0', '1']
# ['sheepie', '1', 'sheepie', 'SH IY1 P IY0', '2', 'iy', '1', '3']
# ['sheepie', '1', 'sheepie', 'SH IY1 P IY0', '4', 'iyF', '0', '2']
# ["reenie's", '1', "reenie's", 'R IY1 N IY0 Z', '2', 'iy', '1', '1']
# ["reenie's", '1', "reenie's", 'R IY1 N IY0 Z', '4', 'iy', '0', '1']
# ['halfies', '3', 'halfies', 'HH AE1 F IY0 Z', '2', 'NA', '1', '8']
# ['halfies', '3', 'halfies', 'HH AE1 F IY0 Z', '4', 'iy', '0', '8']
# ['monther', '1', 'monther', 'M AH1 N TH ER0', '2', 'uh', '1', '1']
# ["sandy'll", '1', "sandy'll", 'S AE1 N D IY0 AH0 L', '2', 'aeh', '1', '1']
# ["sandy'll", '1', "sandy'll", 'S AE1 N D IY0 AH0 L', '5', 'iy', '0', '1']
# ['jacomo', '7', 'jacomo', 'JH AA1 K OW0 M OW0', '2', 'o', '1', '1']
# ['jacomo', '7', 'jacomo', 'JH AA1 K OW0 M OW0', '6', 'owF', '0', '1']
# ['scuze', '2', 'scuze', 'S K Y UW1 Z', '4', 'uw', '1', '1']
# ['contor', '4', 'contor', 'K AA1 N T ER0', '2', 'o', '1', '1']
# ['contor', '4', 'contor', 'K AA1 N T ER0', '5', '*hr', '0', '1']
# ['brickface', '1', 'brickface', 'B R IH1 K F EY2 S', '6', 'ey', '2', '1']
# ["disciplinarian's", '1', "disciplinarian's", 'D IH2 S IH0 P L IH0 N EH1 R IY0 AH0 N Z', '9', 'e', '1', '1']
# ["disciplinarian's", '1', "disciplinarian's", 'D IH2 S IH0 P L IH0 N EH1 R IY0 AH0 N Z', '11', 'iy', '0', '1']
# ['waynewood', '2', 'waynewood', 'W EY1 N W UH2 D', '2', 'ey', '1', '1']
# ["chuckin'", '1', "chuckin'", 'CH AH1 K AH0 N', '2', 'uh', '1', '1']
# ['murelli', '1', 'murelli', 'M UH1 R EH0 L IY0', '6', 'iyF', '0', '3']
# ['murelli', '1', 'murelli', 'M UH1 R EH0 L IY0', '2', 'uwr', '1', '1']
# ['pumfrey', '3', 'pumfrey', 'P AH1 M F R IY0', '2', 'uh', '1', '1']
# ['pumfrey', '3', 'pumfrey', 'P AH1 M F R IY0', '6', 'iyF', '0', '1']
# ["roxborough's", '1', "roxborough's", 'R AA1 K S B AH0 R OW0 Z', '2', 'o', '1', '1']
# ["roxborough's", '1', "roxborough's", 'R AA1 K S B AH0 R OW0 Z', '8', 'ow', '0', '1']
# ['shonk', '3', 'shonk', 'SH AA1 NG K', '2', 'o', '1', '1']
# ["partyin'", '2', "partyin'", 'P AA1 R T IY0 AH0 N', '2', 'ahr', '1', '1']
# ['vaca-', '3', 'vaca-', 'V EY0 K EY1', '2', 'ey', '0', '2']
# ['darvons', '1', 'darvons', 'D AA1 R V AH0 N Z', '2', 'ahr', '1', '1']
# ['darvons', '1', 'darvons', 'D AA1 R V AH0 N Z', '5', '@', '0', '1']
# ["roofin'", '1', "roofin'", 'R UW1 F AH0 N', '2', 'Tuw', '1', '1']
# ["bickerin'", '1', "bickerin'", 'B IH1 K ER0 AH0 N', '2', 'i', '1', '1']
# ["sealin'", '1', "sealin'", 'S IY1 L AH0 N', '2', 'iy', '1', '1']
# ["competin'", '3', "competin'", 'K AH0 M P IY1 T AH0 N', '2', '@', '0', '1']
# ["competin'", '3', "competin'", 'K AH0 M P IY1 T AH0 N', '5', 'iy', '1', '1']
# ['capade', '1', 'capade', 'K AH0 P EY1 D', '2', '@', '0', '1']
# ['capade', '1', 'capade', 'K AH0 P EY1 D', '4', 'ey', '1', '1']
# ['fontanez', '26', 'fontanez', 'F OW0 N T AA1 N EH0 Z', '5', 'o', '1', '2']
# ['fontanez', '26', 'fontanez', 'F OW0 N T AA1 N EH0 Z', '2', 'ow', '0', '1']
# ['fontanez', '26', 'fontanez', 'F OW0 N T AA1 N EH0 Z', '7', 'e', '0', '1']
# ["stroll's", '1', "stroll's", 'S T R OW1 L Z', '4', 'ow', '1', '1']
# ['addeo', '2', 'addeo', 'AA1 D IY0 OW0', '1', 'o', '1', '1']
# ['addeo', '2', 'addeo', 'AA1 D IY0 OW0', '3', 'iy', '0', '1']
# ['addeo', '2', 'addeo', 'AA1 D IY0 OW0', '4', 'owF', '0', '1']
# ["noddin'", '1', "noddin'", 'N AA1 D AH0 N', '2', 'o', '1', '1']
# ['ducket', '1', 'ducket', 'D AH1 K EH0 T', '2', 'uh', '1', '1']
# ['ducket', '1', 'ducket', 'D AH1 K EH0 T', '4', 'e', '0', '1']
# ['murrey', '2', 'murrey', 'M ER1 IY0', '2', '*hr', '1', '1']
# ['murrey', '2', 'murrey', 'M ER1 IY0', '3', 'iyF', '0', '1']
# ['brigatine', '1', 'brigatine', 'B R IH1 G AH0 T IY2 N', '3', 'i', '1', '1']
# ['brigatine', '1', 'brigatine', 'B R IH1 G AH0 T IY2 N', '7', 'iy', '2', '1']
# ['competi-', '1', 'competi-', 'K AA2 M P AH0 T IH1', '2', 'o', '2', '2']
# ['b', "'r ", 'b', 'B IY1', '2', 'iyF', '1', '167']
# ['ed', '0/serendip/ ', 'ed', 'EH1 D', '1', 'e', '1', '36']
# ['goldish', '1', 'goldish', 'G OW1 L D IH0 SH', '2', 'ow', '1', '1']
# ['goldish', '1', 'goldish', 'G OW1 L D IH0 SH', '5', 'i', '0', '1']
# ['rauss', '1', 'rauss', 'R AW1 S', '2', 'aw', '1', '1']
# ['burries', '1', 'burries', 'B ER1 IY0 Z', '2', '*hr', '1', '1']
# ['burries', '1', 'burries', 'B ER1 IY0 Z', '3', 'iy', '0', '1']
# ['senf', '2', 'senf', 'S EH1 N F', '2', 'e', '1', '1']
# ['manting', '1', 'manting', 'M AE1 N T IY0 NG', '5', 'iy', '0', '1']
# ['yadon', '1', 'yadon', 'Y AE1 D AH0 N', '2', 'ae', '1', '1']
# ['holmesburg', '1', 'holmesburg', 'HH OW1 L M Z B ER0 G', '2', 'ow', '1', '1']
# ['holmesburg', '1', 'holmesburg', 'HH OW1 L M Z B ER0 G', '7', '*hr', '0', '1']
# ['stokesberry', '3', 'stokesberry', 'S T OW1 K S B EH0 R IY0', '3', 'ow', '1', '2']
# ['stokesberry', '3', 'stokesberry', 'S T OW1 K S B EH0 R IY0', '7', 'e', '0', '2']
# ['demp', '1', 'demp', 'D EH1 M P', '2', 'e', '1', '3']
# ['medicine', 'davp ', 'medicine', 'M EH1 D AH0 S AH0 N', '2', 'e', '1', '17']
# ['medicine', 'davp ', 'medicine', 'M EH1 D AH0 S AH0 N', '6', '@', '0', '7']
# ['medicine', 'davp ', 'medicine', 'M EH1 D AH0 S AH0 N', '4', '@', '0', '2']
# ["gimble's", '1', "gimble's", 'G IH1 M B AH0 L Z', '2', 'i', '1', '3']
# ['plowers', '1', 'plowers', 'P L AW1 ER0 Z', '3', 'aw', '1', '1']
# ['plowers', '1', 'plowers', 'P L AW1 ER0 Z', '4', '*hr', '0', '1']
# ['photo', 'ygma/thomas ', 'photo', 'F OW1 T OW2', '2', 'ow', '1', '2']
# ['photo', 'ygma/thomas ', 'photo', 'F OW1 T OW2', '4', 'owF', '2', '2']
# ["creepin'", '1', "creepin'", 'K R IY1 P AH0 N', '3', 'iy', '1', '1']
# ['gerundives', '1', 'gerundives', 'JH EH2 R AH1 N D AH0 V Z', '4', 'uh', '1', '1']
# ['gerundives', '1', 'gerundives', 'JH EH2 R AH1 N D AH0 V Z', '7', '@', '0', '1']
# ['asunta', '1', 'asunta', 'AH0 S UW1 N T AH0', '1', '@', '0', '2']
# ['asunta', '1', 'asunta', 'AH0 S UW1 N T AH0', '3', 'Tuw', '1', '3']
# ['asunta', '1', 'asunta', 'AH0 S UW1 N T AH0', '6', '@', '0', '3']
# ['finace', '1', 'finace', 'F IY0 AA1 N S EY0', '2', 'iy', '0', '1']
# ['finace', '1', 'finace', 'F IY0 AA1 N S EY0', '3', 'o', '1', '1']
# ['finace', '1', 'finace', 'F IY0 AA1 N S EY0', '6', 'eyF', '0', '1']
# ['farleys', '1', 'farleys', 'F AA1 R L IY0 Z', '2', 'ahr', '1', '1']
# ['farleys', '1', 'farleys', 'F AA1 R L IY0 Z', '5', 'iy', '0', '1']
# ["putterin'", '1', "putterin'", 'P AH1 T ER0 AH0 N', '2', 'uh', '1', '1']
# ["putterin'", '1', "putterin'", 'P AH1 T ER0 AH0 N', '4', '*hr', '0', '1']
# ['steskal', '3', 'steskal', 'S T EH1 S K AH0 L', '3', 'e', '1', '2']
# ['curby', '1', 'curby', 'K ER1 B IY0', '2', '*hr', '1', '1']
# ['curby', '1', 'curby', 'K ER1 B IY0', '4', 'iyF', '0', '1']

# %% [markdown]
# ## Finding Multiple High Frequency Pronunciations

# %%
import time
import csv
import numpy as np
import ast

t0 = time.time()
PC_file = open('/Users/TaraD/LING_Research/PNCinCOCA_5pcdeleted.csv', newline='')
data_array = np.array(list(csv.reader(PC_file)))
#print(data_array[:5])
header = ['COCA word', 'COCA dict #', 'PNC word', 'Trans', 'v_index', 'v_class', 'Stress', 'PNC count']

reduced_PNCinCOCA2 = [header]
for i in range(1,len(data_array)):
    line = data_array[i]
    word = line[0]
    trans = line[3]
    if i == 1 or word != data_array[i-1,0]:
        word_list = []
        word_list.append(line)
        

    # MAKING WORD_LIST WITH UNIQUE TRANSCRIPTIONS, IF MULTIPLE TRANSCRIPTION, KEEPS ONE WITH MOST COUNTS
    word_list = np.array(word_list)
    if trans in word_list[:,3]:# and i !=1 and word == data_array[i-1,0]:
        index = (np.where(word_list[:,3]==trans))[0]
        if line[7].astype(int) > (word_list[index,7].astype(int)):
            word_list[index] = line
            word_list = word_list.tolist()
        #else:
            #continue
    else:
        word_list = word_list.tolist()
        word_list.append(line)
    
    # At last instance of word: Word list is now unique transcriptions. 
    if i == (len(data_array)-1) or data_array[i+1,0] != word:
        word_array = np.array(word_list)
        #print(word_array)
        #word_list2 = []
        #for k in word_array:
            #word_array2 = np.array(word_list2)
            #if k[3] == 
        
        # IF MULTIPLE TRANSCRIPTIONS
        if len(word_array) > 1:
            Sum = np.sum((word_array[:,7].astype(int)), axis=0)
            
            # MASK SO ONLY TRANSCRIPTIONS > 30% SUMMED COUNTS REMAIN
            mask = (word_array[:,7].astype(int) >= (.30*Sum))#&(word_array[:,7].astype(int) <= (.30*Sum))
            reduced_word_array = word_array[mask]
        #print(reduced_word_array)
        #print(len(word_array), len(reduced_word_array))
        #if (len(set(reduced_word_array[:,3])) > 1):
            #print(set(reduced_word_array[:,3]))
            
            # IF STILL MULTIPLE HIGH TRANSCRIPTIONS: RECORD AND APPEND.  V
            if len(reduced_word_array) > 1:
                reduced_PNCinCOCA2.extend((reduced_word_array).tolist())
    else: 
        #print('continue')
        continue    
print(np.shape(reduced_PNCinCOCA2))
print(*reduced_PNCinCOCA2, sep='\n')
np.savetxt('PNCinCOCA_HighFreqAlt.csv',reduced_PNCinCOCA2, '%s',delimiter=",")
np.savetxt('PNCinCOCA_HighFreqAlt.txt',reduced_PNCinCOCA2,'%-15s')
print(time.time()-t0)
# Out:
# (888, 8)
# ['COCA word', 'COCA dict #', 'PNC word', 'Trans', 'v_index', 'v_class', 'Stress', 'PNC count']
# ['was', '3083112', 'was', 'W AH0 Z', '2', '@', '0', '2172']
# ['was', '3083112', 'was', 'W AH1 Z', '2', 'uh', '1', '1727']
# ['as', '2599971', 'as', 'AE1 Z', '1', 'NA', '1', '683']
# ['as', '2599971', 'as', 'AH0 Z', '1', '@', '0', '495']
# ["it's", '772979', "it's", 'IH1 T S', '1', 'i', '1', '2055']
# ["it's", '772979', "it's", 'AH0 T S', '1', '@', '0', '1776']
# ['began', '109730', 'began', 'B IY0 G AE1 N', '4', 'NA', '1', '33']
# ['began', '109730', 'began', 'B IH0 G AE1 N', '4', 'NA', '1', '37']
# ['into', '723936', 'into', 'IH2 N T UW1', '4', 'Tuw', '1', '245']
# ['into', '723936', 'into', 'IH2 N T AH0', '1', 'i', '2', '289']
# ['can', '949767', 'can', 'K AE1 N', '2', 'NA', '1', '360']
# ['can', '949767', 'can', 'K AH0 N', '2', '@', '0', '224']
# ['between', '290141', 'between', 'B IY0 T W IY1 N', '2', 'iy', '0', '118']
# ['between', '290141', 'between', 'B AH0 T W IY1 N', '5', 'iy', '1', '70']
# ['adding', '17966', 'adding', 'AE1 D IH0 NG', '1', 'ae', '1', '2']
# ['adding', '17966', 'adding', 'AE1 D AH0 N', '1', 'ae', '1', '1']
# ['before', '366010', 'before', 'B IY2 F AO1 R', '4', 'owr', '1', '431']
# ['before', '366010', 'before', 'B AH0 F AO1 R', '4', 'owr', '1', '344']
# ['hundred', '37031', 'hundred', 'HH AH1 N ER0 D', '4', '*hr', '0', '139']
# ['hundred', '37031', 'hundred', 'HH AH1 N D ER0 D', '5', '*hr', '0', '137']
# ['been', '852399', 'been', 'B IH1 N', '2', 'i', '1', '473']
# ['been', '852399', 'been', 'B AH0 N', '2', '@', '0', '403']
# ['hanging', '16655', 'hanging', 'HH AE1 NG IH0 NG', '2', 'ae', '1', '20']
# ['hanging', '16655', 'hanging', 'HH AE1 NG G IH0 NG', '2', 'ae', '1', '24']
# ['already', '125232', 'already', 'AO0 R EH1 D IY0', '5', 'iyF', '0', '103']
# ['already', '125232', 'already', 'AO0 L R EH1 D IY0', '6', 'iyF', '0', '61']
# ['sometimes', '91514', 'sometimes', 'S AH1 M T AY2 M Z', '5', 'ay', '2', '310']
# ['sometimes', '91514', 'sometimes', 'S AH0 M T AY1 M Z', '5', 'ay', '1', '240']
# ['kept', '59068', 'kept', 'K AE1 P T', '2', 'NA', '1', '140']
# ['kept', '59068', 'kept', 'K EH1 P T', '2', 'e', '1', '69']
# ["didn't", '275385', "didn't", 'D IH1 N T', '2', 'i', '1', '1196']
# ["didn't", '275385', "didn't", 'D IH1 D AH0 N', '2', 'i', '1', '593']
# ['good', '394706', 'good', 'G UH1 D', '2', 'u', '1', '717']
# ['good', '394706', 'good', 'G AH0 D', '2', '@', '0', '973']
# ['trying', '128382', 'trying', 'T R AY1 NG', '3', 'ay', '1', '166']
# ['trying', '128382', 'trying', 'T R AY1 IH0 NG', '3', 'ay', '1', '130']
# ['if', '1013741', 'if', 'IH1 F', '1', 'i', '1', '1436']
# ['if', '1013741', 'if', 'AH0 F', '1', '@', '0', '923']
# ['different', '176802', 'different', 'D IH1 F R AH0 N T', '2', 'i', '1', '447']
# ['different', '176802', 'different', 'D IH1 F ER0 AH0 N T', '2', 'i', '1', '256']
# ['favorite', '34477', 'favorite', 'F EY1 V ER0 AH0 T', '2', 'ey', '1', '22']
# ['favorite', '34477', 'favorite', 'F EY1 V R AH0 T', '2', 'ey', '1', '36']
# ['happening', '24994', 'happening', 'HH AE1 P AH0 N IH0 NG', '2', 'ae', '1', '29']
# ['happening', '24994', 'happening', 'HH AE1 P N IH0 NG', '2', 'ae', '1', '36']
# ['without', '187523', 'without', 'W IH2 DH AW1 T', '4', 'aw', '1', '105']
# ['without', '187523', 'without', 'W IH2 TH AW1 T', '4', 'aw', '1', '52']
# ['says', '599409', 'says', 'S IH1 Z', '2', 'i', '1', '253']
# ['says', '599409', 'says', 'S EH1 Z', '2', 'e', '1', '297']
# ['cabinet', '9958', 'cabinet', 'K AE1 B AH0 N AH0 T', '2', 'ae', '1', '3']
# ['cabinet', '9958', 'cabinet', 'K AE1 B N AH0 T', '2', 'ae', '1', '6']
# ['getting', '122440', 'getting', 'G IH1 T IH0 NG', '2', 'i', '1', '306']
# ['getting', '122440', 'getting', 'G EH1 T IH0 NG', '2', 'e', '1', '157']
# ['close', '98419', 'close', 'K L OW1 S', '3', 'ow', '1', '115']
# ['close', '98419', 'close', 'K L OW1 Z', '3', 'ow', '1', '194']
# ['inside', '89322', 'inside', 'IH1 N S AY2 D', '4', 'ay', '2', '61']
# ['inside', '89322', 'inside', 'IH2 N S AY1 D', '4', 'ay', '1', '61']
# ['falling', '19263', 'falling', 'F AO1 L IH0 NG', '2', 'oh', '1', '8']
# ['falling', '19263', 'falling', 'F AA1 L IH0 NG', '2', 'o', '1', '4']
# ['hour', '56716', 'hour', 'AW1 ER0', '1', 'aw', '1', '71']
# ['hour', '56716', 'hour', 'AW1 R', '1', 'aw', '1', '63']
# ['during', '206634', 'during', 'D ER1 IH0 NG', '2', '*hr', '1', '42']
# ['during', '206634', 'during', 'D UH1 R AH0 N', '2', 'uwr', '1', '40']
# ['during', '206634', 'during', 'D UH1 R IH0 NG', '2', 'uwr', '1', '48']
# ['resemble', '3531', 'resemble', 'R AH0 Z EH1 M B AH0 L', '4', 'e', '1', '1']
# ['resemble', '3531', 'resemble', 'R IY0 Z EH1 M B AH0 L', '2', 'iy', '0', '1']
# ['ancient', '21472', 'ancient', 'EY1 N CH AH0 N T', '1', 'ey', '1', '4']
# ['ancient', '21472', 'ancient', 'EY1 N SH AH0 N T', '1', 'ey', '1', '2']
# ['steering', '4958', 'steering', 'S T IH1 R IH0 NG', '3', 'iyr', '1', '1']
# ['steering', '4958', 'steering', 'S T IH1 R AH0 N', '3', 'iyr', '1', '1']
# ['relaxed', '6614', 'relaxed', 'R IY0 L AE1 K S T', '2', 'iy', '0', '4']
# ['relaxed', '6614', 'relaxed', 'R AH0 L AE1 K S T', '4', 'ae', '1', '2']
# ['recently', '60790', 'recently', 'R IY1 S AH0 N L IY0', '7', 'iyF', '0', '30']
# ['recently', '60790', 'recently', 'R IY1 S AH0 N T L IY0', '8', 'iyF', '0', '14']
# ['empty', '26676', 'empty', 'EH1 M T IY0', '4', 'iyF', '0', '13']
# ['empty', '26676', 'empty', 'EH1 M P T IY0', '1', 'e', '1', '18']
# ['palm', '13060', 'palm', 'P AA1 M', '2', 'ah', '1', '9']
# ['palm', '13060', 'palm', 'P AA1 L M', '2', 'ah', '1', '7']
# ['current', '66326', 'current', 'K ER1 N T', '2', '*hr', '1', '2']
# ['current', '66326', 'current', 'K AA1 R AH0 N T', '2', 'ahr', '1', '2']
# ['calm', '14556', 'calm', 'K AA1 M', '2', 'ah', '1', '19']
# ['calm', '14556', 'calm', 'K AA1 L M', '2', 'ah', '1', '11']
# ['enter', '20536', 'enter', 'EH1 N T ER0', '4', '*hr', '0', '4']
# ['enter', '20536', 'enter', 'EH1 N ER0', '1', 'e', '1', '3']
# ['remember', '82434', 'remember', 'R AH0 M EH1 M B ER0', '7', '*hr', '0', '337']
# ['remember', '82434', 'remember', 'R IY0 M EH1 M B ER0', '2', 'iy', '0', '368']
# ['remained', '24394', 'remained', 'R IY0 M EY1 N D', '2', 'iy', '0', '4']
# ['remained', '24394', 'remained', 'R AH0 M EY1 N D', '4', 'ey', '1', '3']
# ['spirits', '7292', 'spirits', 'S P IH1 R AH0 T S', '3', 'iyr', '1', '1']
# ['spirits', '7292', 'spirits', 'S P IY1 R AH0 T S', '3', 'iyr', '1', '2']
# ['thursday', '19456', 'thursday', 'TH ER1 Z D EY2', '2', '*hr', '1', '20']
# ['thursday', '19456', 'thursday', 'TH ER1 Z D IY0', '2', '*hr', '1', '37']
# ['covering', '11820', 'covering', 'K AH1 V ER0 IH0 NG', '2', 'uh', '1', '1']
# ['covering', '11820', 'covering', 'K AH1 V R IH0 NG', '2', 'uh', '1', '2']
# ['received', '46876', 'received', 'R AH0 S IY1 V D', '4', 'iy', '1', '7']
# ['received', '46876', 'received', 'R IY0 S IY1 V D', '4', 'iy', '1', '10']
# ['address', '39322', 'address', 'AE1 D R EH2 S', '1', 'ae', '1', '18']
# ['address', '39322', 'address', 'AH0 D R EH1 S', '4', 'e', '1', '13']
# ['gets', '60758', 'gets', 'G IH1 T S', '2', 'i', '1', '172']
# ['gets', '60758', 'gets', 'G EH1 T S', '2', 'e', '1', '75']
# ['lead', '61833', 'lead', 'L IY1 D', '2', 'iy', '1', '6']
# ['lead', '61833', 'lead', 'L EH1 D', '2', 'e', '1', '3']
# ['barry', '11981', 'barry', 'B EH1 R IY0', '2', 'e', '1', '6']
# ['barry', '11981', 'barry', 'B AE1 R IY0', '2', 'ae', '1', '3']
# ['em', '11160', 'em', 'AH0 M', '1', '@', '0', '134']
# ['em', '11160', 'em', 'EH1 M', '1', 'e', '1', '85']
# ['grandmother', '11525', 'grandmother', 'G R AE1 M AH2 DH ER0', '3', 'aeh', '1', '153']
# ['grandmother', '11525', 'grandmother', 'G R AE1 N M AH2 DH ER0', '3', 'aeh', '1', '88']
# ['huge', '47110', 'huge', 'HH Y UW1 JH', '3', 'uw', '1', '23']
# ['huge', '47110', 'huge', 'Y UW1 JH', '2', 'uw', '1', '19']
# ['prayers', '5000', 'prayers', 'P R EY1 ER0 Z', '4', '*hr', '0', '19']
# ['prayers', '5000', 'prayers', 'P R EH1 R Z', '3', 'e', '1', '11']
# ['casting', '5299', 'casting', 'K AE1 S T IH0 NG', '2', 'aeh', '1', '3']
# ['casting', '5299', 'casting', 'K AE1 S T AH0 N', '2', 'aeh', '1', '5']
# ['stronger', '14319', 'stronger', 'S T R AO1 NG G ER0', '4', 'oh', '1', '10']
# ['stronger', '14319', 'stronger', 'S T R AO1 NG ER0', '4', 'oh', '1', '17']
# ['below', '46150', 'below', 'B AH0 L OW1', '4', 'owF', '1', '11']
# ['below', '46150', 'below', 'B IY0 L OW1', '2', 'iy', '0', '11']
# ['traveling', '12338', 'traveling', 'T R AE1 V L AH0 N', '3', 'ae', '1', '6']
# ['traveling', '12338', 'traveling', 'T R AE1 V L IH0 NG', '3', 'ae', '1', '5']
# ['sunday', '39282', 'sunday', 'S AH1 N D IY2', '2', 'uh', '1', '61']
# ['sunday', '39282', 'sunday', 'S AH1 N D EY2', '2', 'uh', '1', '119']
# ['relief', '20860', 'relief', 'R AH0 L IY1 F', '4', 'iy', '1', '7']
# ['relief', '20860', 'relief', 'R IY0 L IY1 F', '2', 'iy', '0', '9']
# ['remembering', '5852', 'remembering', 'R AH0 M EH1 M B ER0 IH0 NG', '4', 'e', '1', '2']
# ['remembering', '5852', 'remembering', 'R IY0 M EH1 M B ER0 IH0 NG', '4', 'e', '1', '2']
# ['often', '151839', 'often', 'AO1 F T AH0 N', '1', 'oh', '1', '32']
# ['often', '151839', 'often', 'AO1 F AH0 N', '1', 'oh', '1', '49']
# ['outspoken', '2033', 'outspoken', 'AW1 BR SP T S P T OW1 R AH1 K S T AH0 N M IY1', '1', 'aw', '1', '1']
# ['outspoken', '2033', 'outspoken', 'AW1 T S P OW1 K AH0 N', '1', 'aw', '1', '1']
# ['disappeared', '12994', 'disappeared', 'D IH2 S AH0 P IY1 R D', '6', 'iyr', '1', '9']
# ['disappeared', '12994', 'disappeared', 'D IH2 S AH0 P IH1 R D', '6', 'iyr', '1', '4']
# ['prayer', '12824', 'prayer', 'P R EH1 R', '3', 'e', '1', '17']
# ['prayer', '12824', 'prayer', 'P R EY1 ER0', '3', 'ey', '1', '10']
# ['circling', '2151', 'circling', 'S ER1 K L IH0 NG', '2', '*hr', '1', '1']
# ['circling', '2151', 'circling', 'S ER1 K AH0 L IH0 NG', '2', '*hr', '1', '2']
# ['earrings', '2761', 'earrings', 'IY1 R IH0 NG Z', '1', 'iyr', '1', '7']
# ['earrings', '2761', 'earrings', 'IH1 R IH0 NG Z', '1', 'iyr', '1', '6']
# ['graduated', '6497', 'graduated', 'G R AE1 JH UW0 EY2 T AH0 D', '3', 'ae', '1', '95']
# ['graduated', '6497', 'graduated', 'G R AE1 JH AH0 W EY2 T AH0 D', '3', 'ae', '1', '42']
# ['groceries', '2634', 'groceries', 'G R OW1 S ER0 IY0 Z', '3', 'ow', '1', '4']
# ['groceries', '2634', 'groceries', 'G R OW1 S R IY0 Z', '3', 'ow', '1', '7']
# ['frying', '2037', 'frying', 'F R AY1 IH0 NG', '3', 'ay', '1', '3']
# ['frying', '2037', 'frying', 'F R AY1 AH0 N', '3', 'ay', '1', '3']
# ['became', '85178', 'became', 'B IH0 K EY1 M', '4', 'ey', '1', '74']
# ['became', '85178', 'became', 'B IY0 K EY1 M', '4', 'ey', '1', '47']
# ['anxious', '7501', 'anxious', 'AE1 NG K SH AH0 S', '1', 'ae', '1', '4']
# ['anxious', '7501', 'anxious', 'AE1 NG SH AH0 S', '1', 'ae', '1', '2']
# ['require', '29774', 'require', 'R IH0 K W AY1 ER0', '5', 'ay', '1', '2']
# ['require', '29774', 'require', 'R IY2 K W AY1 ER0', '2', 'iy', '2', '1']
# ['entered', '20563', 'entered', 'EH1 N ER0 D', '1', 'e', '1', '2']
# ['entered', '20563', 'entered', 'EH1 N T ER0 D', '1', 'e', '1', '2']
# ['general', '111374', 'general', 'JH EH1 N R AH0 L', '2', 'e', '1', '31']
# ['general', '111374', 'general', 'JH EH1 N ER0 AH0 L', '2', 'e', '1', '21']
# ['bringing', '20795', 'bringing', 'B R IH1 NG IH0 NG', '3', 'i', '1', '1']
# ['bringing', '20795', 'bringing', 'B R IH1 NG AH0 N', '5', '@', '0', '2']
# ['beard', '5838', 'beard', 'B IH1 R D', '2', 'iyr', '1', '8']
# ['beard', '5838', 'beard', 'B IY1 R D', '2', 'iyr', '1', '5']
# ['integrated', '9557', 'integrated', 'IH1 N AH0 G R EY2 T AH0 D', '6', 'ey', '2', '8']
# ['integrated', '9557', 'integrated', 'IH1 N T AH0 G R EY2 T AH0 D', '7', 'ey', '2', '5']
# ['rattling', '1725', 'rattling', 'R AE1 T AH0 L IH0 NG', '2', 'ae', '1', '1']
# ['rattling', '1725', 'rattling', 'R AE1 T L IH0 NG', '2', 'ae', '1', '1']
# ['monday', '24556', 'monday', 'M AH1 N D EY2', '2', 'uh', '1', '21']
# ['monday', '24556', 'monday', 'M AH1 N D IY0', '5', 'iyF', '0', '45']
# ['staring', '14681', 'staring', 'S T EH1 R IH0 NG', '3', 'e', '1', '2']
# ['staring', '14681', 'staring', 'S T EH1 R AH0 N', '3', 'e', '1', '2']
# ['polish', '6765', 'polish', 'P AA1 L IH0 SH', '2', 'o', '1', '29']
# ['polish', '6765', 'polish', 'P OW1 L IH0 SH', '2', 'ow', '1', '40']
# ['located', '16670', 'located', 'L OW1 K EY2 T AH0 D', '2', 'ow', '1', '6']
# ['located', '16670', 'located', 'L OW1 K EY2 D', '4', 'ey', '2', '11']
# ['series', '59352', 'series', 'S IY1 R IY0 Z', '2', 'iyr', '1', '5']
# ['series', '59352', 'series', 'S IH1 R IY0 Z', '2', 'iyr', '1', '3']
# ['response', '50884', 'response', 'R IY0 S P AA1 N S', '5', 'o', '1', '2']
# ['response', '50884', 'response', 'R AH0 S P AA1 N S', '5', 'o', '1', '3']
# ['due', '37806', 'due', 'D UW1', '2', 'Tuw', '1', '17']
# ['due', '37806', 'due', 'D Y UW1', '3', 'uw', '1', '8']
# ['stopping', '7979', 'stopping', 'S T AA1 P IH0 NG', '3', 'o', '1', '7']
# ['stopping', '7979', 'stopping', 'S T AA1 P AH0 N', '3', 'o', '1', '3']
# ['directly', '36473', 'directly', 'D IH0 R EH1 K L IY0', '4', 'e', '1', '5']
# ['directly', '36473', 'directly', 'D ER0 EH1 K T L IY0', '2', '*hr', '0', '7']
# ['weekend', '31069', 'weekend', 'W IY1 K IH2 N D', '2', 'iy', '1', '58']
# ['weekend', '31069', 'weekend', 'W IY1 K EH2 N D', '2', 'iy', '1', '56']
# ['creek', '15934', 'creek', 'K R IY1 K', '3', 'iy', '1', '1']
# ['creek', '15934', 'creek', 'K R IH1 K', '3', 'i', '1', '1']
# ['gradually', '11234', 'gradually', 'G R AE1 JH UW0 AH0 L IY0', '8', 'iyF', '0', '2']
# ['gradually', '11234', 'gradually', 'G R AE1 JH UW0 L IY0', '3', 'ae', '1', '4']
# ['increased', '40986', 'increased', 'IH1 N K R IY2 S T', '1', 'i', '1', '2']
# ['increased', '40986', 'increased', 'IH2 N K R IY1 S T', '5', 'iy', '1', '3']
# ['counted', '7735', 'counted', 'K AW1 N AH0 D', '2', 'aw', '1', '9']
# ['counted', '7735', 'counted', 'K AW1 N T AH0 D', '2', 'aw', '1', '5']
# ['realizing', '5025', 'realizing', 'R IY1 AH0 L AY2 Z IH0 NG', '5', 'ay', '2', '2']
# ['realizing', '5025', 'realizing', 'R IY1 L AY2 Z IH0 NG', '4', 'ay', '2', '4']
# ['evolved', '7020', 'evolved', 'IY0 V AA1 L V D', '1', 'iy', '0', '2']
# ['evolved', '7020', 'evolved', 'IH0 V AA1 L V D', '1', 'i', '0', '1']
# ['causing', '10433', 'causing', 'K AA1 Z IH0 NG', '2', 'o', '1', '1']
# ['causing', '10433', 'causing', 'K AO1 Z IH0 NG', '2', 'oh', '1', '1']
# ['entertained', '1681', 'entertained', 'EH2 N T ER0 T EY1 N D', '1', 'e', '2', '1']
# ['entertained', '1681', 'entertained', 'EH2 N ER0 T EY1 N D', '1', 'e', '2', '2']
# ['howling', '1602', 'howling', 'HH AW1 L IH0 NG', '2', 'aw', '1', '1']
# ['howling', '1602', 'howling', 'HH AW1 L AH0 N', '2', 'aw', '1', '1']
# ['casual', '7462', 'casual', 'K AE1 ZH W AH0 L', '2', 'ae', '1', '5']
# ['casual', '7462', 'casual', 'K AE1 ZH AH0 W AH0 L', '2', 'ae', '1', '3']
# ['raining', '2017', 'raining', 'R EY1 N IH0 NG', '2', 'ey', '1', '7']
# ['raining', '2017', 'raining', 'R EY1 N AH0 N', '2', 'ey', '1', '3']
# ['somebody', '41744', 'somebody', 'S AH1 M B AA2 D IY0', '5', 'o', '2', '434']
# ['somebody', '41744', 'somebody', 'S AH1 M B AH0 D IY0', '7', 'iyF', '0', '189']
# ['nobody', '33732', 'nobody', 'N OW1 B AH0 D IY0', '2', 'ow', '1', '211']
# ['nobody', '33732', 'nobody', 'N OW1 B AA2 D IY2', '4', 'o', '2', '209']
# ['hours', '93763', 'hours', 'AW1 R Z', '1', 'aw', '1', '67']
# ['hours', '93763', 'hours', 'AW1 ER0 Z', '1', 'aw', '1', '124']
# ['regular', '29529', 'regular', 'R EY1 G Y AH0 L ER0', '2', 'ey', '1', '37']
# ['regular', '29529', 'regular', 'R EH1 G Y AH0 L ER0', '2', 'e', '1', '59']
# ['respect', '35709', 'respect', 'R AH0 S P EH1 K T', '5', 'e', '1', '49']
# ['respect', '35709', 'respect', 'R IY0 S P EH1 K T', '5', 'e', '1', '74']
# ['natural', '60294', 'natural', 'N AE1 CH R AH0 L', '2', 'ae', '1', '11']
# ['natural', '60294', 'natural', 'N AE1 CH ER0 AH0 L', '2', 'ae', '1', '11']
# ['monument', '4680', 'monument', 'M AA1 N Y AH0 M AH0 N T', '2', 'o', '1', '1']
# ['monument', '4680', 'monument', 'M AA1 N Y UW0 M AH0 N T', '2', 'o', '1', '1']
# ['retirement', '14701', 'retirement', 'R AH0 T AY1 ER0 M AH0 N T', '4', 'ay', '1', '5']
# ['retirement', '14701', 'retirement', 'R IY0 T AY1 ER0 M AH0 N T', '2', 'iy', '0', '7']
# ['receiving', '12725', 'receiving', 'R AH0 S IY1 V IH0 NG', '4', 'iy', '1', '1']
# ['receiving', '12725', 'receiving', 'R IY0 S IY1 V IH0 NG', '2', 'iy', '0', '1']
# ['respectable', '2652', 'respectable', 'R IY0 S P EH1 K T AH0 B AH0 L', '5', 'e', '1', '4']
# ['respectable', '2652', 'respectable', 'R AH0 S P EH1 K T AH0 B AH0 L', '5', 'e', '1', '4']
# ['enjoy', '24301', 'enjoy', 'AH0 N JH OY1', '4', 'oy', '1', '79']
# ['enjoy', '24301', 'enjoy', 'EH0 N JH OY1', '4', 'oy', '1', '38']
# ['history', '119059', 'history', 'HH IH1 S T R IY0', '2', 'i', '1', '15']
# ['history', '119059', 'history', 'HH IH1 S T ER0 IY0', '5', '*hr', '0', '34']
# ['event', '37262', 'event', 'IH0 V EH1 N T', '3', 'e', '1', '8']
# ['event', '37262', 'event', 'IY0 V EH1 N T', '1', 'iy', '0', '4']
# ['question', '136775', 'question', 'K W EH1 S CH AH0 N', '3', 'e', '1', '23']
# ['question', '136775', 'question', 'K W EH1 SH AH0 N', '3', 'e', '1', '30']
# ['prefer', '12194', 'prefer', 'P R AH0 F ER1', '5', '*hr', '1', '8']
# ['prefer', '12194', 'prefer', 'P R IY0 F ER1', '3', 'iy', '0', '4']
# ['terrorists', '10296', 'terrorists', 'T EH1 R ER0 IH2 S', '4', '*hr', '0', '1']
# ['terrorists', '10296', 'terrorists', 'T EH1 R ER0 IH2 S T S', '4', '*hr', '0', '1']
# ["here's", '31352', "here's", 'HH IY1 R Z', '2', 'iyr', '1', '32']
# ["here's", '31352', "here's", 'HH IH1 R Z', '2', 'iyr', '1', '22']
# ['liberal', '20289', 'liberal', 'L IH1 B ER0 AH0 L', '2', 'i', '1', '7']
# ['liberal', '20289', 'liberal', 'L IH1 B R AH0 L', '2', 'i', '1', '11']
# ['horror', '7786', 'horror', 'HH AO1 R ER0', '2', 'owr', '1', '2']
# ['horror', '7786', 'horror', 'HH AA1 R ER0', '4', '*hr', '0', '1']
# ['protests', '6221', 'protests', 'P R AH0 T EH1 S', '3', '@', '0', '1']
# ['protests', '6221', 'protests', 'P R OW1 T EH2 S', '3', 'ow', '1', '2']
# ['diary', '4762', 'diary', 'D AY1 ER0 IY0', '2', 'ay', '1', '1']
# ['diary', '4762', 'diary', 'D AY1 R IY0', '2', 'ay', '1', '1']
# ['reasonable', '14069', 'reasonable', 'R IY1 Z N AH0 B AH0 L', '2', 'iy', '1', '2']
# ['reasonable', '14069', 'reasonable', 'R IY1 Z AH0 N AH0 B AH0 L', '2', 'iy', '1', '1']
# ['interested', '32045', 'interested', 'IH1 N T R AH0 S T AH0 D', '1', 'i', '1', '20']
# ['interested', '32045', 'interested', 'IH1 N T ER0 AH0 S T AH0 D', '1', 'i', '1', '16']
# ['usual', '20387', 'usual', 'Y UW1 ZH UW0 AH0 L', '2', 'uw', '1', '1']
# ['usual', '20387', 'usual', 'Y UW1 ZH AH0 W AH0 L', '2', 'uw', '1', '1']
# ['sundays', '3705', 'sundays', 'S AH1 N D IY2 Z', '2', 'uh', '1', '10']
# ['sundays', '3705', 'sundays', 'S AH1 N D EY2 Z', '2', 'uh', '1', '12']
# ['discussing', '8137', 'discussing', 'D IH2 S K AH1 S IH0 NG', '5', 'uh', '1', '2']
# ['discussing', '8137', 'discussing', 'D IH2 S K AH1 S AH0 N', '2', 'i', '2', '1']
# ['impact', '44318', 'impact', 'IH1 M P AE0 K T', '1', 'i', '1', '2']
# ['impact', '44318', 'impact', 'IH2 M P AE1 K T', '1', 'i', '2', '1']
# ['automatic', '7237', 'automatic', 'AO2 T OW0 M AE1 T IH0 K', '5', 'ae', '1', '2']
# ['automatic', '7237', 'automatic', 'AO2 T AH0 M AE1 T IH0 K', '1', 'oh', '2', '2']
# ['carol', '9264', 'carol', 'K EH1 R AH0 L', '2', 'e', '1', '9']
# ['carol', '9264', 'carol', 'K AE1 R AH0 L', '2', 'ae', '1', '5']
# ['actually', '117670', 'actually', 'AE1 K SH L IY0', '1', 'ae', '1', '299']
# ['actually', '117670', 'actually', 'AE1 K CH L IY0', '1', 'ae', '1', '187']
# ['national', '181038', 'national', 'N AE1 SH AH0 N AH0 L', '2', 'ae', '1', '9']
# ['national', '181038', 'national', 'N AE1 SH N AH0 L', '2', 'ae', '1', '19']
# ['cameras', '11674', 'cameras', 'K AE1 M ER0 AH0 Z', '2', 'aeh', '1', '5']
# ['cameras', '11674', 'cameras', 'K AE1 M R AH0 Z', '2', 'aeh', '1', '3']
# ['originally', '11834', 'originally', 'ER0 IH1 JH N AH0 L IY0', '1', '*hr', '0', '25']
# ['originally', '11834', 'originally', 'ER0 IH1 JH AH0 N AH0 L IY0', '8', 'iyF', '0', '13']
# ['emerged', '14243', 'emerged', 'IY1 M ER0 JH D', '3', '*hr', '0', '1']
# ['emerged', '14243', 'emerged', 'IH2 M ER1 JH D', '3', '*hr', '1', '1']
# ['opposite', '22035', 'opposite', 'AA1 P AH0 Z AH0 T', '1', 'o', '1', '21']
# ['opposite', '22035', 'opposite', 'AA1 P Z AH0 T', '1', 'o', '1', '11']
# ['de', '68909', 'de', 'D EY1', '2', 'eyF', '1', '1']
# ['de', '68909', 'de', 'D IY1', '2', 'iyF', '1', '1']
# ['de', '68909', 'de', 'D AH0', '2', '@', '0', '1']
# ['dental', '3028', 'dental', 'D EH1 N T AH0 L', '2', 'e', '1', '2']
# ['dental', '3028', 'dental', 'D EH1 N AH0 L', '2', 'e', '1', '1']
# ['superior', '10257', 'superior', 'S UW0 P IY1 R IY0 ER0', '4', 'iyr', '1', '3']
# ['superior', '10257', 'superior', 'S UW0 P IH1 R IY0 ER0', '4', 'iyr', '1', '3']
# ['kong', '9137', 'kong', 'K AA1 NG', '2', 'o', '1', '3']
# ['kong', '9137', 'kong', 'K AO1 NG G', '2', 'oh', '1', '3']
# ['hundreds', '30528', 'hundreds', 'HH AH1 N ER0 D Z', '2', 'uh', '1', '11']
# ['hundreds', '30528', 'hundreds', 'HH AH1 N D ER0 D Z', '5', '*hr', '0', '16']
# ['naturally', '12143', 'naturally', 'N AE1 CH ER0 AH0 L IY0', '2', 'ae', '1', '35']
# ['naturally', '12143', 'naturally', 'N AE1 CH R AH0 L IY0', '2', 'ae', '1', '42']
# ['restaurants', '12933', 'restaurants', 'R EH1 S T ER0 AA2 N T S', '2', 'e', '1', '11']
# ['restaurants', '12933', 'restaurants', 'R EH1 S T R AA2 N T S', '6', 'o', '2', '12']
# ['automobiles', '2263', 'automobiles', 'AO1 T AH0 M OW0 B IY2 L Z', '5', 'ow', '0', '2']
# ['automobiles', '2263', 'automobiles', 'AO2 T AH0 M OW0 B IY1 L Z', '7', 'iy', '1', '4']
# ['enroll', '1751', 'enroll', 'EH0 N R OW1 L', '1', 'e', '0', '1']
# ['enroll', '1751', 'enroll', 'AH0 N R OW1 L', '4', 'ow', '1', '1']
# ['enjoyed', '13161', 'enjoyed', 'AH0 N JH OY1 D', '4', 'oy', '1', '24']
# ['enjoyed', '13161', 'enjoyed', 'EH0 N JH OY1 D', '4', 'oy', '1', '29']
# ['average', '55321', 'average', 'AE1 V R IH0 JH', '1', 'ae', '1', '23']
# ['average', '55321', 'average', 'AE1 V ER0 IH0 JH', '1', 'ae', '1', '11']
# ['result', '65126', 'result', 'R IY0 Z AH1 L T', '2', 'iy', '0', '3']
# ['result', '65126', 'result', 'R AH0 Z AH1 L T', '4', 'uh', '1', '2']
# ['counting', '8074', 'counting', 'K AW1 N IH0 NG', '2', 'aw', '1', '4']
# ['counting', '8074', 'counting', 'K AW1 N AH0 N', '2', 'aw', '1', '3']
# ['whistle', '3178', 'whistle', 'HH W IH1 S AH0 L', '3', 'i', '1', '1']
# ['whistle', '3178', 'whistle', 'W IH1 S AH0 L', '4', '@', '0', '2']
# ['elementary', '15139', 'elementary', 'EH2 L AH0 M EH1 N CH R IY0', '5', 'e', '1', '19']
# ['elementary', '15139', 'elementary', 'EH2 L AH0 M EH1 N T R IY0', '9', 'iyF', '0', '12']
# ['friendship', '8303', 'friendship', 'F R EH1 N SH IH2 P', '3', 'e', '1', '5']
# ['friendship', '8303', 'friendship', 'F R EH1 N D SH IH2 P', '3', 'e', '1', '3']
# ['remembered', '18527', 'remembered', 'R IY0 M EH1 M B ER0 D', '2', 'iy', '0', '13']
# ['remembered', '18527', 'remembered', 'R AH0 M EH1 M B ER0 D', '4', 'e', '1', '11']
# ['repeating', '3314', 'repeating', 'R AH0 P IY1 T IH0 NG', '2', '@', '0', '1']
# ['repeating', '3314', 'repeating', 'R IY0 P IY1 T IH0 NG', '2', 'iy', '0', '2']
# ['research', '136195', 'research', 'R IY0 S ER1 CH', '4', '*hr', '1', '4']
# ['research', '136195', 'research', 'R IY1 S ER0 CH', '2', 'iy', '1', '4']
# ['tourists', '8551', 'tourists', 'T UH1 R IH2 S T S', '4', 'i', '2', '1']
# ['tourists', '8551', 'tourists', 'T UH1 R IH2 S', '2', 'uwr', '1', '1']
# ['umbrella', '3633', 'umbrella', 'AH0 M B R EH1 L AH0', '1', '@', '0', '5']
# ['umbrella', '3633', 'umbrella', 'AH1 M B R EH2 L AH0', '1', 'uh', '1', '6']
# ['advocate', '7300', 'advocate', 'AE1 D V AH0 K AH0 T', '1', 'ae', '1', '1']
# ['advocate', '7300', 'advocate', 'AE1 D V AH0 K EY2 T', '1', 'ae', '1', '1']
# ['concepts', '11455', 'concepts', 'K AA1 N S EH0 P T S', '2', 'o', '1', '1']
# ['concepts', '11455', 'concepts', 'K AA1 N S EH0 P S', '2', 'o', '1', '1']
# ['grandchildren', '5225', 'grandchildren', 'G R AE1 N D CH IH2 L D R AH0 N', '3', 'aeh', '1', '14']
# ['grandchildren', '5225', 'grandchildren', 'G R AE1 N CH IH2 L D R AH0 N', '3', 'aeh', '1', '24']
# ['adults', '24908', 'adults', 'AH0 D AH1 L T S', '3', 'uh', '1', '13']
# ['adults', '24908', 'adults', 'AE1 D AH0 L T S', '1', 'ae', '1', '6']
# ['elaborate', '7112', 'elaborate', 'AH0 L AE1 B ER0 EY2 T', '3', 'ae', '1', '2']
# ['elaborate', '7112', 'elaborate', 'AH0 L AE1 B R AH0 T', '3', 'ae', '1', '2']
# ['alexandra', '1368', 'alexandra', 'AE2 L AH0 G Z AE1 N D R AH0', '1', 'NA', '2', '1']
# ['alexandra', '1368', 'alexandra', 'AE2 L IH0 G Z AE1 N D R AH0', '1', 'NA', '2', '1']
# ['protest', '10680', 'protest', 'P R AH0 T EH1 S T', '5', 'e', '1', '2']
# ['protest', '10680', 'protest', 'P R OW1 T EH2 S T', '3', 'ow', '1', '3']
# ['jewelry', '7238', 'jewelry', 'JH UW1 L R IY0', '2', 'uw', '1', '10']
# ['jewelry', '7238', 'jewelry', 'JH UW1 L ER0 IY0', '2', 'uw', '1', '8']
# ['directed', '15099', 'directed', 'D IH0 R EH1 K T AH0 D', '4', 'e', '1', '2']
# ['directed', '15099', 'directed', 'D ER0 EH1 K T AH0 D', '2', '*hr', '0', '1']
# ["mothers'", '842', "mothers'", 'M AH1 AY1 TH ER0 Z', '2', 'uh', '1', '1']
# ["mothers'", '842', "mothers'", 'M AH1 TH ER0 Z', '4', '*hr', '0', '2']
# ['apprehensive', '875', 'apprehensive', 'AE2 P R IY0 HH EH1 N S IH0 V', '1', 'NA', '2', '1']
# ['apprehensive', '875', 'apprehensive', 'AE2 P R AH0 HH EH1 N S IH0 V', '1', 'NA', '2', '1']
# ['difference', '49769', 'difference', 'D IH1 F R AH0 N S', '2', 'i', '1', '56']
# ['difference', '49769', 'difference', 'D IH1 F ER0 AH0 N S', '2', 'i', '1', '35']
# ['repaired', '1868', 'repaired', 'R IY0 P EH1 R D', '2', 'iy', '0', '1']
# ['repaired', '1868', 'repaired', 'R AH0 P EH1 R D', '4', 'e', '1', '1']
# ['tearing', '3161', 'tearing', 'T EH1 R IH0 NG', '2', 'e', '1', '2']
# ['tearing', '3161', 'tearing', 'T IH1 R IH0 NG', '2', 'iyr', '1', '2']
# ['reports', '44278', 'reports', 'R AH0 P AO1 R T S', '4', 'owr', '1', '2']
# ['reports', '44278', 'reports', 'R IY0 P AO1 R T S', '2', 'iy', '0', '2']
# ['disappear', '7161', 'disappear', 'D IH2 S AH0 P IH1 R', '6', 'iyr', '1', '2']
# ['disappear', '7161', 'disappear', 'D IH2 S AH0 P IY1 R', '2', 'i', '2', '1']
# ['remaining', '22902', 'remaining', 'R AH0 M EY1 N IH0 NG', '4', 'ey', '1', '2']
# ['remaining', '22902', 'remaining', 'R IY0 M EY1 N IH0 NG', '2', 'iy', '0', '1']
# ['blocking', '4118', 'blocking', 'B L AA1 K IH0 NG', '3', 'o', '1', '1']
# ['blocking', '4118', 'blocking', 'B L AA1 K AH0 N', '3', 'o', '1', '1']
# ['adjusting', '3057', 'adjusting', 'AH0 JH AH1 S T IH0 NG', '1', '@', '0', '1']
# ['adjusting', '3057', 'adjusting', 'AH0 JH AH1 S T AH0 N', '3', 'uh', '1', '1']
# ['events', '44666', 'events', 'IY0 V EH1 N T S', '3', 'e', '1', '6']
# ['events', '44666', 'events', 'IH0 V EH1 N T S', '3', 'e', '1', '10']
# ['carrying', '19651', 'carrying', 'K AE1 R IY0 IH0 NG', '2', 'ae', '1', '6']
# ['carrying', '19651', 'carrying', 'K EH1 R IY0 IH0 NG', '2', 'e', '1', '6']
# ['realize', '27982', 'realize', 'R IY1 AH0 L AY2 Z', '5', 'ay', '2', '25']
# ['realize', '27982', 'realize', 'R IY1 L AY2 Z', '4', 'ay', '2', '50']
# ['interesting', '41515', 'interesting', 'IH1 N T R AH0 S T AH0 N', '1', 'i', '1', '33']
# ['interesting', '41515', 'interesting', 'IH1 N T ER0 AH0 S T IH0 NG', '1', 'i', '1', '27']
# ['remembers', '9419', 'remembers', 'R AH0 M EH1 M B ER0 Z', '4', 'e', '1', '6']
# ['remembers', '9419', 'remembers', 'R IY0 M EH1 M B ER0 Z', '2', 'iy', '0', '3']
# ['sandwiches', '3900', 'sandwiches', 'S AE1 M W IH0 CH AH0 Z', '2', 'aeh', '1', '6']
# ['sandwiches', '3900', 'sandwiches', 'S AE1 N W IH0 CH AH0 Z', '2', 'aeh', '1', '8']
# ['herb', '3914', 'herb', 'ER1 B', '1', '*hr', '1', '1']
# ['herb', '3914', 'herb', 'HH ER1 B', '2', '*hr', '1', '1']
# ['polka', '531', 'polka', 'P OW1 K AH0', '2', 'ow', '1', '2']
# ['polka', '531', 'polka', 'P OW1 L K AH0', '2', 'ow', '1', '1']
# ['camera', '36858', 'camera', 'K AE1 M R AH0', '2', 'NA', '1', '11']
# ['camera', '36858', 'camera', 'K AE1 M ER0 AH0', '2', 'NA', '1', '20']
# ['dentist', '2303', 'dentist', 'D EH1 N AH0 S T', '2', 'e', '1', '7']
# ['dentist', '2303', 'dentist', 'D EH1 N T AH0 S T', '2', 'e', '1', '3']
# ['arrow', '3596', 'arrow', 'AE1 R OW0', '1', 'ae', '1', '1']
# ['arrow', '3596', 'arrow', 'EH1 R OW0', '1', 'e', '1', '1']
# ['forest', '30448', 'forest', 'F AO1 R AH0 S T', '2', 'owr', '1', '5']
# ['forest', '30448', 'forest', 'F AA1 R AH0 S T', '2', 'ahr', '1', '6']
# ['seriously', '19969', 'seriously', 'S IY1 R IY0 AH0 S L IY0', '2', 'iyr', '1', '9']
# ['seriously', '19969', 'seriously', 'S IH1 R IY0 AH0 S L IY0', '2', 'iyr', '1', '5']
# ['complaining', '4454', 'complaining', 'K AH0 M P L EY1 N IH0 NG', '6', 'ey', '1', '9']
# ['complaining', '4454', 'complaining', 'K AH0 M P L EY1 N AH0 N', '6', 'ey', '1', '4']
# ['generally', '35264', 'generally', 'JH EH1 N ER0 AH0 L IY0', '2', 'e', '1', '14']
# ['generally', '35264', 'generally', 'JH EH1 N R AH0 L IY0', '2', 'e', '1', '9']
# ['data', '88305', 'data', 'D EY1 T AH0', '2', 'ey', '1', '6']
# ['data', '88305', 'data', 'D AE1 T AH0', '2', 'ae', '1', '3']
# ['respected', '6672', 'respected', 'R IY0 S P EH1 K T AH0 D', '5', 'e', '1', '8']
# ['respected', '6672', 'respected', 'R AH0 S P EH1 K T AH0 D', '5', 'e', '1', '4']
# ['deliberate', '4020', 'deliberate', 'D AH0 L IH1 B ER0 EY2 T', '6', '*hr', '0', '2']
# ['deliberate', '4020', 'deliberate', 'D AH0 L IH1 B ER0 AH0 T', '2', '@', '0', '1']
# ['vehicle', '17884', 'vehicle', 'V IY1 IH0 K AH0 L', '2', 'iy', '1', '1']
# ['vehicle', '17884', 'vehicle', 'V IY1 HH IH0 K AH0 L', '2', 'iy', '1', '1']
# ['mirrors', '4296', 'mirrors', 'M IY1 R ER0 Z', '4', '*hr', '0', '2']
# ['mirrors', '4296', 'mirrors', 'M IH1 R ER0 Z', '4', '*hr', '0', '1']
# ['irritate', '519', 'irritate', 'IY1 R AH0 T EY2 T', '1', 'iyr', '1', '1']
# ['irritate', '519', 'irritate', 'IH1 R AH0 T EY2 T', '1', 'iyr', '1', '2']
# ['plaza', '5423', 'plaza', 'P L AE1 Z AH0', '3', 'ae', '1', '1']
# ['plaza', '5423', 'plaza', 'P L AA1 Z AH0', '3', 'o', '1', '1']
# ['erasers', '146', 'erasers', 'IH0 R EY1 S ER0 Z', '5', '*hr', '0', '1']
# ['erasers', '146', 'erasers', 'IY0 R EY1 S ER0 Z', '3', 'ey', '1', '1']
# ['recess', '2147', 'recess', 'R IY1 S EH0 S', '2', 'iy', '1', '7']
# ['recess', '2147', 'recess', 'R AH0 S EH1 S', '4', 'e', '1', '6']
# ['boundaries', '9123', 'boundaries', 'B AW1 N D R IY0 Z', '2', 'aw', '1', '8']
# ['boundaries', '9123', 'boundaries', 'B AW1 N D ER0 IY0 Z', '2', 'aw', '1', '11']
# ['intimidating', '1930', 'intimidating', 'IH2 N T IH1 M AH0 D EY2 T AH0 N', '1', 'i', '2', '2']
# ['intimidating', '1930', 'intimidating', 'IH2 N T IH1 M AH0 D EY2 T IH0 NG', '8', 'ey', '2', '1']
# ['romance', '6812', 'romance', 'R OW0 M AE1 N S', '2', 'ow', '0', '1']
# ['romance', '6812', 'romance', 'R OW1 M AE0 N S', '4', 'aeh', '0', '2']
# ['weirdo', '200', 'weirdo', 'W IH1 R D OW0', '5', 'owF', '0', '1']
# ['weirdo', '200', 'weirdo', 'W IY1 R D OW0', '2', 'iyr', '1', '1']
# ['tuesday', '21382', 'tuesday', 'T UW1 Z D EY2', '2', 'Tuw', '1', '18']
# ['tuesday', '21382', 'tuesday', 'T UW1 Z D IY0', '2', 'Tuw', '1', '31']
# ['relax', '7052', 'relax', 'R IY0 L AE1 K S', '4', 'ae', '1', '7']
# ['relax', '7052', 'relax', 'R AH0 L AE1 K S', '4', 'ae', '1', '4']
# ['ireland', '7539', 'ireland', 'AY1 R L AH0 N D', '1', 'ay', '1', '23']
# ['ireland', '7539', 'ireland', 'AY1 ER0 L AH0 N D', '1', 'ay', '1', '18']
# ['retiring', '2857', 'retiring', 'R AH0 T AY1 R IH0 NG', '4', 'ay', '1', '2']
# ['retiring', '2857', 'retiring', 'R IY0 T AY1 ER0 IH0 NG', '2', 'iy', '0', '2']
# ['struggling', '12044', 'struggling', 'S T R AH1 G L IH0 NG', '4', 'uh', '1', '3']
# ['struggling', '12044', 'struggling', 'S T R AH1 G L AH0 N', '4', 'uh', '1', '4']
# ['horrendous', '1117', 'horrendous', 'HH AO2 R EH1 N D AH0 S', '2', 'owr', '2', '1']
# ['horrendous', '1117', 'horrendous', 'HH ER0 R EH1 N D AH0 S', '4', 'e', '1', '1']
# ['grandsons', '405', 'grandsons', 'G R AE1 N S AH2 N Z', '3', 'aeh', '1', '3']
# ['grandsons', '405', 'grandsons', 'G R AE1 N D S AH2 N Z', '3', 'aeh', '1', '2']
# ['religious', '49279', 'religious', 'R AH0 L IH1 JH AH0 S', '6', '@', '0', '13']
# ['religious', '49279', 'religious', 'R IY0 L IH1 JH AH0 S', '2', 'iy', '0', '17']
# ['grandson', '2686', 'grandson', 'G R AE1 N D S AH2 N', '3', 'aeh', '1', '7']
# ['grandson', '2686', 'grandson', 'G R AE1 N S AH2 N', '3', 'aeh', '1', '14']
# ['recorder', '2754', 'recorder', 'R IY0 K AO1 R D ER0', '2', 'iy', '0', '6']
# ['recorder', '2754', 'recorder', 'R IH0 K AO1 R D ER0', '4', 'owr', '1', '3']
# ['survey', '30930', 'survey', 'S ER0 V EY1', '2', '*hr', '0', '7']
# ['survey', '30930', 'survey', 'S ER1 V EY2', '2', '*hr', '1', '3']
# ['complains', '1640', 'complains', 'SH K AH0 IY1 M P SP T L ER1 EY1 N N D Z', '4', 'iy', '1', '1']
# ['complains', '1640', 'complains', 'K AH0 M P L EY1 N Z', '6', 'ey', '1', '2']
# ['peer', '9854', 'peer', 'P IH1 R', '2', 'iyr', '1', '1']
# ['peer', '9854', 'peer', 'P IY1 R', '2', 'iyr', '1', '2']
# ['juan', '7605', 'juan', 'HH W AA1 N', '3', 'o', '1', '1']
# ['juan', '7605', 'juan', 'W AA1 N', '2', 'o', '1', '1']
# ['rely', '10312', 'rely', 'R IY0 L AY1', '2', 'iy', '0', '2']
# ['rely', '10312', 'rely', 'R AH0 L AY1', '4', 'ay', '1', '1']
# ['intimate', '7461', 'intimate', 'IH1 N T AH0 M AH0 T', '1', 'i', '1', '2']
# ['intimate', '7461', 'intimate', 'IH1 N AH0 M AH0 T', '5', '@', '0', '1']
# ['honestly', '5788', 'honestly', 'AA1 N AH0 S T L IY0', '1', 'o', '1', '9']
# ['honestly', '5788', 'honestly', 'AA1 N AH0 S L IY0', '1', 'o', '1', '7']
# ['moral', '28480', 'moral', 'M AO1 R AH0 L', '2', 'owr', '1', '5']
# ['moral', '28480', 'moral', 'M AA1 R AH0 L', '2', 'ahr', '1', '4']
# ['acquainted', '1386', 'acquainted', 'AH0 K W EY1 N AH0 D', '4', 'ey', '1', '2']
# ['acquainted', '1386', 'acquainted', 'AH0 K W EY1 N T AH0 D', '1', '@', '0', '1']
# ['procedures', '16208', 'procedures', 'P R AH0 S IY1 JH ER0 Z', '5', 'iy', '1', '1']
# ['procedures', '16208', 'procedures', 'P R OW0 S IY1 JH ER0 Z', '5', 'iy', '1', '1']
# ['enormous', '18547', 'enormous', 'AH0 N AO1 R M AH0 S', '3', 'owr', '1', '7']
# ['enormous', '18547', 'enormous', 'IY0 N AO1 R M AH0 S', '3', 'owr', '1', '6']
# ['restaurant', '26470', 'restaurant', 'R EH1 S T R AA2 N T', '2', 'e', '1', '20']
# ['restaurant', '26470', 'restaurant', 'R EH1 S T ER0 AA2 N T', '2', 'e', '1', '37']
# ['occasionally', '14531', 'occasionally', 'AH0 K EY1 ZH AH0 N L IY0', '3', 'ey', '1', '15']
# ['occasionally', '14531', 'occasionally', 'AH0 K EY1 ZH N AH0 L IY0', '3', 'ey', '1', '10']
# ['transferred', '6237', 'transferred', 'T R AE1 N S F ER0 D', '3', 'aeh', '1', '9']
# ['transferred', '6237', 'transferred', 'T R AE0 N S F ER1 D', '3', 'aeh', '0', '7']
# ['fisherman', '1781', 'fisherman', 'F IH1 SH ER0 M AE2 N', '4', '*hr', '0', '1']
# ['fisherman', '1781', 'fisherman', 'F IH1 SH ER0 M AH0 N', '6', '@', '0', '1']
# ['deliberately', '5646', 'deliberately', 'D AH0 L IH1 B R AH0 T L IY0', '10', 'iyF', '0', '3']
# ['deliberately', '5646', 'deliberately', 'D AH0 L IH1 B ER0 AH0 T L IY0', '2', '@', '0', '2']
# ['encouraged', '13058', 'encouraged', 'EH0 N K ER1 IH0 JH D', '4', '*hr', '1', '3']
# ['encouraged', '13058', 'encouraged', 'EH0 N K ER1 AH0 JH D', '4', '*hr', '1', '2']
# ['cents', '10442', 'cents', 'S EH1 N T S', '2', 'e', '1', '17']
# ['cents', '10442', 'cents', 'S EH1 N S', '2', 'e', '1', '29']
# ['hampshire', '9182', 'hampshire', 'HH AE1 M P SH ER0', '2', 'aeh', '1', '4']
# ['hampshire', '9182', 'hampshire', 'HH AE1 M SH ER0', '2', 'aeh', '1', '2']
# ['pajamas', '1685', 'pajamas', 'P AH0 JH AA1 M AH0 Z', '4', 'o', '1', '4']
# ['pajamas', '1685', 'pajamas', 'P AH0 JH AE1 M AH0 Z', '4', 'aeh', '1', '2']
# ['repairs', '3191', 'repairs', 'R AH0 P EH1 R Z', '4', 'e', '1', '1']
# ['repairs', '3191', 'repairs', 'R IY0 P EH1 R Z', '2', 'iy', '0', '2']
# ['beforehand', '1466', 'beforehand', 'T B AH0 EY1 F AO1 R D HH HH AE2 OW1 N M D F', '4', 'ey', '1', '1']
# ['beforehand', '1466', 'beforehand', 'B AH0 F AO1 R HH AE2 N D', '4', 'owr', '1', '2']
# ['windy', '2019', 'windy', 'W AY1 N D IY0', '5', 'iyF', '0', '2']
# ['windy', '2019', 'windy', 'W IH1 N D IY0', '5', 'iyF', '0', '2']
# ['diving', '3489', 'diving', 'D AY1 V IH0 NG', '2', 'ay', '1', '4']
# ['diving', '3489', 'diving', 'D AY1 V AH0 N', '2', 'ay', '1', '2']
# ['charging', '4397', 'charging', 'CH AA1 R JH IH0 NG', '2', 'ahr', '1', '2']
# ['charging', '4397', 'charging', 'CH AA1 R JH AH0 N', '2', 'ahr', '1', '1']
# ['appearing', '4867', 'appearing', 'AH0 P IY1 R IH0 NG', '3', 'iyr', '1', '2']
# ['appearing', '4867', 'appearing', 'AH0 P IH1 R IH0 NG', '3', 'iyr', '1', '1']
# ['produce', '33492', 'produce', 'P R AH0 D UW1 S', '5', 'Tuw', '1', '9']
# ['produce', '33492', 'produce', 'P R OW1 D UW0 S', '5', 'Tuw', '0', '4']
# ['enjoyment', '2708', 'enjoyment', 'AH0 N JH OY1 M AH0 N T', '4', 'oy', '1', '2']
# ['enjoyment', '2708', 'enjoyment', 'EH0 N JH OY1 M AH0 N T', '1', 'e', '0', '1']
# ['desperately', '6154', 'desperately', 'D EH1 S P R AH0 T L IY0', '2', 'e', '1', '1']
# ['desperately', '6154', 'desperately', 'D EH1 S P ER0 AH0 T L IY0', '2', 'e', '1', '1']
# ["nobody's", '3206', "nobody's", 'N OW1 B AH0 D IY0 Z', '2', 'ow', '1', '7']
# ["nobody's", '3206', "nobody's", 'N OW1 B AA2 D IY2 Z', '4', 'o', '2', '6']
# ['whereabouts', '1406', 'whereabouts', 'HH W EH1 R AH0 B AW2 T S', '7', 'aw', '2', '1']
# ['whereabouts', '1406', 'whereabouts', 'W EH1 R AH0 B AW2 T S', '2', 'e', '1', '1']
# ['reporting', '17580', 'reporting', 'R IY0 P AO1 R T IH0 NG', '2', 'iy', '0', '2']
# ['reporting', '17580', 'reporting', 'R AH0 P AO1 R T IH0 NG', '4', 'owr', '1', '3']
# ['recurring', '1830', 'recurring', 'R IY0 K ER1 IH0 NG', '4', '*hr', '1', '2']
# ['recurring', '1830', 'recurring', 'R IH0 K ER1 IH0 NG', '4', '*hr', '1', '1']
# ['desperate', '10754', 'desperate', 'D EH1 S P R AH0 T', '2', 'e', '1', '3']
# ['desperate', '10754', 'desperate', 'D EH1 S P ER0 AH0 T', '2', 'e', '1', '2']
# ['production', '42176', 'production', 'P ER0 D AH1 K SH AH0 N', '4', 'uh', '1', '3']
# ['production', '42176', 'production', 'P R AH0 D AH1 K SH AH0 N', '5', 'uh', '1', '3']
# ['accidentally', '2982', 'accidentally', 'AE2 K S AH0 D EH1 N T AH0 L IY0', '1', 'NA', '2', '2']
# ['accidentally', '2982', 'accidentally', 'AE2 K S AH0 D EH1 N AH0 L IY0', '1', 'NA', '2', '3']
# ['corporal', '1659', 'corporal', 'K AO1 R P R AH0 L', '2', 'owr', '1', '1']
# ['corporal', '1659', 'corporal', 'K AO1 R P ER0 AH0 L', '2', 'owr', '1', '2']
# ['retire', '4975', 'retire', 'R IY0 T AY1 R', '2', 'iy', '0', '14']
# ['retire', '4975', 'retire', 'R IY2 T AY1 ER0', '4', 'ay', '1', '13']
# ['hon', '467', 'hon', 'HH AA1 N', '2', 'o', '1', '3']
# ['hon', '467', 'hon', 'HH AH1 N', '2', 'uh', '1', '2']
# ['boundary', '3835', 'boundary', 'B AW1 N D R IY0', '2', 'aw', '1', '6']
# ['boundary', '3835', 'boundary', 'B AW1 N D ER0 IY0', '2', 'aw', '1', '3']
# ['grandpa', '2806', 'grandpa', 'G R AE1 M P AA2', '3', 'aeh', '1', '3']
# ['grandpa', '2806', 'grandpa', 'G R AE1 N P AA2', '3', 'aeh', '1', '5']
# ['dungarees', '143', 'dungarees', 'D AH1 NG G ER0 IY2 Z', '2', 'uh', '1', '3']
# ['dungarees', '143', 'dungarees', 'D AH1 NG G ER0 IY0 Z', '2', 'uh', '1', '5']
# ["somebody's", '3250', "somebody's", 'S AH1 M B AH0 D IY0', '7', 'iyF', '0', '32']
# ["somebody's", '3250', "somebody's", 'S AH1 M B AA2 D IY0', '5', 'o', '2', '26']
# ['catherine', '6541', 'catherine', 'K AE1 TH ER0 AH0 N', '2', 'aeh', '1', '8']
# ['catherine', '6541', 'catherine', 'K AE1 TH R IH2 N', '2', 'aeh', '1', '6']
# ['requires', '24665', 'requires', 'R IY0 K W AY1 R Z', '2', 'iy', '0', '1']
# ['requires', '24665', 'requires', 'R IY0 K W AY1 ER0 Z', '5', 'ay', '1', '1']
# ['gushing', '639', 'gushing', 'G AH1 SH AH0 N', '2', 'uh', '1', '1']
# ['gushing', '639', 'gushing', 'G AH1 SH IH0 NG', '2', 'uh', '1', '1']
# ['federal', '90027', 'federal', 'F EH1 D R AH0 L', '2', 'e', '1', '21']
# ['federal', '90027', 'federal', 'F EH1 D ER0 AH0 L', '2', 'e', '1', '18']
# ['employees', '33129', 'employees', 'AH0 M P L OY1 IY0 Z', '6', 'iy', '0', '3']
# ['employees', '33129', 'employees', 'EH0 M P L OY1 IY0 Z', '5', 'oy', '1', '3']
# ['ye', '2853', 'ye', 'Y IY1', '2', 'iyF', '1', '1']
# ['ye', '2853', 'ye', 'Y EH1', '2', 'e', '1', '2']
# ['related', '38254', 'related', 'R IY0 L EY1 T AH0 D', '4', 'ey', '1', '12']
# ['related', '38254', 'related', 'R AH0 L EY1 T AH0 D', '4', 'ey', '1', '9']
# ['chestnut', '1589', 'chestnut', 'CH EH1 S N AH2 T', '2', 'e', '1', '24']
# ['chestnut', '1589', 'chestnut', 'CH EH1 S T N AH2 T', '2', 'e', '1', '19']
# ['automobile', '4703', 'automobile', 'AO1 T AH0 M OW0 B IY2 L', '1', 'oh', '1', '7']
# ['automobile', '4703', 'automobile', 'AO2 T AH0 M OW0 B IY1 L', '7', 'iy', '1', '3']
# ['spraying', '1588', 'spraying', 'S P R EY1 IH0 NG', '4', 'ey', '1', '2']
# ['spraying', '1588', 'spraying', 'S P R EY1 AH0 N', '4', 'ey', '1', '1']
# ['effective', '39281', 'effective', 'AH0 F EH1 K T IH0 V', '3', 'e', '1', '2']
# ['effective', '39281', 'effective', 'IY1 F EH0 K T IH0 V', '1', 'iy', '1', '2']
# ['wednesday', '17783', 'wednesday', 'W EH1 N Z D IY0', '6', 'iyF', '0', '30']
# ['wednesday', '17783', 'wednesday', 'W EH1 N Z D EY2', '6', 'eyF', '2', '16']
# ['rejection', '5030', 'rejection', 'R IY0 JH EH1 K SH AH0 N', '2', 'iy', '0', '1']
# ['rejection', '5030', 'rejection', 'R IH0 JH EH1 K SH AH0 N', '4', 'e', '1', '2']
# ['audition', '1551', 'audition', 'AO0 D IH1 SH AH0 N', '1', 'oh', '0', '2']
# ['audition', '1551', 'audition', 'AA0 D IH1 SH AH0 N', '3', 'i', '1', '4']
# ['dragging', '3434', 'dragging', 'D R AE1 G IH0 NG', '3', 'ae', '1', '3']
# ['dragging', '3434', 'dragging', 'D R AE1 G AH0 N', '3', 'ae', '1', '3']
# ['qualms', '666', 'qualms', 'K W AA1 L M Z', '3', 'o', '1', '1']
# ['qualms', '666', 'qualms', 'K W AA1 M Z', '3', 'o', '1', '1']
# ['piers', '1065', 'piers', 'P IY1 R Z', '2', 'iyr', '1', '3']
# ['piers', '1065', 'piers', 'P IH1 R Z', '2', 'iyr', '1', '5']
# ['essentially', '16374', 'essentially', 'AH0 S EH1 N SH AH0 L IY0', '3', 'e', '1', '2']
# ['essentially', '16374', 'essentially', 'AH0 S EH1 N CH AH0 L IY0', '3', 'e', '1', '4']
# ['lists', '9222', 'lists', 'L IH1 S', '2', 'i', '1', '1']
# ['lists', '9222', 'lists', 'L IH1 S T S', '2', 'i', '1', '1']
# ['reception', '6531', 'reception', 'R IY0 S EH1 P SH AH0 N', '4', 'e', '1', '3']
# ['reception', '6531', 'reception', 'R AH0 S EH1 P SH AH0 N', '4', 'e', '1', '7']
# ['relieve', '2951', 'relieve', 'R AH0 L IY1 V', '2', '@', '0', '2']
# ['relieve', '2951', 'relieve', 'R IY0 L IY1 V', '2', 'iy', '0', '1']
# ['gear', '12408', 'gear', 'G IH1 R', '2', 'iyr', '1', '2']
# ['gear', '12408', 'gear', 'G IY1 R', '2', 'iyr', '1', '1']
# ['economic', '96565', 'economic', 'IY2 K AH0 N AA1 M IH0 K', '5', 'o', '1', '2']
# ['economic', '96565', 'economic', 'EH2 K AH0 N AA1 M IH0 K', '1', 'e', '2', '1']
# ['traditionally', '8101', 'traditionally', 'T R AH0 D IH1 SH AH0 N AH0 L IY0', '5', 'i', '1', '1']
# ['traditionally', '8101', 'traditionally', 'T R AH0 D IH1 SH N AH0 L IY0', '10', 'iyF', '0', '1']
# ['pierced', '1935', 'pierced', 'P IY1 R S T', '2', 'iyr', '1', '2']
# ['pierced', '1935', 'pierced', 'P IH1 R S T', '2', 'iyr', '1', '1']
# ['specially', '2333', 'specially', 'S P EH1 SH L IY0', '3', 'e', '1', '8']
# ['specially', '2333', 'specially', 'S P EH1 SH AH0 L IY0', '3', 'e', '1', '5']
# ['ordering', '3659', 'ordering', 'AO1 R D ER0 IH0 NG', '1', 'owr', '1', '1']
# ['ordering', '3659', 'ordering', 'AO1 R D ER0 AH0 N', '1', 'owr', '1', '2']
# ['volunteering', '1265', 'volunteering', 'V AO2 L AH0 N T IH1 R IH0 NG', '2', 'oh', '2', '1']
# ['volunteering', '1265', 'volunteering', 'V AO2 L AH0 N T IH1 R AH0 N', '7', 'iyr', '1', '1']
# ['finance', '13662', 'finance', 'F AY1 N AE2 N S', '2', 'ay', '1', '2']
# ['finance', '13662', 'finance', 'F AH0 N AE1 N S', '4', 'aeh', '1', '1']
# ['additional', '32664', 'additional', 'AH0 D IH1 SH AH0 N AH0 L', '3', 'i', '1', '2']
# ['additional', '32664', 'additional', 'AH0 D IH1 SH N AH0 L', '1', '@', '0', '1']
# ['walkman', '352', 'walkman', 'W AO1 K M AE2 N', '2', 'oh', '1', '2']
# ['walkman', '352', 'walkman', 'W AO1 K M AH0 N', '2', 'oh', '1', '1']
# ['hears', '5811', 'hears', 'HH IY1 R Z', '2', 'iyr', '1', '2']
# ['hears', '5811', 'hears', 'HH IH1 R Z', '2', 'iyr', '1', '1']
# ['recovery', '15602', 'recovery', 'R IH0 K AH1 V R IY0', '2', 'i', '0', '1']
# ['recovery', '15602', 'recovery', 'R IH0 K AH1 V ER0 IY0', '4', 'uh', '1', '1']
# ['veterans', '9983', 'veterans', 'V EH1 T ER0 AH0 N Z', '2', 'e', '1', '4']
# ['veterans', '9983', 'veterans', 'V EH1 T R AH0 N Z', '2', 'e', '1', '2']
# ['fracture', '2219', 'fracture', 'F R AE1 K CH ER0', '3', 'ae', '1', '2']
# ['fracture', '2219', 'fracture', 'F R AE1 K SH ER0', '3', 'ae', '1', '1']
# ['conduct', '16701', 'conduct', 'K AH0 N D AH1 K T', '5', 'uh', '1', '2']
# ['conduct', '16701', 'conduct', 'K AA1 N D AH0 K T', '2', 'o', '1', '3']
# ['improvise', '835', 'improvise', 'IH1 M P R AH0 V AY2 Z', '1', 'i', '1', '1']
# ['improvise', '835', 'improvise', 'IH2 M P R AH0 V AY1 Z', '7', 'ay', '1', '1']
# ['shoving', '1339', 'shoving', 'SH AH1 V IH0 NG', '2', 'uh', '1', '2']
# ['shoving', '1339', 'shoving', 'SH AH1 V AH0 N', '2', 'uh', '1', '1']
# ['associated', '37672', 'associated', 'AH0 S OW1 SH IY0 EY2 T AH0 D', '3', 'ow', '1', '7']
# ['associated', '37672', 'associated', 'AH0 S OW1 S IY0 EY2 T AH0 D', '3', 'ow', '1', '7']
# ['rewarding', '2718', 'rewarding', 'R IY0 W AO1 R D IH0 NG', '4', 'owr', '1', '2']
# ['rewarding', '2718', 'rewarding', 'R AH0 W AO1 R D IH0 NG', '4', 'owr', '1', '1']
# ['candidates', '22742', 'candidates', 'K AE1 N D AH0 D EY0 T S', '2', 'aeh', '1', '1']
# ['candidates', '22742', 'candidates', 'K AE1 N AH0 D AH0 T S', '2', 'aeh', '1', '1']
# ['replace', '13723', 'replace', 'R IY2 P L EY1 S', '5', 'ey', '1', '7']
# ['replace', '13723', 'replace', 'ER0 P L EY1 S', '4', 'ey', '1', '3']
# ['cheer', '3457', 'cheer', 'CH IY1 R', '2', 'iyr', '1', '3']
# ['cheer', '3457', 'cheer', 'CH IH1 R', '2', 'iyr', '1', '2']
# ['consequently', '6793', 'consequently', 'K AA1 N S AH0 K W AH0 N T L IY0', '12', 'iyF', '0', '2']
# ['consequently', '6793', 'consequently', 'K AA1 N S AH0 K W EH2 N T L IY0', '2', 'o', '1', '1']
# ['economy', '61583', 'economy', 'IH0 K AA1 N AH0 M IY0', '3', 'o', '1', '5']
# ['economy', '61583', 'economy', 'IY0 K AA1 N AH0 M IY0', '3', 'o', '1', '9']
# ['barriers', '7803', 'barriers', 'B EH1 R IY0 ER0 Z', '2', 'e', '1', '2']
# ['barriers', '7803', 'barriers', 'B AE1 R IY0 ER0 Z', '2', 'ae', '1', '1']
# ['professionally', '2520', 'professionally', 'P R AH0 F EH1 SH N AH0 L IY0', '5', 'e', '1', '1']
# ['professionally', '2520', 'professionally', 'P R AH0 F EH1 SH AH0 N AH0 L IY0', '5', 'e', '1', '1']
# ['puerto', '5941', 'puerto', 'P AO1 R T ER0', '5', '*hr', '0', '26']
# ['puerto', '5941', 'puerto', 'P AO1 R T AH0', '5', '@', '0', '19']
# ['figuring', '3153', 'figuring', 'F IH1 G Y ER0 IH0 NG', '2', 'i', '1', '1']
# ['figuring', '3153', 'figuring', 'F IH1 G Y ER0 AH0 N', '5', '*hr', '0', '1']
# ['mentally', '6186', 'mentally', 'M EH1 N T AH0 L IY0', '7', 'iyF', '0', '3']
# ['mentally', '6186', 'mentally', 'M EH1 N AH0 L IY0', '2', 'e', '1', '5']
# ['fashionable', '2514', 'fashionable', 'F AE1 SH N AH0 B AH0 L', '2', 'ae', '1', '2']
# ['fashionable', '2514', 'fashionable', 'F AE1 SH AH0 N AH0 B AH0 L', '2', 'ae', '1', '1']
# ['employed', '11576', 'employed', 'AH0 M P L OY1 D', '5', 'oy', '1', '4']
# ['employed', '11576', 'employed', 'EH0 M P L OY1 D', '1', 'e', '0', '3']
# ['association', '46306', 'association', 'AH0 S OW2 S IY0 EY1 SH AH0 N', '6', 'ey', '1', '14']
# ['association', '46306', 'association', 'AH0 S OW2 SH IY0 EY1 SH AH0 N', '3', 'ow', '2', '17']
# ['enjoys', '3696', 'enjoys', 'AH0 N JH OY1 Z', '4', 'oy', '1', '2']
# ['enjoys', '3696', 'enjoys', 'EH0 N JH OY1 Z', '4', 'oy', '1', '4']
# ['seventies', '1572', 'seventies', 'S EH1 V AH0 N T IY0 Z', '7', 'iy', '0', '24']
# ['seventies', '1572', 'seventies', 'S EH1 V AH0 N IY0 Z', '2', 'e', '1', '18']
# ['sentimental', '2227', 'sentimental', 'S EH2 N AH0 M EH1 N T AH0 L', '2', 'e', '2', '1']
# ['sentimental', '2227', 'sentimental', 'S EH2 N AH0 M EH1 N AH0 L', '2', 'e', '2', '1']
# ['reliable', '9096', 'reliable', 'R IY0 L AY1 AH0 B AH0 L', '2', 'iy', '0', '2']
# ['reliable', '9096', 'reliable', 'R AH0 L AY1 AH0 B AH0 L', '2', '@', '0', '1']
# ['remarks', '7303', 'remarks', 'R AH0 M AA1 R K S', '4', 'ahr', '1', '1']
# ['remarks', '7303', 'remarks', 'R IY0 M AA1 R K S', '2', 'iy', '0', '1']
# ['concentrating', '2737', 'concentrating', 'K AA1 N S AH0 N T R EY2 T IH0 NG', '2', 'o', '1', '2']
# ['concentrating', '2737', 'concentrating', 'K AA1 N S AH0 N T R EY2 T AH0 N', '2', 'o', '1', '1']
# ['evolution', '11967', 'evolution', 'EH2 V AH0 L UW1 SH AH0 N', '5', 'Tuw', '1', '2']
# ['evolution', '11967', 'evolution', 'EH2 V OW0 L UW1 SH AH0 N', '1', 'e', '2', '3']
# ['recession', '10217', 'recession', 'R IY2 S EH1 SH AH0 N', '4', 'e', '1', '4']
# ['recession', '10217', 'recession', 'R AH0 S EH1 SH AH0 N', '4', 'e', '1', '2']
# ['evaluation', '14398', 'evaluation', 'IY0 V AE2 L Y UW0 EY1 SH AH0 N', '1', 'iy', '0', '1']
# ['evaluation', '14398', 'evaluation', 'IH0 V AE2 L Y UW0 EY1 SH AH0 N', '3', 'NA', '2', '1']
# ...
# ['wrestling', '3856', 'wrestling', 'R EH1 S L AH0 N', '2', 'e', '1', '5']
# ['wrestling', '3856', 'wrestling', 'R EH1 S L IH0 NG', '2', 'e', '1', '4']
# ['luxuries', '591', 'luxuries', 'L AH1 G ZH ER0 IY0 Z', '2', 'uh', '1', '1']
# ['luxuries', '591', 'luxuries', 'T L EY1 AH1 K AH1 S AH0 N G D SP ZH DH ER0 EH1 N W IY0 IY1 Z D', '4', 'uh', '1', '1']
# ['defect', '1925', 'defect', 'D AH0 F EH1 K T', '4', 'e', '1', '2']
# ['defect', '1925', 'defect', 'D IY1 F EH0 K T', '2', 'iy', '1', '3']
# ['catharine', '163', 'catharine', 'K AE1 TH R AH0 N', '2', 'aeh', '1', '3']
# ['catharine', '163', 'catharine', 'K AE1 TH ER0 IH2 N', '2', 'aeh', '1', '2']
# ['freudian', '590', 'freudian', 'F R UW1 D IY0 AH0 N', '5', 'iy', '0', '1']
# ['freudian', '590', 'freudian', 'F R OY1 D IY0 AH0 N', '3', 'oy', '1', '1']
# ['documentary', '6223', 'documentary', 'D AA2 K Y AH0 M EH1 N ER0 IY0', '2', 'o', '2', '1']
# ['documentary', '6223', 'documentary', 'D AA2 K Y AH0 M EH1 N T ER0 IY0', '2', 'o', '2', '1']
# ['mifflin', '568', 'mifflin', 'M IH1 F L IH2 N', '2', 'i', '1', '8']
# ['mifflin', '568', 'mifflin', 'M IH1 F L IH0 N', '2', 'i', '1', '4']
# ['minority', '18934', 'minority', 'M AY0 N AO1 R AH0 T IY0', '2', 'ay', '0', '3']
# ['minority', '18934', 'minority', 'M AH0 N AO1 R AH0 T IY0', '4', 'owr', '1', '2']
# ['presidents', '9996', 'presidents', 'P R EH1 Z AH0 D AH0 N S', '3', 'e', '1', '2']
# ['presidents', '9996', 'presidents', 'P R EH1 Z AH0 D AH0 N T S', '3', 'e', '1', '1']
# ['walkers', '926', 'walkers', 'W Y AE1 AO1 K SP ER0 Z', '3', 'NA', '1', '1']
# ['walkers', '926', 'walkers', 'W AO1 K ER0 Z', '4', '*hr', '0', '1']
# ['louis', '19286', 'louis', 'L UW1 AH0 S', '3', '@', '0', '6']
# ['louis', '19286', 'louis', 'L UW1 IY0', '2', 'Tuw', '1', '4']
# ['convent', '1211', 'convent', 'K AA1 N V AH0 N T', '2', 'o', '1', '11']
# ['convent', '1211', 'convent', 'K AA1 N V EH2 N T', '2', 'o', '1', '10']
# ['transfers', '3095', 'transfers', 'T R AE0 N S F ER1 Z', '3', 'aeh', '0', '1']
# ['transfers', '3095', 'transfers', 'T R AE1 N S F ER0 Z', '3', 'aeh', '1', '1']
# ['attribute', '2908', 'attribute', 'AH0 T R IH1 B Y UW2 T', '4', 'i', '1', '1']
# ['attribute', '2908', 'attribute', 'AE1 T R AH0 B Y UW2 T', '1', 'ae', '1', '1']
# ['graduation', '5745', 'graduation', 'G R AE2 JH UW0 EY1 SH AH0 N', '5', 'uw', '0', '6']
# ['graduation', '5745', 'graduation', 'G R AE2 JH AH0 W EY1 SH AH0 N', '3', 'NA', '2', '4']
# ['pianist', '1989', 'pianist', 'P IY0 AE1 N AH0 S T', '2', 'iy', '0', '1']
# ['pianist', '1989', 'pianist', 'P IY1 AH0 N AH0 S T', '2', 'iy', '1', '1']
# ['adequate', '9919', 'adequate', 'AE1 D AH0 K W AH0 T', '1', 'ae', '1', '1']
# ['adequate', '9919', 'adequate', 'AE1 D AH0 K W EY2 T', '1', 'ae', '1', '1']
# ['printing', '4436', 'printing', 'P R IH1 N IH0 NG', '5', 'i', '0', '2']
# ['printing', '4436', 'printing', 'P R IH1 N T IH0 NG', '6', 'i', '0', '1']
# ['waltzes', '143', 'waltzes', 'W AO1 L S AH0 Z', '2', 'oh', '1', '1']
# ['waltzes', '143', 'waltzes', 'W AO1 L T S AH0 Z', '6', '@', '0', '1']
# ['korea', '15885', 'korea', 'K ER0 R IY1 AH0', '5', '@', '0', '5']
# ['korea', '15885', 'korea', 'K R IY1 AH0', '3', 'iy', '1', '8']
# ['pleated', '516', 'pleated', 'P L IY1 T IH0 D', '3', 'iy', '1', '1']
# ['pleated', '516', 'pleated', 'P L IY1 T AH0 D', '3', 'iy', '1', '1']
# ['racists', '452', 'racists', 'R EY1 S AH0 S', '2', 'ey', '1', '1']
# ['racists', '452', 'racists', 'R EY1 S AH0 S T S', '2', 'ey', '1', '1']
# ['pitching', '4926', 'pitching', 'P IH1 CH IH0 NG', '2', 'i', '1', '1']
# ['pitching', '4926', 'pitching', 'P IH1 CH AH0 N', '2', 'i', '1', '2']
# ['ay', '442', 'ay', 'AY1', '1', 'ay', '1', '4']
# ['ay', '442', 'ay', 'EY1', '1', 'eyF', '1', '2']
# ["wha'", '28', "wha'", 'W AA1', '2', 'o', '1', '1']
# ["wha'", '28', "wha'", 'W AH1', '2', 'uh', '1', '2']
# ['wired', '2478', 'wired', 'W AY1 R D', '2', 'ay', '1', '1']
# ['wired', '2478', 'wired', 'W AY1 ER0 D', '2', 'ay', '1', '2']
# ['segmented', '440', 'segmented', 'S EH2 G M EH1 N AH0 D', '2', 'e', '2', '1']
# ['segmented', '440', 'segmented', 'S EH1 G M EH2 N AH0 D', '2', 'e', '1', '1']
# ['re', '7192', 're', 'R IY1', '2', 'iyF', '1', '14']
# ['re', '7192', 're', 'R EY1', '2', 'eyF', '1', '7']
# ['punctured', '507', 'punctured', 'P AH1 NG K SH ER0 D', '2', 'uh', '1', '1']
# ['punctured', '507', 'punctured', 'P AH1 NG K CH ER0 D', '6', '*hr', '0', '1']
# ['presbyterian', '2047', 'presbyterian', 'P R EH2 S B AH0 T IY1 R IY0 AH0 N', '8', 'iyr', '1', '3']
# ['presbyterian', '2047', 'presbyterian', 'P R EH2 Z B AH0 T IH1 R IY0 AH0 N', '8', 'iyr', '1', '6']
# ['receipt', '1697', 'receipt', 'R IY0 S IY1 T', '2', 'iy', '0', '3']
# ['receipt', '1697', 'receipt', 'R AH0 S IY1 T', '4', 'iy', '1', '2']
# ['bragging', '969', 'bragging', 'B R AE1 G IH0 NG', '3', 'ae', '1', '2']
# ['bragging', '969', 'bragging', 'B R AE1 G AH0 N', '3', 'ae', '1', '1']
# ['welsh', '1422', 'welsh', 'W EH1 L CH', '2', 'e', '1', '1']
# ['welsh', '1422', 'welsh', 'W EH1 L SH', '2', 'e', '1', '2']
# ['graduates', '5828', 'graduates', 'G R AE1 JH UW0 EY2 T S', '3', 'ae', '1', '4']
# ['graduates', '5828', 'graduates', 'G R AE1 JH AH0 W AH0 T S', '3', 'ae', '1', '4']
# ['earring', '589', 'earring', 'IY1 R IH0 NG', '1', 'iyr', '1', '3']
# ['earring', '589', 'earring', 'IH1 R IH0 NG', '1', 'iyr', '1', '2']
# ['thursdays', '1379', 'thursdays', 'TH ER1 Z D EY0 Z', '2', '*hr', '1', '3']
# ['thursdays', '1379', 'thursdays', 'TH ER1 Z D IY0 Z', '2', '*hr', '1', '2']
# ['practitioner', '2016', 'practitioner', 'P R AE0 K T IH1 SH N ER0', '3', 'NA', '0', '1']
# ['practitioner', '2016', 'practitioner', 'P R AE0 K T IH1 SH AH0 N ER0', '3', 'NA', '0', '1']
# ['fuckers', '137', 'fuckers', 'F AH1 K ER0', '2', 'uh', '1', '2']
# ['fuckers', '137', 'fuckers', 'F AH1 K ER0 Z', '2', 'uh', '1', '1']
# ['hosts', '4890', 'hosts', 'HH OW1 S', '2', 'ow', '1', '1']
# ['hosts', '4890', 'hosts', 'HH OW1 S S', '2', 'ow', '1', '1']
# ["job's", '331', "job's", 'JH AA1 B Z', '2', 'o', '1', '1']
# ["job's", '331', "job's", 'JH OW1 B Z', '2', 'ow', '1', '1']
# ['curry', '3460', 'curry', 'K AH1 R IY0', '2', 'uh', '1', '14']
# ['curry', '3460', 'curry', 'K ER1 IY0', '2', '*hr', '1', '8']
# ['chauffeur', '611', 'chauffeur', 'SH OW0 F ER1', '2', 'ow', '0', '1']
# ['chauffeur', '611', 'chauffeur', 'SH OW1 F ER0', '2', 'ow', '1', '1']
# ['diapers', '1722', 'diapers', 'D AY1 AH0 P ER0 Z', '2', 'ay', '1', '1']
# ['diapers', '1722', 'diapers', 'D AY1 P ER0 Z', '2', 'ay0', '1', '2']
# ['advantages', '6793', 'advantages', 'AH0 D V AE1 N IH0 JH AH0 Z', '1', '@', '0', '1']
# ['advantages', '6793', 'advantages', 'AE0 D V AE1 N T IH0 JH AH0 Z', '1', 'NA', '0', '1']
# ['encyclopedia', '1624', 'encyclopedia', 'AH0 N S AY2 K L AH0 P IY1 D IY0 AH0', '4', 'ay0', '2', '1']
# ['encyclopedia', '1624', 'encyclopedia', 'AH0 N S AY2 K L OW0 P IY1 D IY0 AH0', '4', 'ay0', '2', '2']
# ['mozart', '1812', 'mozart', 'M OW1 T S AA0 R T', '2', 'ow', '1', '1']
# ['mozart', '1812', 'mozart', 'M OW1 Z AA0 R T', '4', 'ahr', '0', '1']
# ['exceptionally', '2060', 'exceptionally', 'IH0 K S EH1 P SH AH0 N AH0 L IY0', '1', 'i', '0', '1']
# ['exceptionally', '2060', 'exceptionally', 'IH0 K S EH1 P SH N AH0 L IY0', '4', 'e', '1', '2']
# ['cardiologist', '772', 'cardiologist', 'AH1 K Z AA2 S R IH1 T D IH0 IY0 NG AA1 OW1 V L ER0 AH0 DH JH EH1 AH0 R S SP T', '11', 'iy', '0', '1']
# ['cardiologist', '772', 'cardiologist', 'K AA2 R D IY0 AA1 L AH0 JH AH0 S T', '2', 'ahr', '2', '1']
# ['gears', '2233', 'gears', 'G IH1 R Z', '2', 'iyr', '1', '1']
# ['gears', '2233', 'gears', 'G IY1 R Z', '2', 'iyr', '1', '1']
# ['wednesdays', '1024', 'wednesdays', 'W EH1 N Z D EY2 Z', '2', 'e', '1', '4']
# ['wednesdays', '1024', 'wednesdays', 'W EH1 N Z D IY0 Z', '6', 'iy', '0', '4']
# ['whooping', '592', 'whooping', 'HH W UW1 P IH0 NG', '3', 'uw', '1', '1']
# ['whooping', '592', 'whooping', 'H W UW1 P IH0 NG', '3', 'uw', '1', '1']
# ['episcopalian', '285', 'episcopalian', 'IH2 P IH2 S K AH0 P EY1 L Y AH0 N', '3', 'i', '2', '1']
# ['episcopalian', '285', 'episcopalian', 'IH2 P IH2 S K AH0 P EY1 L IY0 AH0 N', '8', 'ey', '1', '2']
# ['regulations', '13790', 'regulations', 'R EH2 IH0 NG G SP Y AH0 B L AE1 EY1 K SH SP AH0 N Z', '2', 'e', '2', '1']
# ['regulations', '13790', 'regulations', 'R EH2 G Y AH0 L EY1 SH AH0 N Z', '7', 'ey', '1', '2']
# ['korean', '9413', 'korean', 'K ER0 R IY1 AH0 N', '2', '*hr', '0', '6']
# ['korean', '9413', 'korean', 'K ER0 IY1 AH0 N', '2', '*hr', '0', '6']
# ["puttin'", '92', "puttin'", 'P UH1 T AH0 N', '2', 'u', '1', '3']
# ["puttin'", '92', "puttin'", 'P AH1 T AH0 N', '2', 'uh', '1', '2']
# ['holmes', '4324', 'holmes', 'HH OW1 M Z', '2', 'ow', '1', '1']
# ['holmes', '4324', 'holmes', 'HH OW1 L M Z', '2', 'ow', '1', '1']
# ['demoralizing', '255', 'demoralizing', 'D IH2 M AA1 R AH0 L AY2 Z IH0 NG', '2', 'i', '2', '1']
# ['demoralizing', '255', 'demoralizing', 'D IH2 M AO1 R AH0 L AY2 Z IH0 NG', '2', 'i', '2', '1']
# ['bumming', '68', 'bumming', 'B AH1 M AH0 NG', '2', 'uh', '1', '1']
# ['bumming', '68', 'bumming', 'B AH1 M IH0 NG', '2', 'uh', '1', '1']
# ['geared', '2072', 'geared', 'G IH1 R D', '2', 'iyr', '1', '2']
# ['geared', '2072', 'geared', 'G IY1 R D', '2', 'iyr', '1', '3']
# ['relates', '3600', 'relates', 'R AH0 L EY1 T S', '4', 'ey', '1', '2']
# ['relates', '3600', 'relates', 'R IY0 L EY1 T S', '2', 'iy', '0', '1']
# ['coronary', '1647', 'coronary', 'K AO1 R AH0 N EH2 R IY0', '2', 'owr', '1', '1']
# ['coronary', '1647', 'coronary', 'K AA1 R AH0 N EH2 R IY0', '4', '@', '0', '1']
# ['lenient', '619', 'lenient', 'L IY1 N IY0 AH0 N T', '4', 'iy', '0', '3']
# ['lenient', '619', 'lenient', 'L IY1 N Y AH0 N T', '2', 'iy', '1', '4']
# ['grandparent', '489', 'grandparent', 'G R AE1 N P EH2 R AH0 N T', '3', 'aeh', '1', '1']
# ['grandparent', '489', 'grandparent', 'G R AE1 M P EH2 R AH0 N T', '6', 'e', '2', '1']
# ['grandparent', '489', 'grandparent', 'G R AE1 N D P EH2 R AH0 N T', '3', 'aeh', '1', '1']
# ['tackling', '1296', 'tackling', 'T AE1 K L IH0 NG', '2', 'NA', '1', '2']
# ['tackling', '1296', 'tackling', 'T AE1 K AH0 L IH0 NG', '2', 'NA', '1', '1']
# ['integration', '9349', 'integration', 'IH2 N T AH0 G R EY1 SH AH0 N', '7', 'ey', '1', '1']
# ['integration', '9349', 'integration', 'IH2 N AH0 G R EY1 SH AH0 N', '1', 'i', '2', '1']
# ['entertainers', '934', 'entertainers', 'EH2 N ER0 T EY1 N ER0 Z', '5', 'ey', '1', '1']
# ['entertainers', '934', 'entertainers', 'EH2 N T ER0 T EY1 N ER0 Z', '1', 'e', '2', '1']
# ['priority', '11082', 'priority', 'P R AY0 AO1 R AH0 T IY0', '3', 'ay', '0', '1']
# ['priority', '11082', 'priority', 'P R AY0 AA1 R AH0 T IY0', '8', 'iyF', '0', '2']
# ['quebec', '2695', 'quebec', 'K AH0 B EH1 K', '2', '@', '0', '3']
# ['quebec', '2695', 'quebec', 'K W AH0 B EH1 K', '3', '@', '0', '2']
# ['jewellery', '75', 'jewellery', 'JH UW1 L R IY0', '5', 'iyF', '0', '2']
# ['jewellery', '75', 'jewellery', 'JH UW1 L ER0 IY0', '2', 'uw', '1', '1']
# ['intersections', '833', 'intersections', 'IH2 N ER0 S EH1 K SH AH0 N Z', '5', 'e', '1', '1']
# ['intersections', '833', 'intersections', 'IH2 N T ER0 S EH1 K SH AH0 N Z', '6', 'e', '1', '1']
# ['flunking', '127', 'flunking', 'F L AH1 NG K AH0 N', '3', 'uh', '1', '1']
# ['flunking', '127', 'flunking', 'F L AH1 NG K IH0 NG', '3', 'uh', '1', '1']
# ['alphonsus', '107', 'alphonsus', 'EH1 AE2 N T L F HH AA1 OW1 M T AH0 SP N Z AH0 S DH', '1', 'e', '1', '1']
# ['alphonsus', '107', 'alphonsus', 'AE0 L F AA1 N S AH0 S', '4', 'o', '1', '1']
# ['every-', '127', 'every-', 'EH1 V R IY0', '1', 'e', '1', '10']
# ['every-', '127', 'every-', 'EH1 V ER0 IY0', '3', '*hr', '0', '5']
# ["listenin'", '36', "listenin'", 'L IH1 S N AH0 N', '2', 'i', '1', '1']
# ["listenin'", '36', "listenin'", 'L IH1 S AH0 N AH0 N', '4', '@', '0', '1']
# ['blacking', '113', 'blacking', 'B L AE1 K IY0 NG', '3', 'ae', '1', '1']
# ['blacking', '113', 'blacking', 'B L AE1 K IH0 NG', '3', 'ae', '1', '1']
# ["enjoyin'", '10', "enjoyin'", 'EH0 N JH OY1 AH0 N', '4', 'oy', '1', '1']
# ["enjoyin'", '10', "enjoyin'", 'AH0 N JH OY1 AH0 N', '4', 'oy', '1', '1']
# ['nationally', '5001', 'nationally', 'N AE1 SH N AH0 L IY0', '2', 'ae', '1', '2']
# ['nationally', '5001', 'nationally', 'N AE1 SH AH0 N AH0 L IY0', '2', 'ae', '1', '1']
# ["alzheimer's", '3824', "alzheimer's", 'AE1 L Z HH AY2 M ER0 Z', '1', 'NA', '1', '2']
# ["alzheimer's", '3824', "alzheimer's", 'AA1 L T S HH AY2 M ER0 Z', '1', 'o', '1', '1']
# ['delano', '457', 'delano', 'D AH0 L AA1 N OW0', '4', 'o', '1', '1']
# ['delano', '457', 'delano', 'D EH1 L AH0 N OW0', '6', 'owF', '0', '1']
# ['percentages', '3087', 'percentages', 'P ER0 S EH1 N IH0 JH AH0 Z', '6', 'i', '0', '1']
# ['percentages', '3087', 'percentages', 'P ER0 S EH1 N T IH0 JH AH0 Z', '2', '*hr', '0', '1']
# ["associate's", '350', "associate's", 'AH0 S OW1 S IY0 AH0 T S', '3', 'ow', '1', '1']
# ["associate's", '350', "associate's", 'AH0 S OW1 SH IY0 AH0 T S', '3', 'ow', '1', '1']
# ['ramsey', '3549', 'ramsey', 'R AE1 M Z IY0', '2', 'aeh', '1', '1']
# ['ramsey', '3549', 'ramsey', 'R AE1 M Z IY2', '2', 'aeh', '1', '1']
# ['mummery', '11', 'mummery', 'M AH1 M ER0 IY2', '2', 'uh', '1', '2']
# ['mummery', '11', 'mummery', 'M AH1 M ER0 IY0', '4', '*hr', '0', '2']
# ["teresa's", '313', "teresa's", 'T ER0 IY1 S AH0 Z', '3', 'iy', '1', '4']
# ["teresa's", '313', "teresa's", 'T ER0 EY1 S AH0 Z', '3', 'ey', '1', '2']
# ['seniority', '817', 'seniority', 'S IY0 N Y AA1 R AH0 T IY0', '2', 'iy', '0', '1']
# ['seniority', '817', 'seniority', 'S IY0 N Y AO1 R AH0 T IY0', '2', 'iy', '0', '2']
# ['presbyterians', '297', 'presbyterians', 'P R EH2 S B AH0 T IY1 R IY0 AH0 N Z', '8', 'iyr', '1', '1']
# ['presbyterians', '297', 'presbyterians', 'P R EH2 Z B AH0 T IY1 R IY0 AH0 N Z', '3', 'e', '2', '1']
# ['archdiocese', '1095', 'archdiocese', 'AA2 R CH D AY1 AH0 S AH0 S', '1', 'ahr', '2', '1']
# ['archdiocese', '1095', 'archdiocese', 'AA2 R CH D AY1 AH0 S IY0 Z', '1', 'ahr', '2', '1']
# ['diocese', '1351', 'diocese', 'D AY1 AH0 S IY2 Z', '5', 'iy', '2', '2']
# ['diocese', '1351', 'diocese', 'D AY1 AH0 S AH0 S', '2', 'ay', '1', '1']
# ['dion', '881', 'dion', 'D AY1 AH0 N', '2', 'ay', '1', '1']
# ['dion', '881', 'dion', 'D IY1 AO2 N', '2', 'iy', '1', '1']
# ['annunciation', '207', 'annunciation', 'AH0 N AA1 N S IH0 EY2 SH AH0 N', '7', 'ey', '2', '11']
# ['annunciation', '207', 'annunciation', 'AH0 N AH2 N S IH0 EY1 SH AH0 N', '3', 'uh', '2', '7']
# ['newkirk', '168', 'newkirk', 'N UW1 K ER0 K', '2', 'Tuw', '1', '1']
# ['newkirk', '168', 'newkirk', 'N UW1 K ER2 K', '2', 'Tuw', '1', '2']
# ['morristown', '195', 'morristown', 'M AA1 R AH0 S T AW2 N', '2', 'ahr', '1', '3']
# ['morristown', '195', 'morristown', 'M AO1 R AH0 S T AW2 N', '2', 'owr', '1', '2']
# ['juniata', '28', 'juniata', 'JH UW2 N IY0 AE1 T AH0', '2', 'uw', '2', '1']
# ['juniata', '28', 'juniata', 'Y UW0 N IY0 AA1 T AH0', '4', 'iy', '0', '2']
# ['tsunami', '2261', 'tsunami', 'S UW0 N AA1 M IY0', '4', 'o', '1', '2']
# ['tsunami', '2261', 'tsunami', 'T S UW0 N AA1 M IY0', '5', 'o', '1', '1']
# ['trolly', '5', 'trolly', 'T R AA1 L IY0', '3', 'o', '1', '2']
# ['trolly', '5', 'trolly', 'CH R AA1 L IY0', '5', 'iyF', '0', '1']
# ["bitchin'", '40', "bitchin'", 'B IH1 CH IH0 N', '2', 'i', '1', '1']
# ["bitchin'", '40', "bitchin'", 'B IH1 CH AH0 N', '2', 'i', '1', '1']
# ['palmyra', '158', 'palmyra', 'P AE0 L M AY1 R AH0', '5', 'ay', '1', '1']
# ['palmyra', '158', 'palmyra', 'P AO0 L M AY1 R AH0', '5', 'ay', '1', '2']
# ["surroundin'", '1', "surroundin'", 'S ER0 AW1 N D IH0 N', '2', '*hr', '0', '1']
# ["surroundin'", '1', "surroundin'", 'S ER0 AW1 N D AH0 N', '2', '*hr', '0', '1']
# ['warrington', '62', 'warrington', 'W AA1 R IH0 NG T AH0 N', '2', 'ahr', '1', '1']
# ['warrington', '62', 'warrington', 'W AO1 R IH0 NG T AH0 N', '2', 'owr', '1', '1']
# ["paintin'", '10', "paintin'", 'P EY1 N AH0 N', '2', 'ey', '1', '2']
# ["paintin'", '10', "paintin'", 'P EY1 N T AH0 N', '2', 'ey', '1', '1']
# ['andorra', '25', 'andorra', 'AE0 N D AA1 R AH0', '1', 'NA', '0', '1']
# ['andorra', '25', 'andorra', 'AE0 N D AO1 R AH0', '1', 'NA', '0', '1']
# ['masterman', '19', 'masterman', 'M AE1 S T ER0 M AH0 N', '2', 'NA', '1', '2']
# ['masterman', '19', 'masterman', 'M AE1 S T ER0 M IH2 N', '2', 'NA', '1', '3']
# ["wrestlin'", '4', "wrestlin'", 'R EH1 S L AH0 N', '2', 'e', '1', '1']
# ["wrestlin'", '4', "wrestlin'", 'R EH1 S AH0 L AH0 N', '2', 'e', '1', '2']
# 3.382871150970459

# %% [markdown]
# ## Removing Same Stress Vowel Entries from High Freq Alt

# %%
import time
import csv
import numpy as np
import ast

t0 = time.time()
PC_file = open('/Users/TaraD/LING_Research/PNCinCOCA_HighFreqAlt.csv', newline='')
data_array = np.array(list(csv.reader(PC_file)))
print(data_array[:5])
header = ['COCA word', 'COCA dict #', 'PNC word', 'Trans', 'v_index', 'v_class', 'Stress', 'PNC count']
# Out:
# [['COCA word' 'COCA dict #' 'PNC word' 'Trans' 'v_index' 'v_class'
#   'Stress' 'PNC count']
#  ['was' '3083112' 'was' 'W AH0 Z' '2' '@' '0' '2172']
#  ['was' '3083112' 'was' 'W AH1 Z' '2' 'uh' '1' '1727']
#  ['as' '2599971' 'as' 'AE1 Z' '1' 'NA' '1' '683']
#  ['as' '2599971' 'as' 'AH0 Z' '1' '@' '0' '495']]

# %%
reduced_PNCinCOCA3 = [header]
print("length of highfreqalt:", len(data_array[1:]))
for i in range(1,len(data_array[1:])):
    line = data_array[i]
    word = line[0]
    if i == 1 or word != data_array[i-1,0]:
        word_list = []
    word_list.append(line)
    if i == (len(data_array)-1) or data_array[i+1,0] != word:
        word_array = np.array(word_list)
        #indices = np.where(word_array[:,6] == 1)[0]
        if (len(word_array)==2) and (word_array[0,6].astype(int) == 1) and (word_array[0,6] == word_array[1,6]) and (word_array[0,5] == word_array[1,5]) and (word_array[0,4] == word_array[1,4]):
            print(word)
            continue
        else:
            reduced_PNCinCOCA3.extend(word_array.tolist())
print(len(reduced_PNCinCOCA3))
print(reduced_PNCinCOCA3)

np.savetxt('PNCinCOCA_HighFreqAlt_reduced.csv',reduced_PNCinCOCA3, '%s',delimiter=",")
np.savetxt('PNCinCOCA_HighFreqAlt_reduced.txt',reduced_PNCinCOCA3,'%-15s')
# Out:
# length of highfreqalt: 887
# began
# adding
# before
# hanging
# didn't
# trying
# different
# favorite
# happening
# without
# cabinet
# close
# hour
# ancient
# steering
# palm
# calm
# spirits
# thursday
# covering
# received
# grandmother
# casting
# stronger
# traveling
# sunday
# remembering
# often
# outspoken
# disappeared
# circling
# earrings
# graduated
# groceries
# frying
# became
# anxious
# entered
# general
# beard
# rattling
# staring
# series
# response
# stopping
# weekend
# counted
# howling
# casual
# raining
# hours
# respect
# natural
# monument
# respectable
# enjoy
# question
# here's
# liberal
# diary
# reasonable
# interested
# usual
# sundays
# actually
# national
# cameras
# opposite
# dental
# superior
# naturally
# enjoyed
# average
# counting
# friendship
# advocate
# concepts
# grandchildren
# elaborate
# jewelry
# difference
# blocking
# events
# interesting
# sandwiches
# polka
# camera
# dentist
# seriously
# complaining
# generally
# respected
# vehicle
# irritate
# boundaries
# tuesday
# relax
# ireland
# struggling
# grandsons
# grandson
# peer
# honestly
# procedures
# enormous
# restaurant
# occasionally
# encouraged
# cents
# hampshire
# diving
# charging
# appearing
# desperately
# recurring
# desperate
# corporal
# boundary
# grandpa
# dungarees
# catherine
# gushing
# federal
# related
# chestnut
# spraying
# dragging
# qualms
# piers
# essentially
# lists
# reception
# gear
# pierced
# specially
# ordering
# walkman
# hears
# veterans
# fracture
# shoving
# associated
# rewarding
# candidates
# cheer
# economy
# professionally
# fashionable
# enjoys
# concentrating
# recession
# victory
# whoa
# boyfriends
# fridays
# balm
# baptists
# blaming
# spelling
# credentials
# wrestling
# catharine
# mifflin
# presidents
# convent
# adequate
# pleated
# racists
# pitching
# wired
# presbyterian
# bragging
# welsh
# graduates
# earring
# thursdays
# fuckers
# hosts
# gears
# whooping
# holmes
# bumming
# geared
# tackling
# flunking
# blacking
# enjoyin'
# nationally
# associate's
# ramsey
# newkirk
# bitchin'
# palmyra
# paintin'
# masterman
# 496
# [['COCA word', 'COCA dict #', 'PNC word', 'Trans', 'v_index', 'v_class', 'Stress', 'PNC count'], ['was', '3083112', 'was', 'W AH0 Z', '2', '@', '0', '2172'], ['was', '3083112', 'was', 'W AH1 Z', '2', 'uh', '1', '1727'], ['as', '2599971', 'as', 'AE1 Z', '1', 'NA', '1', '683'], ['as', '2599971', 'as', 'AH0 Z', '1', '@', '0', '495'], ["it's", '772979', "it's", 'IH1 T S', '1', 'i', '1', '2055'], ["it's", '772979', "it's", 'AH0 T S', '1', '@', '0', '1776'], ['into', '723936', 'into', 'IH2 N T UW1', '4', 'Tuw', '1', '245'], ['into', '723936', 'into', 'IH2 N T AH0', '1', 'i', '2', '289'], ['can', '949767', 'can', 'K AE1 N', '2', 'NA', '1', '360'], ['can', '949767', 'can', 'K AH0 N', '2', '@', '0', '224'], ['between', '290141', 'between', 'B IY0 T W IY1 N', '2', 'iy', '0', '118'], ['between', '290141', 'between', 'B AH0 T W IY1 N', '5', 'iy', '1', '70'], ['hundred', '37031', 'hundred', 'HH AH1 N ER0 D', '4', '*hr', '0', '139'], ['hundred', '37031', 'hundred', 'HH AH1 N D ER0 D', '5', '*hr', '0', '137'], ['been', '852399', 'been', 'B IH1 N', '2', 'i', '1', '473'], ['been', '852399', 'been', 'B AH0 N', '2', '@', '0', '403'], ['already', '125232', 'already', 'AO0 R EH1 D IY0', '5', 'iyF', '0', '103'], ['already', '125232', 'already', 'AO0 L R EH1 D IY0', '6', 'iyF', '0', '61'], ['sometimes', '91514', 'sometimes', 'S AH1 M T AY2 M Z', '5', 'ay', '2', '310'], ['sometimes', '91514', 'sometimes', 'S AH0 M T AY1 M Z', '5', 'ay', '1', '240'], ['kept', '59068', 'kept', 'K AE1 P T', '2', 'NA', '1', '140'], ['kept', '59068', 'kept', 'K EH1 P T', '2', 'e', '1', '69'], ['good', '394706', 'good', 'G UH1 D', '2', 'u', '1', '717'], ['good', '394706', 'good', 'G AH0 D', '2', '@', '0', '973'], ['if', '1013741', 'if', 'IH1 F', '1', 'i', '1', '1436'], ['if', '1013741', 'if', 'AH0 F', '1', '@', '0', '923'], ['says', '599409', 'says', 'S IH1 Z', '2', 'i', '1', '253'], ['says', '599409', 'says', 'S EH1 Z', '2', 'e', '1', '297'], ['getting', '122440', 'getting', 'G IH1 T IH0 NG', '2', 'i', '1', '306'], ['getting', '122440', 'getting', 'G EH1 T IH0 NG', '2', 'e', '1', '157'], ['inside', '89322', 'inside', 'IH1 N S AY2 D', '4', 'ay', '2', '61'], ['inside', '89322', 'inside', 'IH2 N S AY1 D', '4', 'ay', '1', '61'], ['falling', '19263', 'falling', 'F AO1 L IH0 NG', '2', 'oh', '1', '8'], ['falling', '19263', 'falling', 'F AA1 L IH0 NG', '2', 'o', '1', '4'], ['during', '206634', 'during', 'D ER1 IH0 NG', '2', '*hr', '1', '42'], ['during', '206634', 'during', 'D UH1 R AH0 N', '2', 'uwr', '1', '40'], ['during', '206634', 'during', 'D UH1 R IH0 NG', '2', 'uwr', '1', '48'], ['resemble', '3531', 'resemble', 'R AH0 Z EH1 M B AH0 L', '4', 'e', '1', '1'], ['resemble', '3531', 'resemble', 'R IY0 Z EH1 M B AH0 L', '2', 'iy', '0', '1'], ['relaxed', '6614', 'relaxed', 'R IY0 L AE1 K S T', '2', 'iy', '0', '4'], ['relaxed', '6614', 'relaxed', 'R AH0 L AE1 K S T', '4', 'ae', '1', '2'], ['recently', '60790', 'recently', 'R IY1 S AH0 N L IY0', '7', 'iyF', '0', '30'], ['recently', '60790', 'recently', 'R IY1 S AH0 N T L IY0', '8', 'iyF', '0', '14'], ['empty', '26676', 'empty', 'EH1 M T IY0', '4', 'iyF', '0', '13'], ['empty', '26676', 'empty', 'EH1 M P T IY0', '1', 'e', '1', '18'], ['current', '66326', 'current', 'K ER1 N T', '2', '*hr', '1', '2'], ['current', '66326', 'current', 'K AA1 R AH0 N T', '2', 'ahr', '1', '2'], ['enter', '20536', 'enter', 'EH1 N T ER0', '4', '*hr', '0', '4'], ['enter', '20536', 'enter', 'EH1 N ER0', '1', 'e', '1', '3'], ['remember', '82434', 'remember', 'R AH0 M EH1 M B ER0', '7', '*hr', '0', '337'], ['remember', '82434', 'remember', 'R IY0 M EH1 M B ER0', '2', 'iy', '0', '368'], ['remained', '24394', 'remained', 'R IY0 M EY1 N D', '2', 'iy', '0', '4'], ['remained', '24394', 'remained', 'R AH0 M EY1 N D', '4', 'ey', '1', '3'], ['address', '39322', 'address', 'AE1 D R EH2 S', '1', 'ae', '1', '18'], ['address', '39322', 'address', 'AH0 D R EH1 S', '4', 'e', '1', '13'], ['gets', '60758', 'gets', 'G IH1 T S', '2', 'i', '1', '172'], ['gets', '60758', 'gets', 'G  ...
